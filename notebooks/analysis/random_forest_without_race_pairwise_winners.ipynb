# %% [markdown]
# # `random_forest_without_race_pairwise_winners.ipynb`

# %% [markdown]
# ### Author: Anthony Hein

# %% [markdown]
# #### Last updated: 11/20/2021

# %% [markdown]
# # Overview:
#
# Use the datasets
# * `X_train_preprocess_without_race.csv`
# * `X_dev_preprocess_without_race.csv`
# * `X_test_preprocess_without_race.csv`
#
# and the targets in
# * `X_train_pairwise_winner_labels.csv`
# * `X_dev_pairwise_winner_labels.csv`
# * `X_test_pairwise_winner_labels.csv`
#
# to make a random forests model that tries to predict the pairwise winner between each pair of runners.

# %% [markdown]
# ---

# %% [markdown]
# ## Setup

# %%
from datetime import datetime
import git
import os
from typing import List
from tqdm import tqdm
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
BASE_DIR = git.Repo(os.getcwd(), search_parent_directories=True).working_dir
BASE_DIR
# Out:
# '/Users/anthonyhein/Desktop/SML310/project'

# %% [markdown]
# ---

# %% [markdown]
# ## Load `X_train_preprocess_without_race.csv`

# %%
X_train = pd.read_csv(f"{BASE_DIR}/data/analysis/X_train_preprocess_without_race.csv", low_memory=False)
X_train.head()
# Out:
#    horse1_age  horse1_saddle  horse1_decimalPrice  horse1_isFav  \
# 0    0.200000       0.230769             0.196970           0.0
# 1    0.400000       0.038462             0.072222           0.0
# 2    0.133333       0.423077             0.098485           0.0
# 3    0.133333       0.423077             0.098485           0.0
# 4    0.133333       0.192308             0.090278           0.0
#
#    horse1_outHandicap  horse1_RPR  horse1_weight  horse1_jockey_d_last_race  \
# 0                 0.0     0.73125       0.692308                   0.007631
# 1                 0.0     0.73125       0.743590                   0.005050
# 2                 0.0     0.65000       0.705128                   0.000740
# 3                 0.0     0.65000       0.705128                   0.000740
# 4                 0.0     0.66250       0.730769                   0.000740
#
#    horse1_jockey_d_first_race  horse1_jockey_prev_1_position  ...  \
# 0                    0.236544                          0.100  ...
# 1                    0.236544                          0.100  ...
# 2                    0.237283                          0.025  ...
# 3                    0.237283                          0.025  ...
# 4                    0.234655                          0.050  ...
#
#    horse2_jockey_prev_3_position_rain  \
# 0                               0.050
# 1                               0.100
# 2                               0.100
# 3                               0.075
# 4                               0.100
#
#    horse2_jockey_prev_1_finishing_time_ratio_rain  \
# 0                                        0.805104
# 1                                        0.801416
# 2                                        0.799909
# 3                                        0.800176
# 4                                        0.799642
#
#    horse2_jockey_prev_2_finishing_time_ratio_rain  \
# 0                                        0.780139
# 1                                        0.781238
# 2                                        0.780139
# 3                                        0.781623
# 4                                        0.783601
#
#    horse2_jockey_prev_3_finishing_time_ratio_rain  \
# 0                                        0.783438
# 1                                        0.794160
# 2                                        0.786816
# 3                                        0.781870
# 4                                        0.785468
#
#    horse2_jockey_prev_1_position_rhum  horse2_jockey_prev_2_position_rhum  \
# 0                               0.100                               0.025
# 1                               0.075                               0.050
# 2                               0.025                               0.100
# 3                               0.050                               0.075
# 4                               0.125                               0.100
#
#    horse2_jockey_prev_3_position_rhum  \
# 0                               0.025
# 1                               0.075
# 2                               0.025
# 3                               0.050
# 4                               0.025
#
#    horse2_jockey_prev_1_finishing_time_ratio_rhum  \
# 0                                        0.805104
# 1                                        0.801416
# 2                                        0.799642
# 3                                        0.801163
# 4                                        0.803191
#
#    horse2_jockey_prev_2_finishing_time_ratio_rhum  \
# 0                                        0.799642
# 1                                        0.800487
# 2                                        0.806486
# 3                                        0.801416
# 4                                        0.805104
#
#    horse2_jockey_prev_3_finishing_time_ratio_rhum
# 0                                        0.780139
# 1                                        0.785703
# 2                                        0.780139
# 3                                        0.780963
# 4                                        0.780139
#
# [5 rows x 144 columns]

# %%
X_train.shape
# Out:
# (800666, 144)

# %% [markdown]
# ---

# %% [markdown]
# ## Load `X_dev_preprocess_without_race.csv`

# %%
X_dev = pd.read_csv(f"{BASE_DIR}/data/analysis/X_dev_preprocess_without_race.csv", low_memory=False)
X_dev.head()
# Out:
#    horse1_age  horse1_saddle  horse1_decimalPrice  horse1_isFav  \
# 0    0.285714       0.105263             0.200000           0.0
# 1    0.285714       0.210526             0.157143           0.0
# 2    0.285714       0.210526             0.157143           0.0
# 3    0.285714       0.210526             0.157143           0.0
# 4    0.285714       0.210526             0.157143           0.0
#
#    horse1_outHandicap  horse1_RPR  horse1_weight  horse1_jockey_d_last_race  \
# 0                 0.0    0.608392       0.769231                   0.001516
# 1                 0.0    0.258741       0.769231                   0.000445
# 2                 0.0    0.258741       0.769231                   0.000445
# 3                 0.0    0.258741       0.769231                   0.000445
# 4                 0.0    0.258741       0.769231                   0.000445
#
#    horse1_jockey_d_first_race  horse1_jockey_prev_1_position  ...  \
# 0                    0.629407                          0.250  ...
# 1                    0.286087                          0.075  ...
# 2                    0.286087                          0.075  ...
# 3                    0.286087                          0.075  ...
# 4                    0.286087                          0.075  ...
#
#    horse2_jockey_prev_3_position_rain  \
# 0                               0.200
# 1                               0.075
# 2                               0.125
# 3                               0.050
# 4                               0.175
#
#    horse2_jockey_prev_1_finishing_time_ratio_rain  \
# 0                                        0.828972
# 1                                        0.826039
# 2                                        0.826413
# 3                                        0.832401
# 4                                        0.857255
#
#    horse2_jockey_prev_2_finishing_time_ratio_rain  \
# 0                                        0.837641
# 1                                        0.826039
# 2                                        0.841758
# 3                                        0.832114
# 4                                        0.835266
#
#    horse2_jockey_prev_3_finishing_time_ratio_rain  \
# 0                                        0.843255
# 1                                        0.842799
# 2                                        0.844367
# 3                                        0.828366
# 4                                        0.834946
#
#    horse2_jockey_prev_1_position_rhum  horse2_jockey_prev_2_position_rhum  \
# 0                               0.075                               0.050
# 1                               0.025                               0.025
# 2                               0.125                               0.050
# 3                               0.100                               0.075
# 4                               0.150                               0.025
#
#    horse2_jockey_prev_3_position_rhum  \
# 0                               0.275
# 1                               0.075
# 2                               0.275
# 3                               0.050
# 4                               0.200
#
#    horse2_jockey_prev_1_finishing_time_ratio_rhum  \
# 0                                        0.834583
# 1                                        0.826039
# 2                                        0.843955
# 3                                        0.832401
# 4                                        0.857255
#
#    horse2_jockey_prev_2_finishing_time_ratio_rhum  \
# 0                                        0.828972
# 1                                        0.826039
# 2                                        0.826413
# 3                                        0.837064
# 4                                        0.826039
#
#    horse2_jockey_prev_3_finishing_time_ratio_rhum
# 0                                        0.853796
# 1                                        0.842799
# 2                                        0.841758
# 3                                        0.828519
# 4                                        0.837392
#
# [5 rows x 144 columns]

# %%
X_dev.shape
# Out:
# (228766, 144)

# %% [markdown]
# ---

# %% [markdown]
# ## Load `X_test_preprocess_without_race.csv`

# %%
X_test = pd.read_csv(f"{BASE_DIR}/data/analysis/X_test_preprocess_without_race.csv", low_memory=False)
X_test.head()
# Out:
#    horse1_age  horse1_saddle  horse1_decimalPrice  horse1_isFav  \
# 0    0.230769       0.333333              0.03268           0.0
# 1    0.230769       0.333333              0.03268           0.0
# 2    0.230769       0.333333              0.03268           0.0
# 3    0.230769       0.333333              0.03268           0.0
# 4    0.230769       0.333333              0.03268           0.0
#
#    horse1_outHandicap  horse1_RPR  horse1_weight  horse1_jockey_d_last_race  \
# 0                 0.0    0.344828        0.74359                   0.001053
# 1                 0.0    0.344828        0.74359                   0.001053
# 2                 0.0    0.344828        0.74359                   0.001053
# 3                 0.0    0.344828        0.74359                   0.001053
# 4                 0.0    0.344828        0.74359                   0.001053
#
#    horse1_jockey_d_first_race  horse1_jockey_prev_1_position  ...  \
# 0                     0.49501                          0.225  ...
# 1                     0.49501                          0.225  ...
# 2                     0.49501                          0.225  ...
# 3                     0.49501                          0.225  ...
# 4                     0.49501                          0.225  ...
#
#    horse2_jockey_prev_3_position_rain  \
# 0                               0.200
# 1                               0.150
# 2                               0.075
# 3                               0.250
# 4                               0.250
#
#    horse2_jockey_prev_1_finishing_time_ratio_rain  \
# 0                                        0.865544
# 1                                        0.864781
# 2                                        0.838534
# 3                                        0.851685
# 4                                        0.847892
#
#    horse2_jockey_prev_2_finishing_time_ratio_rain  \
# 0                                        0.847264
# 1                                        0.840533
# 2                                        0.843337
# 3                                        0.849673
# 4                                        0.842776
#
#    horse2_jockey_prev_3_finishing_time_ratio_rain  \
# 0                                        0.853154
# 1                                        0.855519
# 2                                        0.846422
# 3                                        0.854624
# 4                                        0.862423
#
#    horse2_jockey_prev_1_position_rhum  horse2_jockey_prev_2_position_rhum  \
# 0                               0.025                               0.200
# 1                               0.025                               0.025
# 2                               0.200                               0.100
# 3                               0.150                               0.250
# 4                               0.175                               0.075
#
#    horse2_jockey_prev_3_position_rhum  \
# 0                               0.300
# 1                               0.025
# 2                               0.125
# 3                               0.200
# 4                               0.275
#
#    horse2_jockey_prev_1_finishing_time_ratio_rhum  \
# 0                                        0.840533
# 1                                        0.840533
# 2                                        0.853412
# 3                                        0.849673
# 4                                        0.853634
#
#    horse2_jockey_prev_2_finishing_time_ratio_rhum  \
# 0                                        0.850856
# 1                                        0.840533
# 2                                        0.842583
# 3                                        0.854624
# 4                                        0.844529
#
#    horse2_jockey_prev_3_finishing_time_ratio_rhum
# 0                                        0.864844
# 1                                        0.840533
# 2                                        0.847859
# 3                                        0.858051
# 4                                        0.862845
#
# [5 rows x 144 columns]

# %%
X_test.shape
# Out:
# (114392, 144)

# %% [markdown]
# ---

# %% [markdown]
# ## Load Pairwise Winner Labels

# %%
X_train_pairwise_winner_labels = np.loadtxt(f"{BASE_DIR}/data/analysis/x_train_pairwise_winner_labels.csv",
                                            dtype=int,
                                            delimiter=',')

# %%
X_dev_pairwise_winner_labels = np.loadtxt(f"{BASE_DIR}/data/analysis/X_dev_pairwise_winner_labels.csv",
                                          dtype=int,
                                          delimiter=',')

# %%
X_test_pairwise_winner_labels = np.loadtxt(f"{BASE_DIR}/data/analysis/X_test_pairwise_winner_labels.csv",
                                           dtype=int,
                                           delimiter=',')

# %% [markdown]
# ---

# %% [markdown]
# ## Random Forest Model

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import PredefinedSplit, GridSearchCV

## Fixing Random Seed for Reproducibility
np.random.seed(0)

# %%
## Hyperparameter Space

space = {
    'n_estimators': [10, 50, 100, 200],
    'max_features': ['auto', 'sqrt'],
    'min_samples_leaf': [1, 5, 10, 50],
}

# %%
X_train_plus_dev = pd.concat([X_train, X_dev])
X_train_plus_dev.shape
# Out:
# (1029432, 144)

# %%
X_train_plus_dev_pairwise_winner_labels = np.concatenate(
    (X_train_pairwise_winner_labels, X_dev_pairwise_winner_labels)
)
X_train_plus_dev_pairwise_winner_labels
# Out:
# array([1, 0, 1, ..., 1, 1, 1])

# %%
len(X_train), len(X_dev)
# Out:
# (800666, 228766)

# %%
test_fold = np.concatenate(
    (np.full(len(X_train), -1),
     np.zeros(len(X_dev)))
)
test_fold
# Out:
# array([-1., -1., -1., ...,  0.,  0.,  0.])

# %%
## Predefined Split
ps = PredefinedSplit(test_fold)
ps
# Out:
# PredefinedSplit(test_fold=array([-1, -1, ...,  0,  0]))

# %%
rf = RandomForestClassifier()

# %%
rf = GridSearchCV(rf, space, verbose=25, refit=False, cv=ps)

# %%
search = rf.fit(X_train_plus_dev.to_numpy(), X_train_plus_dev_pairwise_winner_labels)
# Out:
# Fitting 1 folds for each of 32 candidates, totalling 32 fits
# [CV 1/1; 1/32] START max_features=auto, min_samples_leaf=1, n_estimators=10.....
# [CV 1/1; 1/32] END max_features=auto, min_samples_leaf=1, n_estimators=10;, score=0.704 total time= 1.8min
# [CV 1/1; 2/32] START max_features=auto, min_samples_leaf=1, n_estimators=50.....
# [CV 1/1; 2/32] END max_features=auto, min_samples_leaf=1, n_estimators=50;, score=0.795 total time= 8.9min
# [CV 1/1; 3/32] START max_features=auto, min_samples_leaf=1, n_estimators=100....
# [CV 1/1; 3/32] END max_features=auto, min_samples_leaf=1, n_estimators=100;, score=0.821 total time=14.6min
# [CV 1/1; 4/32] START max_features=auto, min_samples_leaf=1, n_estimators=200....
# [CV 1/1; 4/32] END max_features=auto, min_samples_leaf=1, n_estimators=200;, score=0.833 total time=30.4min
# [CV 1/1; 5/32] START max_features=auto, min_samples_leaf=5, n_estimators=10.....
# [CV 1/1; 5/32] END max_features=auto, min_samples_leaf=5, n_estimators=10;, score=0.765 total time= 1.6min
# [CV 1/1; 6/32] START max_features=auto, min_samples_leaf=5, n_estimators=50.....
# [CV 1/1; 6/32] END max_features=auto, min_samples_leaf=5, n_estimators=50;, score=0.827 total time= 7.7min
# [CV 1/1; 7/32] START max_features=auto, min_samples_leaf=5, n_estimators=100....
# [CV 1/1; 7/32] END max_features=auto, min_samples_leaf=5, n_estimators=100;, score=0.841 total time=16.0min
# [CV 1/1; 8/32] START max_features=auto, min_samples_leaf=5, n_estimators=200....
# [CV 1/1; 8/32] END max_features=auto, min_samples_leaf=5, n_estimators=200;, score=0.854 total time=29.6min
# [CV 1/1; 9/32] START max_features=auto, min_samples_leaf=10, n_estimators=10....
# [CV 1/1; 9/32] END max_features=auto, min_samples_leaf=10, n_estimators=10;, score=0.799 total time= 1.5min
# [CV 1/1; 10/32] START max_features=auto, min_samples_leaf=10, n_estimators=50...
# [CV 1/1; 10/32] END max_features=auto, min_samples_leaf=10, n_estimators=50;, score=0.835 total time= 6.9min
# [CV 1/1; 11/32] START max_features=auto, min_samples_leaf=10, n_estimators=100..
# [CV 1/1; 11/32] END max_features=auto, min_samples_leaf=10, n_estimators=100;, score=0.846 total time=14.1min
# [CV 1/1; 12/32] START max_features=auto, min_samples_leaf=10, n_estimators=200..
# [CV 1/1; 12/32] END max_features=auto, min_samples_leaf=10, n_estimators=200;, score=0.843 total time=30.2min
# [CV 1/1; 13/32] START max_features=auto, min_samples_leaf=50, n_estimators=10...
# [CV 1/1; 13/32] END max_features=auto, min_samples_leaf=50, n_estimators=10;, score=0.803 total time= 1.5min
# [CV 1/1; 14/32] START max_features=auto, min_samples_leaf=50, n_estimators=50...
# [CV 1/1; 14/32] END max_features=auto, min_samples_leaf=50, n_estimators=50;, score=0.825 total time= 6.1min
# [CV 1/1; 15/32] START max_features=auto, min_samples_leaf=50, n_estimators=100..
# [CV 1/1; 15/32] END max_features=auto, min_samples_leaf=50, n_estimators=100;, score=0.828 total time=11.2min
# [CV 1/1; 16/32] START max_features=auto, min_samples_leaf=50, n_estimators=200..
# [CV 1/1; 16/32] END max_features=auto, min_samples_leaf=50, n_estimators=200;, score=0.837 total time=22.8min
# [CV 1/1; 17/32] START max_features=sqrt, min_samples_leaf=1, n_estimators=10....
# [CV 1/1; 17/32] END max_features=sqrt, min_samples_leaf=1, n_estimators=10;, score=0.686 total time= 1.8min
# [CV 1/1; 18/32] START max_features=sqrt, min_samples_leaf=1, n_estimators=50....
# [CV 1/1; 18/32] END max_features=sqrt, min_samples_leaf=1, n_estimators=50;, score=0.790 total time= 8.3min
# [CV 1/1; 19/32] START max_features=sqrt, min_samples_leaf=1, n_estimators=100...
# [CV 1/1; 19/32] END max_features=sqrt, min_samples_leaf=1, n_estimators=100;, score=0.816 total time=15.0min
# [CV 1/1; 20/32] START max_features=sqrt, min_samples_leaf=1, n_estimators=200...
# [CV 1/1; 20/32] END max_features=sqrt, min_samples_leaf=1, n_estimators=200;, score=0.835 total time=24.0min
# [CV 1/1; 21/32] START max_features=sqrt, min_samples_leaf=5, n_estimators=10....
# [CV 1/1; 21/32] END max_features=sqrt, min_samples_leaf=5, n_estimators=10;, score=0.769 total time= 1.2min
# [CV 1/1; 22/32] START max_features=sqrt, min_samples_leaf=5, n_estimators=50....
# [CV 1/1; 22/32] END max_features=sqrt, min_samples_leaf=5, n_estimators=50;, score=0.831 total time= 5.6min
# [CV 1/1; 23/32] START max_features=sqrt, min_samples_leaf=5, n_estimators=100...
# [CV 1/1; 23/32] END max_features=sqrt, min_samples_leaf=5, n_estimators=100;, score=0.839 total time=11.3min
# [CV 1/1; 24/32] START max_features=sqrt, min_samples_leaf=5, n_estimators=200...
# [CV 1/1; 24/32] END max_features=sqrt, min_samples_leaf=5, n_estimators=200;, score=0.848 total time=22.5min
# [CV 1/1; 25/32] START max_features=sqrt, min_samples_leaf=10, n_estimators=10...
# [CV 1/1; 25/32] END max_features=sqrt, min_samples_leaf=10, n_estimators=10;, score=0.796 total time= 1.2min
# [CV 1/1; 26/32] START max_features=sqrt, min_samples_leaf=10, n_estimators=50...
# [CV 1/1; 26/32] END max_features=sqrt, min_samples_leaf=10, n_estimators=50;, score=0.842 total time= 6.1min
# [CV 1/1; 27/32] START max_features=sqrt, min_samples_leaf=10, n_estimators=100..
# [CV 1/1; 27/32] END max_features=sqrt, min_samples_leaf=10, n_estimators=100;, score=0.841 total time=11.7min
# [CV 1/1; 28/32] START max_features=sqrt, min_samples_leaf=10, n_estimators=200..
# [CV 1/1; 28/32] END max_features=sqrt, min_samples_leaf=10, n_estimators=200;, score=0.843 total time=22.6min
# [CV 1/1; 29/32] START max_features=sqrt, min_samples_leaf=50, n_estimators=10...
# [CV 1/1; 29/32] END max_features=sqrt, min_samples_leaf=50, n_estimators=10;, score=0.803 total time= 1.1min
# [CV 1/1; 30/32] START max_features=sqrt, min_samples_leaf=50, n_estimators=50...
# [CV 1/1; 30/32] END max_features=sqrt, min_samples_leaf=50, n_estimators=50;, score=0.824 total time= 5.8min
# [CV 1/1; 31/32] START max_features=sqrt, min_samples_leaf=50, n_estimators=100..
# [CV 1/1; 31/32] END max_features=sqrt, min_samples_leaf=50, n_estimators=100;, score=0.833 total time=10.2min
# [CV 1/1; 32/32] START max_features=sqrt, min_samples_leaf=50, n_estimators=200..
# [CV 1/1; 32/32] END max_features=sqrt, min_samples_leaf=50, n_estimators=200;, score=0.834 total time=20.6min

# %%
print(f"Best Score: {search.best_score_}")
print(f"Best Hyperparameters: {search.best_params_}")
# Out:
# Best Score: 0.8536233531206561
# Best Hyperparameters: {'max_features': 'auto', 'min_samples_leaf': 5, 'n_estimators': 200}

# %%
pd.DataFrame(search.cv_results_)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0      107.766213           0.0         0.674145             0.0
# 1      529.805695           0.0         2.971045             0.0
# 2      872.000490           0.0         5.210074             0.0
# 3     1810.016851           0.0        11.573124             0.0
# 4       95.621263           0.0         0.605932             0.0
# 5      461.268478           0.0         2.908027             0.0
# 6      952.696069           0.0         5.087189             0.0
# 7     1765.740534           0.0        10.948357             0.0
# 8       90.753737           0.0         0.589362             0.0
# 9      409.274624           0.0         2.077695             0.0
# 10     840.263452           0.0         4.881129             0.0
# 11    1804.304374           0.0         9.445501             0.0
# 12      86.555065           0.0         0.543253             0.0
# 13     366.253593           0.0         1.564903             0.0
# 14     670.118964           0.0         3.748892             0.0
# 15    1359.466022           0.0         7.565788             0.0
# 16     104.301398           0.0         0.725129             0.0
# 17     493.986803           0.0         3.095950             0.0
# 18     896.169129           0.0         4.235019             0.0
# 19    1430.646067           0.0         7.168162             0.0
# 20      69.072522           0.0         0.434584             0.0
# 21     336.959699           0.0         1.798823             0.0
# 22     673.877776           0.0         3.414653             0.0
# 23    1344.426250           0.0         7.210399             0.0
# 24      70.802003           0.0         0.496827             0.0
# 25     361.309829           0.0         1.991916             0.0
# 26     698.454605           0.0         3.753423             0.0
# 27    1350.196242           0.0         7.494796             0.0
# 28      63.582749           0.0         0.384556             0.0
# 29     344.093196           0.0         1.412131             0.0
# 30     609.476784           0.0         3.016324             0.0
# 31    1230.982142           0.0         7.110353             0.0
#
#    param_max_features param_min_samples_leaf param_n_estimators  \
# 0                auto                      1                 10
# 1                auto                      1                 50
# 2                auto                      1                100
# 3                auto                      1                200
# 4                auto                      5                 10
# 5                auto                      5                 50
# 6                auto                      5                100
# 7                auto                      5                200
# 8                auto                     10                 10
# 9                auto                     10                 50
# 10               auto                     10                100
# 11               auto                     10                200
# 12               auto                     50                 10
# 13               auto                     50                 50
# 14               auto                     50                100
# 15               auto                     50                200
# 16               sqrt                      1                 10
# 17               sqrt                      1                 50
# 18               sqrt                      1                100
# 19               sqrt                      1                200
# 20               sqrt                      5                 10
# 21               sqrt                      5                 50
# 22               sqrt                      5                100
# 23               sqrt                      5                200
# 24               sqrt                     10                 10
# 25               sqrt                     10                 50
# 26               sqrt                     10                100
# 27               sqrt                     10                200
# 28               sqrt                     50                 10
# 29               sqrt                     50                 50
# 30               sqrt                     50                100
# 31               sqrt                     50                200
#
#                                                params  split0_test_score  \
# 0   {'max_features': 'auto', 'min_samples_leaf': 1...           0.703702
# 1   {'max_features': 'auto', 'min_samples_leaf': 1...           0.795039
# 2   {'max_features': 'auto', 'min_samples_leaf': 1...           0.821215
# 3   {'max_features': 'auto', 'min_samples_leaf': 1...           0.833494
# 4   {'max_features': 'auto', 'min_samples_leaf': 5...           0.765114
# 5   {'max_features': 'auto', 'min_samples_leaf': 5...           0.826526
# 6   {'max_features': 'auto', 'min_samples_leaf': 5...           0.840767
# 7   {'max_features': 'auto', 'min_samples_leaf': 5...           0.853623
# 8   {'max_features': 'auto', 'min_samples_leaf': 1...           0.799074
# 9   {'max_features': 'auto', 'min_samples_leaf': 1...           0.834626
# 10  {'max_features': 'auto', 'min_samples_leaf': 1...           0.845598
# 11  {'max_features': 'auto', 'min_samples_leaf': 1...           0.843333
# 12  {'max_features': 'auto', 'min_samples_leaf': 5...           0.802960
# 13  {'max_features': 'auto', 'min_samples_leaf': 5...           0.825175
# 14  {'max_features': 'auto', 'min_samples_leaf': 5...           0.828314
# 15  {'max_features': 'auto', 'min_samples_leaf': 5...           0.836746
# 16  {'max_features': 'sqrt', 'min_samples_leaf': 1...           0.685823
# 17  {'max_features': 'sqrt', 'min_samples_leaf': 1...           0.789750
# 18  {'max_features': 'sqrt', 'min_samples_leaf': 1...           0.816354
# 19  {'max_features': 'sqrt', 'min_samples_leaf': 1...           0.835391
# 20  {'max_features': 'sqrt', 'min_samples_leaf': 5...           0.769376
# 21  {'max_features': 'sqrt', 'min_samples_leaf': 5...           0.830998
# 22  {'max_features': 'sqrt', 'min_samples_leaf': 5...           0.839373
# 23  {'max_features': 'sqrt', 'min_samples_leaf': 5...           0.848050
# 24  {'max_features': 'sqrt', 'min_samples_leaf': 1...           0.796176
# 25  {'max_features': 'sqrt', 'min_samples_leaf': 1...           0.842455
# 26  {'max_features': 'sqrt', 'min_samples_leaf': 1...           0.841222
# 27  {'max_features': 'sqrt', 'min_samples_leaf': 1...           0.842660
# 28  {'max_features': 'sqrt', 'min_samples_leaf': 5...           0.803454
# 29  {'max_features': 'sqrt', 'min_samples_leaf': 5...           0.823890
# 30  {'max_features': 'sqrt', 'min_samples_leaf': 5...           0.833258
# 31  {'max_features': 'sqrt', 'min_samples_leaf': 5...           0.833939
#
#     mean_test_score  std_test_score  rank_test_score
# 0          0.703702             0.0               31
# 1          0.795039             0.0               27
# 2          0.821215             0.0               21
# 3          0.833494             0.0               14
# 4          0.765114             0.0               30
# 5          0.826526             0.0               18
# 6          0.840767             0.0                8
# 7          0.853623             0.0                1
# 8          0.799074             0.0               25
# 9          0.834626             0.0               12
# 10         0.845598             0.0                3
# 11         0.843333             0.0                4
# 12         0.802960             0.0               24
# 13         0.825175             0.0               19
# 14         0.828314             0.0               17
# 15         0.836746             0.0               10
# 16         0.685823             0.0               32
# 17         0.789750             0.0               28
# 18         0.816354             0.0               22
# 19         0.835391             0.0               11
# 20         0.769376             0.0               29
# 21         0.830998             0.0               16
# 22         0.839373             0.0                9
# 23         0.848050             0.0                2
# 24         0.796176             0.0               26
# 25         0.842455             0.0                6
# 26         0.841222             0.0                7
# 27         0.842660             0.0                5
# 28         0.803454             0.0               23
# 29         0.823890             0.0               20
# 30         0.833258             0.0               15
# 31         0.833939             0.0               13

# %%
pd.DataFrame(search.cv_results_).to_csv(
    f"{BASE_DIR}/data/analysis/random_forest/without_race_with_weather.csv", index=False
)

# %%
import pickle

rf = RandomForestClassifier(
    max_features='auto',
    min_samples_leaf=5,
    n_estimators=200,
).fit(X_train.to_numpy(), X_train_pairwise_winner_labels)

with open(f"{BASE_DIR}/data/analysis/random_forest/without_race_with_weather.pkl",'wb') as f:
    pickle.dump(rf, f)

# %% [markdown]
# ---
