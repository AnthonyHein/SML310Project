# %% [markdown]
# # `extra_trees_without_race_pairwise_winners.ipynb`

# %% [markdown]
# ### Author: Anthony Hein

# %% [markdown]
# #### Last updated: 11/29/2021

# %% [markdown]
# # Overview:
#
# Use the datasets
# * `X_train_preprocess_without_race.csv`
# * `X_dev_preprocess_without_race.csv`
# * `X_test_preprocess_without_race.csv`
#
# and the targets in
# * `X_train_pairwise_winner_labels.csv`
# * `X_dev_pairwise_winner_labels.csv`
# * `X_test_pairwise_winner_labels.csv`
#
# to make an extra trees model that tries to predict the pairwise winner between each pair of runners.

# %% [markdown]
# ---

# %% [markdown]
# ## Setup

# %%
from datetime import datetime
import git
import os
from typing import List
from tqdm import tqdm
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
BASE_DIR = git.Repo(os.getcwd(), search_parent_directories=True).working_dir
BASE_DIR
# Out:
# '/Users/anthonyhein/Desktop/SML310/project'

# %% [markdown]
# ---

# %% [markdown]
# ## Load `X_train_preprocess_without_race.csv`

# %%
X_train = pd.read_csv(f"{BASE_DIR}/data/analysis/X_train_preprocess_without_race.csv", low_memory=False)
X_train.head()
# Out:
#    horse1_age  horse1_saddle  horse1_decimalPrice  horse1_isFav  \
# 0    0.200000       0.230769             0.196970           0.0
# 1    0.400000       0.038462             0.072222           0.0
# 2    0.133333       0.423077             0.098485           0.0
# 3    0.133333       0.423077             0.098485           0.0
# 4    0.133333       0.192308             0.090278           0.0
#
#    horse1_outHandicap  horse1_RPR  horse1_weight  horse1_jockey_d_last_race  \
# 0                 0.0     0.73125       0.692308                   0.007631
# 1                 0.0     0.73125       0.743590                   0.005050
# 2                 0.0     0.65000       0.705128                   0.000740
# 3                 0.0     0.65000       0.705128                   0.000740
# 4                 0.0     0.66250       0.730769                   0.000740
#
#    horse1_jockey_d_first_race  horse1_jockey_prev_1_position  ...  \
# 0                    0.236544                          0.100  ...
# 1                    0.236544                          0.100  ...
# 2                    0.237283                          0.025  ...
# 3                    0.237283                          0.025  ...
# 4                    0.234655                          0.050  ...
#
#    horse2_jockey_prev_3_position_rain  \
# 0                               0.050
# 1                               0.100
# 2                               0.100
# 3                               0.075
# 4                               0.100
#
#    horse2_jockey_prev_1_finishing_time_ratio_rain  \
# 0                                        0.805104
# 1                                        0.801416
# 2                                        0.799909
# 3                                        0.800176
# 4                                        0.799642
#
#    horse2_jockey_prev_2_finishing_time_ratio_rain  \
# 0                                        0.780139
# 1                                        0.781238
# 2                                        0.780139
# 3                                        0.781623
# 4                                        0.783601
#
#    horse2_jockey_prev_3_finishing_time_ratio_rain  \
# 0                                        0.783438
# 1                                        0.794160
# 2                                        0.786816
# 3                                        0.781870
# 4                                        0.785468
#
#    horse2_jockey_prev_1_position_rhum  horse2_jockey_prev_2_position_rhum  \
# 0                               0.100                               0.025
# 1                               0.075                               0.050
# 2                               0.025                               0.100
# 3                               0.050                               0.075
# 4                               0.125                               0.100
#
#    horse2_jockey_prev_3_position_rhum  \
# 0                               0.025
# 1                               0.075
# 2                               0.025
# 3                               0.050
# 4                               0.025
#
#    horse2_jockey_prev_1_finishing_time_ratio_rhum  \
# 0                                        0.805104
# 1                                        0.801416
# 2                                        0.799642
# 3                                        0.801163
# 4                                        0.803191
#
#    horse2_jockey_prev_2_finishing_time_ratio_rhum  \
# 0                                        0.799642
# 1                                        0.800487
# 2                                        0.806486
# 3                                        0.801416
# 4                                        0.805104
#
#    horse2_jockey_prev_3_finishing_time_ratio_rhum
# 0                                        0.780139
# 1                                        0.785703
# 2                                        0.780139
# 3                                        0.780963
# 4                                        0.780139
#
# [5 rows x 144 columns]

# %%
X_train.shape
# Out:
# (800666, 144)

# %% [markdown]
# ---

# %% [markdown]
# ## Load `X_dev_preprocess_without_race.csv`

# %%
X_dev = pd.read_csv(f"{BASE_DIR}/data/analysis/X_dev_preprocess_without_race.csv", low_memory=False)
X_dev.head()
# Out:
#    horse1_age  horse1_saddle  horse1_decimalPrice  horse1_isFav  \
# 0    0.285714       0.105263             0.200000           0.0
# 1    0.285714       0.210526             0.157143           0.0
# 2    0.285714       0.210526             0.157143           0.0
# 3    0.285714       0.210526             0.157143           0.0
# 4    0.285714       0.210526             0.157143           0.0
#
#    horse1_outHandicap  horse1_RPR  horse1_weight  horse1_jockey_d_last_race  \
# 0                 0.0    0.608392       0.769231                   0.001516
# 1                 0.0    0.258741       0.769231                   0.000445
# 2                 0.0    0.258741       0.769231                   0.000445
# 3                 0.0    0.258741       0.769231                   0.000445
# 4                 0.0    0.258741       0.769231                   0.000445
#
#    horse1_jockey_d_first_race  horse1_jockey_prev_1_position  ...  \
# 0                    0.629407                          0.250  ...
# 1                    0.286087                          0.075  ...
# 2                    0.286087                          0.075  ...
# 3                    0.286087                          0.075  ...
# 4                    0.286087                          0.075  ...
#
#    horse2_jockey_prev_3_position_rain  \
# 0                               0.200
# 1                               0.075
# 2                               0.125
# 3                               0.050
# 4                               0.175
#
#    horse2_jockey_prev_1_finishing_time_ratio_rain  \
# 0                                        0.828972
# 1                                        0.826039
# 2                                        0.826413
# 3                                        0.832401
# 4                                        0.857255
#
#    horse2_jockey_prev_2_finishing_time_ratio_rain  \
# 0                                        0.837641
# 1                                        0.826039
# 2                                        0.841758
# 3                                        0.832114
# 4                                        0.835266
#
#    horse2_jockey_prev_3_finishing_time_ratio_rain  \
# 0                                        0.843255
# 1                                        0.842799
# 2                                        0.844367
# 3                                        0.828366
# 4                                        0.834946
#
#    horse2_jockey_prev_1_position_rhum  horse2_jockey_prev_2_position_rhum  \
# 0                               0.075                               0.050
# 1                               0.025                               0.025
# 2                               0.125                               0.050
# 3                               0.100                               0.075
# 4                               0.150                               0.025
#
#    horse2_jockey_prev_3_position_rhum  \
# 0                               0.275
# 1                               0.075
# 2                               0.275
# 3                               0.050
# 4                               0.200
#
#    horse2_jockey_prev_1_finishing_time_ratio_rhum  \
# 0                                        0.834583
# 1                                        0.826039
# 2                                        0.843955
# 3                                        0.832401
# 4                                        0.857255
#
#    horse2_jockey_prev_2_finishing_time_ratio_rhum  \
# 0                                        0.828972
# 1                                        0.826039
# 2                                        0.826413
# 3                                        0.837064
# 4                                        0.826039
#
#    horse2_jockey_prev_3_finishing_time_ratio_rhum
# 0                                        0.853796
# 1                                        0.842799
# 2                                        0.841758
# 3                                        0.828519
# 4                                        0.837392
#
# [5 rows x 144 columns]

# %%
X_dev.shape
# Out:
# (228766, 144)

# %% [markdown]
# ---

# %% [markdown]
# ## Load `X_test_preprocess_without_race.csv`

# %%
X_test = pd.read_csv(f"{BASE_DIR}/data/analysis/X_test_preprocess_without_race.csv", low_memory=False)
X_test.head()
# Out:
#    horse1_age  horse1_saddle  horse1_decimalPrice  horse1_isFav  \
# 0    0.230769       0.333333              0.03268           0.0
# 1    0.230769       0.333333              0.03268           0.0
# 2    0.230769       0.333333              0.03268           0.0
# 3    0.230769       0.333333              0.03268           0.0
# 4    0.230769       0.333333              0.03268           0.0
#
#    horse1_outHandicap  horse1_RPR  horse1_weight  horse1_jockey_d_last_race  \
# 0                 0.0    0.344828        0.74359                   0.001053
# 1                 0.0    0.344828        0.74359                   0.001053
# 2                 0.0    0.344828        0.74359                   0.001053
# 3                 0.0    0.344828        0.74359                   0.001053
# 4                 0.0    0.344828        0.74359                   0.001053
#
#    horse1_jockey_d_first_race  horse1_jockey_prev_1_position  ...  \
# 0                     0.49501                          0.225  ...
# 1                     0.49501                          0.225  ...
# 2                     0.49501                          0.225  ...
# 3                     0.49501                          0.225  ...
# 4                     0.49501                          0.225  ...
#
#    horse2_jockey_prev_3_position_rain  \
# 0                               0.200
# 1                               0.150
# 2                               0.075
# 3                               0.250
# 4                               0.250
#
#    horse2_jockey_prev_1_finishing_time_ratio_rain  \
# 0                                        0.865544
# 1                                        0.864781
# 2                                        0.838534
# 3                                        0.851685
# 4                                        0.847892
#
#    horse2_jockey_prev_2_finishing_time_ratio_rain  \
# 0                                        0.847264
# 1                                        0.840533
# 2                                        0.843337
# 3                                        0.849673
# 4                                        0.842776
#
#    horse2_jockey_prev_3_finishing_time_ratio_rain  \
# 0                                        0.853154
# 1                                        0.855519
# 2                                        0.846422
# 3                                        0.854624
# 4                                        0.862423
#
#    horse2_jockey_prev_1_position_rhum  horse2_jockey_prev_2_position_rhum  \
# 0                               0.025                               0.200
# 1                               0.025                               0.025
# 2                               0.200                               0.100
# 3                               0.150                               0.250
# 4                               0.175                               0.075
#
#    horse2_jockey_prev_3_position_rhum  \
# 0                               0.300
# 1                               0.025
# 2                               0.125
# 3                               0.200
# 4                               0.275
#
#    horse2_jockey_prev_1_finishing_time_ratio_rhum  \
# 0                                        0.840533
# 1                                        0.840533
# 2                                        0.853412
# 3                                        0.849673
# 4                                        0.853634
#
#    horse2_jockey_prev_2_finishing_time_ratio_rhum  \
# 0                                        0.850856
# 1                                        0.840533
# 2                                        0.842583
# 3                                        0.854624
# 4                                        0.844529
#
#    horse2_jockey_prev_3_finishing_time_ratio_rhum
# 0                                        0.864844
# 1                                        0.840533
# 2                                        0.847859
# 3                                        0.858051
# 4                                        0.862845
#
# [5 rows x 144 columns]

# %%
X_test.shape
# Out:
# (114392, 144)

# %% [markdown]
# ---

# %% [markdown]
# ## Load Pairwise Winner Labels

# %%
X_train_pairwise_winner_labels = np.loadtxt(f"{BASE_DIR}/data/analysis/x_train_pairwise_winner_labels.csv",
                                            dtype=int,
                                            delimiter=',')

# %%
X_dev_pairwise_winner_labels = np.loadtxt(f"{BASE_DIR}/data/analysis/X_dev_pairwise_winner_labels.csv",
                                          dtype=int,
                                          delimiter=',')

# %%
X_test_pairwise_winner_labels = np.loadtxt(f"{BASE_DIR}/data/analysis/X_test_pairwise_winner_labels.csv",
                                           dtype=int,
                                           delimiter=',')

# %% [markdown]
# ---

# %% [markdown]
# ## Extra Trees Model

# %%
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.model_selection import PredefinedSplit, GridSearchCV

## Fixing Random Seed for Reproducibility
np.random.seed(0)

# %%
## Hyperparameter Space

space = {
    'n_estimators': [10, 50, 100, 200],
    'max_features': ['auto', 'sqrt'],
    'min_samples_leaf': [1, 5, 10, 50],
}

# %%
X_train_plus_dev = pd.concat([X_train, X_dev])
X_train_plus_dev.shape
# Out:
# (1029432, 144)

# %%
X_train_plus_dev_pairwise_winner_labels = np.concatenate(
    (X_train_pairwise_winner_labels, X_dev_pairwise_winner_labels)
)
X_train_plus_dev_pairwise_winner_labels
# Out:
# array([1, 0, 1, ..., 1, 1, 1])

# %%
len(X_train), len(X_dev)
# Out:
# (800666, 228766)

# %%
test_fold = np.concatenate(
    (np.full(len(X_train), -1),
     np.zeros(len(X_dev)))
)
test_fold
# Out:
# array([-1., -1., -1., ...,  0.,  0.,  0.])

# %%
## Predefined Split
ps = PredefinedSplit(test_fold)
ps
# Out:
# PredefinedSplit(test_fold=array([-1, -1, ...,  0,  0]))

# %%
rf = ExtraTreesClassifier()

# %%
rf = GridSearchCV(rf, space, verbose=25, refit=False, cv=ps)

# %%
search = rf.fit(X_train_plus_dev.to_numpy(), X_train_plus_dev_pairwise_winner_labels)
# Out:
# Fitting 1 folds for each of 32 candidates, totalling 32 fits
# [CV 1/1; 1/32] START max_features=auto, min_samples_leaf=1, n_estimators=10.....
# [CV 1/1; 1/32] END max_features=auto, min_samples_leaf=1, n_estimators=10;, score=0.646 total time=  54.6s
# [CV 1/1; 2/32] START max_features=auto, min_samples_leaf=1, n_estimators=50.....
# [CV 1/1; 2/32] END max_features=auto, min_samples_leaf=1, n_estimators=50;, score=0.765 total time= 4.0min
# [CV 1/1; 3/32] START max_features=auto, min_samples_leaf=1, n_estimators=100....
# [CV 1/1; 3/32] END max_features=auto, min_samples_leaf=1, n_estimators=100;, score=0.791 total time= 7.7min
# [CV 1/1; 4/32] START max_features=auto, min_samples_leaf=1, n_estimators=200....
# [CV 1/1; 4/32] END max_features=auto, min_samples_leaf=1, n_estimators=200;, score=0.808 total time=12.7min
# [CV 1/1; 5/32] START max_features=auto, min_samples_leaf=5, n_estimators=10.....
# [CV 1/1; 5/32] END max_features=auto, min_samples_leaf=5, n_estimators=10;, score=0.752 total time=  35.6s
# [CV 1/1; 6/32] START max_features=auto, min_samples_leaf=5, n_estimators=50.....
# [CV 1/1; 6/32] END max_features=auto, min_samples_leaf=5, n_estimators=50;, score=0.809 total time= 2.8min
# [CV 1/1; 7/32] START max_features=auto, min_samples_leaf=5, n_estimators=100....
# [CV 1/1; 7/32] END max_features=auto, min_samples_leaf=5, n_estimators=100;, score=0.817 total time= 5.6min
# [CV 1/1; 8/32] START max_features=auto, min_samples_leaf=5, n_estimators=200....
# [CV 1/1; 8/32] END max_features=auto, min_samples_leaf=5, n_estimators=200;, score=0.822 total time=11.3min
# [CV 1/1; 9/32] START max_features=auto, min_samples_leaf=10, n_estimators=10....
# [CV 1/1; 9/32] END max_features=auto, min_samples_leaf=10, n_estimators=10;, score=0.746 total time=  31.4s
# [CV 1/1; 10/32] START max_features=auto, min_samples_leaf=10, n_estimators=50...
# [CV 1/1; 10/32] END max_features=auto, min_samples_leaf=10, n_estimators=50;, score=0.806 total time= 2.6min
# [CV 1/1; 11/32] START max_features=auto, min_samples_leaf=10, n_estimators=100..
# [CV 1/1; 11/32] END max_features=auto, min_samples_leaf=10, n_estimators=100;, score=0.819 total time= 5.8min
# [CV 1/1; 12/32] START max_features=auto, min_samples_leaf=10, n_estimators=200..
# [CV 1/1; 12/32] END max_features=auto, min_samples_leaf=10, n_estimators=200;, score=0.825 total time=11.5min
# [CV 1/1; 13/32] START max_features=auto, min_samples_leaf=50, n_estimators=10...
# [CV 1/1; 13/32] END max_features=auto, min_samples_leaf=50, n_estimators=10;, score=0.776 total time=  30.6s
# [CV 1/1; 14/32] START max_features=auto, min_samples_leaf=50, n_estimators=50...
# [CV 1/1; 14/32] END max_features=auto, min_samples_leaf=50, n_estimators=50;, score=0.795 total time= 2.6min
# [CV 1/1; 15/32] START max_features=auto, min_samples_leaf=50, n_estimators=100..
# [CV 1/1; 15/32] END max_features=auto, min_samples_leaf=50, n_estimators=100;, score=0.814 total time= 4.9min
# [CV 1/1; 16/32] START max_features=auto, min_samples_leaf=50, n_estimators=200..
# [CV 1/1; 16/32] END max_features=auto, min_samples_leaf=50, n_estimators=200;, score=0.819 total time=10.1min
# [CV 1/1; 17/32] START max_features=sqrt, min_samples_leaf=1, n_estimators=10....
# [CV 1/1; 17/32] END max_features=sqrt, min_samples_leaf=1, n_estimators=10;, score=0.621 total time=  45.2s
# [CV 1/1; 18/32] START max_features=sqrt, min_samples_leaf=1, n_estimators=50....
# [CV 1/1; 18/32] END max_features=sqrt, min_samples_leaf=1, n_estimators=50;, score=0.746 total time= 3.5min
# [CV 1/1; 19/32] START max_features=sqrt, min_samples_leaf=1, n_estimators=100...
# [CV 1/1; 19/32] END max_features=sqrt, min_samples_leaf=1, n_estimators=100;, score=0.797 total time= 6.7min
# [CV 1/1; 20/32] START max_features=sqrt, min_samples_leaf=1, n_estimators=200...
# [CV 1/1; 20/32] END max_features=sqrt, min_samples_leaf=1, n_estimators=200;, score=0.814 total time=13.7min
# [CV 1/1; 21/32] START max_features=sqrt, min_samples_leaf=5, n_estimators=10....
# [CV 1/1; 21/32] END max_features=sqrt, min_samples_leaf=5, n_estimators=10;, score=0.752 total time=  35.9s
# [CV 1/1; 22/32] START max_features=sqrt, min_samples_leaf=5, n_estimators=50....
# [CV 1/1; 22/32] END max_features=sqrt, min_samples_leaf=5, n_estimators=50;, score=0.807 total time= 3.1min
# [CV 1/1; 23/32] START max_features=sqrt, min_samples_leaf=5, n_estimators=100...
# [CV 1/1; 23/32] END max_features=sqrt, min_samples_leaf=5, n_estimators=100;, score=0.818 total time= 6.0min
# [CV 1/1; 24/32] START max_features=sqrt, min_samples_leaf=5, n_estimators=200...
# [CV 1/1; 24/32] END max_features=sqrt, min_samples_leaf=5, n_estimators=200;, score=0.829 total time=11.8min
# [CV 1/1; 25/32] START max_features=sqrt, min_samples_leaf=10, n_estimators=10...
# [CV 1/1; 25/32] END max_features=sqrt, min_samples_leaf=10, n_estimators=10;, score=0.753 total time=  36.7s
# [CV 1/1; 26/32] START max_features=sqrt, min_samples_leaf=10, n_estimators=50...
# [CV 1/1; 26/32] END max_features=sqrt, min_samples_leaf=10, n_estimators=50;, score=0.811 total time= 2.8min
# [CV 1/1; 27/32] START max_features=sqrt, min_samples_leaf=10, n_estimators=100..
# [CV 1/1; 27/32] END max_features=sqrt, min_samples_leaf=10, n_estimators=100;, score=0.822 total time= 5.8min
# [CV 1/1; 28/32] START max_features=sqrt, min_samples_leaf=10, n_estimators=200..
# [CV 1/1; 28/32] END max_features=sqrt, min_samples_leaf=10, n_estimators=200;, score=0.829 total time=11.8min
# [CV 1/1; 29/32] START max_features=sqrt, min_samples_leaf=50, n_estimators=10...
# [CV 1/1; 29/32] END max_features=sqrt, min_samples_leaf=50, n_estimators=10;, score=0.791 total time=  32.8s
# [CV 1/1; 30/32] START max_features=sqrt, min_samples_leaf=50, n_estimators=50...
# [CV 1/1; 30/32] END max_features=sqrt, min_samples_leaf=50, n_estimators=50;, score=0.803 total time= 2.6min
# [CV 1/1; 31/32] START max_features=sqrt, min_samples_leaf=50, n_estimators=100..
# [CV 1/1; 31/32] END max_features=sqrt, min_samples_leaf=50, n_estimators=100;, score=0.809 total time= 5.1min
# [CV 1/1; 32/32] START max_features=sqrt, min_samples_leaf=50, n_estimators=200..
# [CV 1/1; 32/32] END max_features=sqrt, min_samples_leaf=50, n_estimators=200;, score=0.820 total time=10.5min

# %%
print(f"Best Score: {search.best_score_}")
print(f"Best Hyperparameters: {search.best_params_}")
# Out:
# Best Score: 0.8286852067177815
# Best Hyperparameters: {'max_features': 'sqrt', 'min_samples_leaf': 5, 'n_estimators': 200}

# %%
pd.DataFrame(search.cv_results_).sort_values('rank_test_score')
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 23     696.966121           0.0         8.914138             0.0
# 27     697.368469           0.0         8.212973             0.0
# 11     681.181798           0.0         8.559916             0.0
# 7      667.365322           0.0         7.794024             0.0
# 26     344.760757           0.0         4.325450             0.0
# 31     621.657438           0.0         6.439013             0.0
# 15     599.243321           0.0         6.919588             0.0
# 10     346.313335           0.0         3.764994             0.0
# 22     353.366761           0.0         4.073291             0.0
# 6      333.499472           0.0         3.998338             0.0
# 14     292.889411           0.0         3.497507             0.0
# 19     810.885541           0.0         9.728824             0.0
# 25     167.288876           0.0         1.993136             0.0
# 5      166.497323           0.0         1.998929             0.0
# 30     300.427544           0.0         3.202844             0.0
# 3      750.292135           0.0         9.536505             0.0
# 21     183.180364           0.0         2.137669             0.0
# 9      156.247859           0.0         2.025413             0.0
# 29     152.570684           0.0         1.726410             0.0
# 18     396.695156           0.0         5.226770             0.0
# 13     153.299600           0.0         1.747513             0.0
# 2      455.479463           0.0         5.505737             0.0
# 28      32.381930           0.0         0.406067             0.0
# 12      30.186994           0.0         0.436538             0.0
# 1      236.160089           0.0         3.210637             0.0
# 24      36.188615           0.0         0.482320             0.0
# 4       34.993092           0.0         0.560747             0.0
# 20      35.387952           0.0         0.535209             0.0
# 8       30.948420           0.0         0.434667             0.0
# 17     210.064963           0.0         2.371134             0.0
# 0       53.504924           0.0         1.060793             0.0
# 16      44.668572           0.0         0.579442             0.0
#
#    param_max_features param_min_samples_leaf param_n_estimators  \
# 23               sqrt                      5                200
# 27               sqrt                     10                200
# 11               auto                     10                200
# 7                auto                      5                200
# 26               sqrt                     10                100
# 31               sqrt                     50                200
# 15               auto                     50                200
# 10               auto                     10                100
# 22               sqrt                      5                100
# 6                auto                      5                100
# 14               auto                     50                100
# 19               sqrt                      1                200
# 25               sqrt                     10                 50
# 5                auto                      5                 50
# 30               sqrt                     50                100
# 3                auto                      1                200
# 21               sqrt                      5                 50
# 9                auto                     10                 50
# 29               sqrt                     50                 50
# 18               sqrt                      1                100
# 13               auto                     50                 50
# 2                auto                      1                100
# 28               sqrt                     50                 10
# 12               auto                     50                 10
# 1                auto                      1                 50
# 24               sqrt                     10                 10
# 4                auto                      5                 10
# 20               sqrt                      5                 10
# 8                auto                     10                 10
# 17               sqrt                      1                 50
# 0                auto                      1                 10
# 16               sqrt                      1                 10
#
#                                                params  split0_test_score  \
# 23  {'max_features': 'sqrt', 'min_samples_leaf': 5...           0.828685
# 27  {'max_features': 'sqrt', 'min_samples_leaf': 1...           0.828646
# 11  {'max_features': 'auto', 'min_samples_leaf': 1...           0.825022
# 7   {'max_features': 'auto', 'min_samples_leaf': 5...           0.822238
# 26  {'max_features': 'sqrt', 'min_samples_leaf': 1...           0.822093
# 31  {'max_features': 'sqrt', 'min_samples_leaf': 5...           0.820367
# 15  {'max_features': 'auto', 'min_samples_leaf': 5...           0.819383
# 10  {'max_features': 'auto', 'min_samples_leaf': 1...           0.819322
# 22  {'max_features': 'sqrt', 'min_samples_leaf': 5...           0.817731
# 6   {'max_features': 'auto', 'min_samples_leaf': 5...           0.817154
# 14  {'max_features': 'auto', 'min_samples_leaf': 5...           0.814365
# 19  {'max_features': 'sqrt', 'min_samples_leaf': 1...           0.814321
# 25  {'max_features': 'sqrt', 'min_samples_leaf': 1...           0.811244
# 5   {'max_features': 'auto', 'min_samples_leaf': 5...           0.809408
# 30  {'max_features': 'sqrt', 'min_samples_leaf': 5...           0.809364
# 3   {'max_features': 'auto', 'min_samples_leaf': 1...           0.807825
# 21  {'max_features': 'sqrt', 'min_samples_leaf': 5...           0.807327
# 9   {'max_features': 'auto', 'min_samples_leaf': 1...           0.805753
# 29  {'max_features': 'sqrt', 'min_samples_leaf': 5...           0.802593
# 18  {'max_features': 'sqrt', 'min_samples_leaf': 1...           0.796753
# 13  {'max_features': 'auto', 'min_samples_leaf': 5...           0.795127
# 2   {'max_features': 'auto', 'min_samples_leaf': 1...           0.790694
# 28  {'max_features': 'sqrt', 'min_samples_leaf': 5...           0.790629
# 12  {'max_features': 'auto', 'min_samples_leaf': 5...           0.775793
# 1   {'max_features': 'auto', 'min_samples_leaf': 1...           0.764926
# 24  {'max_features': 'sqrt', 'min_samples_leaf': 1...           0.753455
# 4   {'max_features': 'auto', 'min_samples_leaf': 5...           0.752275
# 20  {'max_features': 'sqrt', 'min_samples_leaf': 5...           0.751895
# 8   {'max_features': 'auto', 'min_samples_leaf': 1...           0.746426
# 17  {'max_features': 'sqrt', 'min_samples_leaf': 1...           0.745705
# 0   {'max_features': 'auto', 'min_samples_leaf': 1...           0.646009
# 16  {'max_features': 'sqrt', 'min_samples_leaf': 1...           0.620595
#
#     mean_test_score  std_test_score  rank_test_score
# 23         0.828685             0.0                1
# 27         0.828646             0.0                2
# 11         0.825022             0.0                3
# 7          0.822238             0.0                4
# 26         0.822093             0.0                5
# 31         0.820367             0.0                6
# 15         0.819383             0.0                7
# 10         0.819322             0.0                8
# 22         0.817731             0.0                9
# 6          0.817154             0.0               10
# 14         0.814365             0.0               11
# 19         0.814321             0.0               12
# 25         0.811244             0.0               13
# 5          0.809408             0.0               14
# 30         0.809364             0.0               15
# 3          0.807825             0.0               16
# 21         0.807327             0.0               17
# 9          0.805753             0.0               18
# 29         0.802593             0.0               19
# 18         0.796753             0.0               20
# 13         0.795127             0.0               21
# 2          0.790694             0.0               22
# 28         0.790629             0.0               23
# 12         0.775793             0.0               24
# 1          0.764926             0.0               25
# 24         0.753455             0.0               26
# 4          0.752275             0.0               27
# 20         0.751895             0.0               28
# 8          0.746426             0.0               29
# 17         0.745705             0.0               30
# 0          0.646009             0.0               31
# 16         0.620595             0.0               32

# %%
pd.DataFrame(search.cv_results_).to_csv(
    f'{BASE_DIR}/data/analysis/extra_trees/without_race_with_weather.csv', index=False
)

# %%
import pickle

rf = ExtraTreesClassifier(
    max_features='sqrt',
    min_samples_leaf=5,
    n_estimators=200,
).fit(X_train.to_numpy(), X_train_pairwise_winner_labels)

with open(f"{BASE_DIR}/data/analysis/extra_trees/without_race_with_weather.pkl",'wb') as f:
    pickle.dump(rf, f)

# %% [markdown]
# ---
