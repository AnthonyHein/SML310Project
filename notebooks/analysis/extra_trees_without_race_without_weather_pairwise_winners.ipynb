# %% [markdown]
# # `extra_trees_without_race_without_weather_pairwise_winners.ipynb`

# %% [markdown]
# ### Author: Anthony Hein

# %% [markdown]
# #### Last updated: 11/29/2021

# %% [markdown]
# # Overview:
#
# Use the datasets
# * `X_train_preprocess_without_race.csv`
# * `X_dev_preprocess_without_race.csv`
# * `X_test_preprocess_without_race.csv`
#
# and the targets in
# * `X_train_pairwise_winner_labels.csv`
# * `X_dev_pairwise_winner_labels.csv`
# * `X_test_pairwise_winner_labels.csv`
#
# to make an extra trees model that tries to predict the pairwise winner between each pair of runners.

# %% [markdown]
# ---

# %% [markdown]
# ## Setup

# %%
from datetime import datetime
import git
import os
from typing import List
from tqdm import tqdm
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
BASE_DIR = git.Repo(os.getcwd(), search_parent_directories=True).working_dir
BASE_DIR
# Out:
# '/Users/anthonyhein/Desktop/SML310/project'

# %% [markdown]
# ---

# %% [markdown]
# ## Remove Features that Involve Weather

# %%
drop_cols = [
    'horse1_jockey_prev_1_position_temp',
    'horse1_jockey_prev_2_position_temp',
    'horse1_jockey_prev_3_position_temp',
    'horse1_jockey_prev_1_finishing_time_ratio_temp',
    'horse1_jockey_prev_2_finishing_time_ratio_temp',
    'horse1_jockey_prev_3_finishing_time_ratio_temp',
    'horse1_jockey_prev_1_position_msl',
    'horse1_jockey_prev_2_position_msl',
    'horse1_jockey_prev_3_position_msl',
    'horse1_jockey_prev_1_finishing_time_ratio_msl',
    'horse1_jockey_prev_2_finishing_time_ratio_msl',
    'horse1_jockey_prev_3_finishing_time_ratio_msl',
    'horse1_jockey_prev_1_position_rain',
    'horse1_jockey_prev_2_position_rain',
    'horse1_jockey_prev_3_position_rain',
    'horse1_jockey_prev_1_finishing_time_ratio_rain',
    'horse1_jockey_prev_2_finishing_time_ratio_rain',
    'horse1_jockey_prev_3_finishing_time_ratio_rain',
    'horse1_jockey_prev_1_position_rhum',
    'horse1_jockey_prev_2_position_rhum',
    'horse1_jockey_prev_3_position_rhum',
    'horse1_jockey_prev_1_finishing_time_ratio_rhum',
    'horse1_jockey_prev_2_finishing_time_ratio_rhum',
    'horse1_jockey_prev_3_finishing_time_ratio_rhum',
    'horse2_jockey_prev_1_position_temp',
    'horse2_jockey_prev_2_position_temp',
    'horse2_jockey_prev_3_position_temp',
    'horse2_jockey_prev_1_finishing_time_ratio_temp',
    'horse2_jockey_prev_2_finishing_time_ratio_temp',
    'horse2_jockey_prev_3_finishing_time_ratio_temp',
    'horse2_jockey_prev_1_position_msl',
    'horse2_jockey_prev_2_position_msl',
    'horse2_jockey_prev_3_position_msl',
    'horse2_jockey_prev_1_finishing_time_ratio_msl',
    'horse2_jockey_prev_2_finishing_time_ratio_msl',
    'horse2_jockey_prev_3_finishing_time_ratio_msl',
    'horse2_jockey_prev_1_position_rain',
    'horse2_jockey_prev_2_position_rain',
    'horse2_jockey_prev_3_position_rain',
    'horse2_jockey_prev_1_finishing_time_ratio_rain',
    'horse2_jockey_prev_2_finishing_time_ratio_rain',
    'horse2_jockey_prev_3_finishing_time_ratio_rain',
    'horse2_jockey_prev_1_position_rhum',
    'horse2_jockey_prev_2_position_rhum',
    'horse2_jockey_prev_3_position_rhum',
    'horse2_jockey_prev_1_finishing_time_ratio_rhum',
    'horse2_jockey_prev_2_finishing_time_ratio_rhum',
    'horse2_jockey_prev_3_finishing_time_ratio_rhum'
]

# %% [markdown]
# ---

# %% [markdown]
# ## Load `X_train_preprocess_without_race.csv`

# %%
X_train = pd.read_csv(f"{BASE_DIR}/data/analysis/X_train_preprocess_without_race.csv", low_memory=False)
X_train.head()
# Out:
#    horse1_age  horse1_saddle  horse1_decimalPrice  horse1_isFav  \
# 0    0.200000       0.230769             0.196970           0.0
# 1    0.400000       0.038462             0.072222           0.0
# 2    0.133333       0.423077             0.098485           0.0
# 3    0.133333       0.423077             0.098485           0.0
# 4    0.133333       0.192308             0.090278           0.0
#
#    horse1_outHandicap  horse1_RPR  horse1_weight  horse1_jockey_d_last_race  \
# 0                 0.0     0.73125       0.692308                   0.007631
# 1                 0.0     0.73125       0.743590                   0.005050
# 2                 0.0     0.65000       0.705128                   0.000740
# 3                 0.0     0.65000       0.705128                   0.000740
# 4                 0.0     0.66250       0.730769                   0.000740
#
#    horse1_jockey_d_first_race  horse1_jockey_prev_1_position  ...  \
# 0                    0.236544                          0.100  ...
# 1                    0.236544                          0.100  ...
# 2                    0.237283                          0.025  ...
# 3                    0.237283                          0.025  ...
# 4                    0.234655                          0.050  ...
#
#    horse2_jockey_prev_3_position_rain  \
# 0                               0.050
# 1                               0.100
# 2                               0.100
# 3                               0.075
# 4                               0.100
#
#    horse2_jockey_prev_1_finishing_time_ratio_rain  \
# 0                                        0.805104
# 1                                        0.801416
# 2                                        0.799909
# 3                                        0.800176
# 4                                        0.799642
#
#    horse2_jockey_prev_2_finishing_time_ratio_rain  \
# 0                                        0.780139
# 1                                        0.781238
# 2                                        0.780139
# 3                                        0.781623
# 4                                        0.783601
#
#    horse2_jockey_prev_3_finishing_time_ratio_rain  \
# 0                                        0.783438
# 1                                        0.794160
# 2                                        0.786816
# 3                                        0.781870
# 4                                        0.785468
#
#    horse2_jockey_prev_1_position_rhum  horse2_jockey_prev_2_position_rhum  \
# 0                               0.100                               0.025
# 1                               0.075                               0.050
# 2                               0.025                               0.100
# 3                               0.050                               0.075
# 4                               0.125                               0.100
#
#    horse2_jockey_prev_3_position_rhum  \
# 0                               0.025
# 1                               0.075
# 2                               0.025
# 3                               0.050
# 4                               0.025
#
#    horse2_jockey_prev_1_finishing_time_ratio_rhum  \
# 0                                        0.805104
# 1                                        0.801416
# 2                                        0.799642
# 3                                        0.801163
# 4                                        0.803191
#
#    horse2_jockey_prev_2_finishing_time_ratio_rhum  \
# 0                                        0.799642
# 1                                        0.800487
# 2                                        0.806486
# 3                                        0.801416
# 4                                        0.805104
#
#    horse2_jockey_prev_3_finishing_time_ratio_rhum
# 0                                        0.780139
# 1                                        0.785703
# 2                                        0.780139
# 3                                        0.780963
# 4                                        0.780139
#
# [5 rows x 144 columns]

# %%
X_train.shape
# Out:
# (800666, 144)

# %%
X_train = X_train.drop(columns=drop_cols)
X_train.shape
# Out:
# (800666, 96)

# %% [markdown]
# ---

# %% [markdown]
# ## Load `X_dev_preprocess_without_race.csv`

# %%
X_dev = pd.read_csv(f"{BASE_DIR}/data/analysis/X_dev_preprocess_without_race.csv", low_memory=False)
X_dev.head()
# Out:
#    horse1_age  horse1_saddle  horse1_decimalPrice  horse1_isFav  \
# 0    0.285714       0.105263             0.200000           0.0
# 1    0.285714       0.210526             0.157143           0.0
# 2    0.285714       0.210526             0.157143           0.0
# 3    0.285714       0.210526             0.157143           0.0
# 4    0.285714       0.210526             0.157143           0.0
#
#    horse1_outHandicap  horse1_RPR  horse1_weight  horse1_jockey_d_last_race  \
# 0                 0.0    0.608392       0.769231                   0.001516
# 1                 0.0    0.258741       0.769231                   0.000445
# 2                 0.0    0.258741       0.769231                   0.000445
# 3                 0.0    0.258741       0.769231                   0.000445
# 4                 0.0    0.258741       0.769231                   0.000445
#
#    horse1_jockey_d_first_race  horse1_jockey_prev_1_position  ...  \
# 0                    0.629407                          0.250  ...
# 1                    0.286087                          0.075  ...
# 2                    0.286087                          0.075  ...
# 3                    0.286087                          0.075  ...
# 4                    0.286087                          0.075  ...
#
#    horse2_jockey_prev_3_position_rain  \
# 0                               0.200
# 1                               0.075
# 2                               0.125
# 3                               0.050
# 4                               0.175
#
#    horse2_jockey_prev_1_finishing_time_ratio_rain  \
# 0                                        0.828972
# 1                                        0.826039
# 2                                        0.826413
# 3                                        0.832401
# 4                                        0.857255
#
#    horse2_jockey_prev_2_finishing_time_ratio_rain  \
# 0                                        0.837641
# 1                                        0.826039
# 2                                        0.841758
# 3                                        0.832114
# 4                                        0.835266
#
#    horse2_jockey_prev_3_finishing_time_ratio_rain  \
# 0                                        0.843255
# 1                                        0.842799
# 2                                        0.844367
# 3                                        0.828366
# 4                                        0.834946
#
#    horse2_jockey_prev_1_position_rhum  horse2_jockey_prev_2_position_rhum  \
# 0                               0.075                               0.050
# 1                               0.025                               0.025
# 2                               0.125                               0.050
# 3                               0.100                               0.075
# 4                               0.150                               0.025
#
#    horse2_jockey_prev_3_position_rhum  \
# 0                               0.275
# 1                               0.075
# 2                               0.275
# 3                               0.050
# 4                               0.200
#
#    horse2_jockey_prev_1_finishing_time_ratio_rhum  \
# 0                                        0.834583
# 1                                        0.826039
# 2                                        0.843955
# 3                                        0.832401
# 4                                        0.857255
#
#    horse2_jockey_prev_2_finishing_time_ratio_rhum  \
# 0                                        0.828972
# 1                                        0.826039
# 2                                        0.826413
# 3                                        0.837064
# 4                                        0.826039
#
#    horse2_jockey_prev_3_finishing_time_ratio_rhum
# 0                                        0.853796
# 1                                        0.842799
# 2                                        0.841758
# 3                                        0.828519
# 4                                        0.837392
#
# [5 rows x 144 columns]

# %%
X_dev.shape
# Out:
# (228766, 144)

# %%
X_dev = X_dev.drop(columns=drop_cols)
X_dev.shape
# Out:
# (228766, 96)

# %% [markdown]
# ---

# %% [markdown]
# ## Load `X_test_preprocess_without_race.csv`

# %%
X_test = pd.read_csv(f"{BASE_DIR}/data/analysis/X_test_preprocess_without_race.csv", low_memory=False)
X_test.head()
# Out:
#    horse1_age  horse1_saddle  horse1_decimalPrice  horse1_isFav  \
# 0    0.230769       0.333333              0.03268           0.0
# 1    0.230769       0.333333              0.03268           0.0
# 2    0.230769       0.333333              0.03268           0.0
# 3    0.230769       0.333333              0.03268           0.0
# 4    0.230769       0.333333              0.03268           0.0
#
#    horse1_outHandicap  horse1_RPR  horse1_weight  horse1_jockey_d_last_race  \
# 0                 0.0    0.344828        0.74359                   0.001053
# 1                 0.0    0.344828        0.74359                   0.001053
# 2                 0.0    0.344828        0.74359                   0.001053
# 3                 0.0    0.344828        0.74359                   0.001053
# 4                 0.0    0.344828        0.74359                   0.001053
#
#    horse1_jockey_d_first_race  horse1_jockey_prev_1_position  ...  \
# 0                     0.49501                          0.225  ...
# 1                     0.49501                          0.225  ...
# 2                     0.49501                          0.225  ...
# 3                     0.49501                          0.225  ...
# 4                     0.49501                          0.225  ...
#
#    horse2_jockey_prev_3_position_rain  \
# 0                               0.200
# 1                               0.150
# 2                               0.075
# 3                               0.250
# 4                               0.250
#
#    horse2_jockey_prev_1_finishing_time_ratio_rain  \
# 0                                        0.865544
# 1                                        0.864781
# 2                                        0.838534
# 3                                        0.851685
# 4                                        0.847892
#
#    horse2_jockey_prev_2_finishing_time_ratio_rain  \
# 0                                        0.847264
# 1                                        0.840533
# 2                                        0.843337
# 3                                        0.849673
# 4                                        0.842776
#
#    horse2_jockey_prev_3_finishing_time_ratio_rain  \
# 0                                        0.853154
# 1                                        0.855519
# 2                                        0.846422
# 3                                        0.854624
# 4                                        0.862423
#
#    horse2_jockey_prev_1_position_rhum  horse2_jockey_prev_2_position_rhum  \
# 0                               0.025                               0.200
# 1                               0.025                               0.025
# 2                               0.200                               0.100
# 3                               0.150                               0.250
# 4                               0.175                               0.075
#
#    horse2_jockey_prev_3_position_rhum  \
# 0                               0.300
# 1                               0.025
# 2                               0.125
# 3                               0.200
# 4                               0.275
#
#    horse2_jockey_prev_1_finishing_time_ratio_rhum  \
# 0                                        0.840533
# 1                                        0.840533
# 2                                        0.853412
# 3                                        0.849673
# 4                                        0.853634
#
#    horse2_jockey_prev_2_finishing_time_ratio_rhum  \
# 0                                        0.850856
# 1                                        0.840533
# 2                                        0.842583
# 3                                        0.854624
# 4                                        0.844529
#
#    horse2_jockey_prev_3_finishing_time_ratio_rhum
# 0                                        0.864844
# 1                                        0.840533
# 2                                        0.847859
# 3                                        0.858051
# 4                                        0.862845
#
# [5 rows x 144 columns]

# %%
X_test.shape
# Out:
# (114392, 144)

# %%
X_test = X_test.drop(columns=drop_cols)
X_test.shape
# Out:
# (114392, 96)

# %% [markdown]
# ---

# %% [markdown]
# ## Load Pairwise Winner Labels

# %%
X_train_pairwise_winner_labels = np.loadtxt(f"{BASE_DIR}/data/analysis/x_train_pairwise_winner_labels.csv",
                                            dtype=int,
                                            delimiter=',')

# %%
X_dev_pairwise_winner_labels = np.loadtxt(f"{BASE_DIR}/data/analysis/X_dev_pairwise_winner_labels.csv",
                                          dtype=int,
                                          delimiter=',')

# %%
X_test_pairwise_winner_labels = np.loadtxt(f"{BASE_DIR}/data/analysis/X_test_pairwise_winner_labels.csv",
                                           dtype=int,
                                           delimiter=',')

# %% [markdown]
# ---

# %% [markdown]
# ## Extra Trees Model

# %%
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.model_selection import PredefinedSplit, GridSearchCV

## Fixing Random Seed for Reproducibility
np.random.seed(0)

# %%
## Hyperparameter Space

space = {
    'n_estimators': [10, 50, 100, 200],
    'max_features': ['auto', 'sqrt'],
    'min_samples_leaf': [1, 5, 10, 50],
}

# %%
X_train_plus_dev = pd.concat([X_train, X_dev])
X_train_plus_dev.shape
# Out:
# (1029432, 96)

# %%
X_train_plus_dev_pairwise_winner_labels = np.concatenate(
    (X_train_pairwise_winner_labels, X_dev_pairwise_winner_labels)
)
X_train_plus_dev_pairwise_winner_labels
# Out:
# array([1, 0, 1, ..., 1, 1, 1])

# %%
len(X_train), len(X_dev)
# Out:
# (800666, 228766)

# %%
test_fold = np.concatenate(
    (np.full(len(X_train), -1),
     np.zeros(len(X_dev)))
)
test_fold
# Out:
# array([-1., -1., -1., ...,  0.,  0.,  0.])

# %%
## Predefined Split
ps = PredefinedSplit(test_fold)
ps
# Out:
# PredefinedSplit(test_fold=array([-1, -1, ...,  0,  0]))

# %%
rf = ExtraTreesClassifier()

# %%
rf = GridSearchCV(rf, space, verbose=25, refit=False, cv=ps)

# %%
search = rf.fit(X_train_plus_dev.to_numpy(), X_train_plus_dev_pairwise_winner_labels)
# Out:
# Fitting 1 folds for each of 32 candidates, totalling 32 fits
# [CV 1/1; 1/32] START max_features=auto, min_samples_leaf=1, n_estimators=10.....
# [CV 1/1; 1/32] END max_features=auto, min_samples_leaf=1, n_estimators=10;, score=0.704 total time=  32.6s
# [CV 1/1; 2/32] START max_features=auto, min_samples_leaf=1, n_estimators=50.....
# [CV 1/1; 2/32] END max_features=auto, min_samples_leaf=1, n_estimators=50;, score=0.780 total time= 2.7min
# [CV 1/1; 3/32] START max_features=auto, min_samples_leaf=1, n_estimators=100....
# [CV 1/1; 3/32] END max_features=auto, min_samples_leaf=1, n_estimators=100;, score=0.812 total time= 5.2min
# [CV 1/1; 4/32] START max_features=auto, min_samples_leaf=1, n_estimators=200....
# [CV 1/1; 4/32] END max_features=auto, min_samples_leaf=1, n_estimators=200;, score=0.831 total time=10.5min
# [CV 1/1; 5/32] START max_features=auto, min_samples_leaf=5, n_estimators=10.....
# [CV 1/1; 5/32] END max_features=auto, min_samples_leaf=5, n_estimators=10;, score=0.766 total time=  32.1s
# [CV 1/1; 6/32] START max_features=auto, min_samples_leaf=5, n_estimators=50.....
# [CV 1/1; 6/32] END max_features=auto, min_samples_leaf=5, n_estimators=50;, score=0.826 total time= 2.4min
# [CV 1/1; 7/32] START max_features=auto, min_samples_leaf=5, n_estimators=100....
# [CV 1/1; 7/32] END max_features=auto, min_samples_leaf=5, n_estimators=100;, score=0.828 total time= 4.7min
# [CV 1/1; 8/32] START max_features=auto, min_samples_leaf=5, n_estimators=200....
# [CV 1/1; 8/32] END max_features=auto, min_samples_leaf=5, n_estimators=200;, score=0.836 total time= 9.5min
# [CV 1/1; 9/32] START max_features=auto, min_samples_leaf=10, n_estimators=10....
# [CV 1/1; 9/32] END max_features=auto, min_samples_leaf=10, n_estimators=10;, score=0.772 total time=  27.6s
# [CV 1/1; 10/32] START max_features=auto, min_samples_leaf=10, n_estimators=50...
# [CV 1/1; 10/32] END max_features=auto, min_samples_leaf=10, n_estimators=50;, score=0.822 total time= 2.2min
# [CV 1/1; 11/32] START max_features=auto, min_samples_leaf=10, n_estimators=100..
# [CV 1/1; 11/32] END max_features=auto, min_samples_leaf=10, n_estimators=100;, score=0.831 total time= 4.6min
# [CV 1/1; 12/32] START max_features=auto, min_samples_leaf=10, n_estimators=200..
# [CV 1/1; 12/32] END max_features=auto, min_samples_leaf=10, n_estimators=200;, score=0.834 total time= 8.2min
# [CV 1/1; 13/32] START max_features=auto, min_samples_leaf=50, n_estimators=10...
# [CV 1/1; 13/32] END max_features=auto, min_samples_leaf=50, n_estimators=10;, score=0.789 total time=  22.6s
# [CV 1/1; 14/32] START max_features=auto, min_samples_leaf=50, n_estimators=50...
# [CV 1/1; 14/32] END max_features=auto, min_samples_leaf=50, n_estimators=50;, score=0.820 total time= 1.8min
# [CV 1/1; 15/32] START max_features=auto, min_samples_leaf=50, n_estimators=100..
# [CV 1/1; 15/32] END max_features=auto, min_samples_leaf=50, n_estimators=100;, score=0.823 total time= 3.7min
# [CV 1/1; 16/32] START max_features=auto, min_samples_leaf=50, n_estimators=200..
# [CV 1/1; 16/32] END max_features=auto, min_samples_leaf=50, n_estimators=200;, score=0.832 total time=10.9min
# [CV 1/1; 17/32] START max_features=sqrt, min_samples_leaf=1, n_estimators=10....
# [CV 1/1; 17/32] END max_features=sqrt, min_samples_leaf=1, n_estimators=10;, score=0.671 total time=  28.7s
# [CV 1/1; 18/32] START max_features=sqrt, min_samples_leaf=1, n_estimators=50....
# [CV 1/1; 18/32] END max_features=sqrt, min_samples_leaf=1, n_estimators=50;, score=0.786 total time= 2.3min
# [CV 1/1; 19/32] START max_features=sqrt, min_samples_leaf=1, n_estimators=100...
# [CV 1/1; 19/32] END max_features=sqrt, min_samples_leaf=1, n_estimators=100;, score=0.812 total time= 4.6min
# [CV 1/1; 20/32] START max_features=sqrt, min_samples_leaf=1, n_estimators=200...
# [CV 1/1; 20/32] END max_features=sqrt, min_samples_leaf=1, n_estimators=200;, score=0.834 total time= 9.3min
# [CV 1/1; 21/32] START max_features=sqrt, min_samples_leaf=5, n_estimators=10....
# [CV 1/1; 21/32] END max_features=sqrt, min_samples_leaf=5, n_estimators=10;, score=0.772 total time=  25.6s
# [CV 1/1; 22/32] START max_features=sqrt, min_samples_leaf=5, n_estimators=50....
# [CV 1/1; 22/32] END max_features=sqrt, min_samples_leaf=5, n_estimators=50;, score=0.825 total time= 2.1min
# [CV 1/1; 23/32] START max_features=sqrt, min_samples_leaf=5, n_estimators=100...
# [CV 1/1; 23/32] END max_features=sqrt, min_samples_leaf=5, n_estimators=100;, score=0.830 total time= 4.2min
# [CV 1/1; 24/32] START max_features=sqrt, min_samples_leaf=5, n_estimators=200...
# [CV 1/1; 24/32] END max_features=sqrt, min_samples_leaf=5, n_estimators=200;, score=0.838 total time=16.0min
# [CV 1/1; 25/32] START max_features=sqrt, min_samples_leaf=10, n_estimators=10...
# [CV 1/1; 25/32] END max_features=sqrt, min_samples_leaf=10, n_estimators=10;, score=0.781 total time=  25.8s
# [CV 1/1; 26/32] START max_features=sqrt, min_samples_leaf=10, n_estimators=50...
# [CV 1/1; 26/32] END max_features=sqrt, min_samples_leaf=10, n_estimators=50;, score=0.820 total time= 2.2min
# [CV 1/1; 27/32] START max_features=sqrt, min_samples_leaf=10, n_estimators=100..
# [CV 1/1; 27/32] END max_features=sqrt, min_samples_leaf=10, n_estimators=100;, score=0.830 total time= 4.3min
# [CV 1/1; 28/32] START max_features=sqrt, min_samples_leaf=10, n_estimators=200..
# [CV 1/1; 28/32] END max_features=sqrt, min_samples_leaf=10, n_estimators=200;, score=0.834 total time= 8.1min
# [CV 1/1; 29/32] START max_features=sqrt, min_samples_leaf=50, n_estimators=10...
# [CV 1/1; 29/32] END max_features=sqrt, min_samples_leaf=50, n_estimators=10;, score=0.793 total time=  22.0s
# [CV 1/1; 30/32] START max_features=sqrt, min_samples_leaf=50, n_estimators=50...
# [CV 1/1; 30/32] END max_features=sqrt, min_samples_leaf=50, n_estimators=50;, score=0.802 total time= 1.8min
# [CV 1/1; 31/32] START max_features=sqrt, min_samples_leaf=50, n_estimators=100..
# [CV 1/1; 31/32] END max_features=sqrt, min_samples_leaf=50, n_estimators=100;, score=0.825 total time= 3.5min
# [CV 1/1; 32/32] START max_features=sqrt, min_samples_leaf=50, n_estimators=200..
# [CV 1/1; 32/32] END max_features=sqrt, min_samples_leaf=50, n_estimators=200;, score=0.827 total time= 7.1min

# %%
print(f"Best Score: {search.best_score_}")
print(f"Best Hyperparameters: {search.best_params_}")
# Out:
# Best Score: 0.8375239327522447
# Best Hyperparameters: {'max_features': 'sqrt', 'min_samples_leaf': 5, 'n_estimators': 200}

# %%
pd.DataFrame(search.cv_results_).sort_values('rank_test_score')
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 23     950.554664           0.0         8.116885             0.0
# 7      561.504580           0.0         9.587898             0.0
# 27     482.029384           0.0         6.050520             0.0
# 19     550.408509           0.0         8.237085             0.0
# 11     485.671816           0.0         6.136399             0.0
# 15     649.037802           0.0         4.906199             0.0
# 3      620.151099           0.0        10.696832             0.0
# 10     271.203179           0.0         3.570949             0.0
# 26     253.031876           0.0         3.198568             0.0
# 22     248.165315           0.0         3.456243             0.0
# 6      280.369955           0.0         3.793199             0.0
# 31     421.606573           0.0         4.747101             0.0
# 5      140.918642           0.0         1.967600             0.0
# 21     125.374560           0.0         1.677879             0.0
# 30     208.339884           0.0         2.420870             0.0
# 14     221.704448           0.0         2.542475             0.0
# 9      129.730499           0.0         1.659318             0.0
# 13     107.789361           0.0         1.288905             0.0
# 25     129.876535           0.0         1.648302             0.0
# 18     274.940249           0.0         3.725193             0.0
# 2      305.908114           0.0         4.324851             0.0
# 29     104.309074           0.0         1.221894             0.0
# 28      21.639052           0.0         0.322637             0.0
# 12      22.307140           0.0         0.338629             0.0
# 17     137.956816           0.0         1.902094             0.0
# 24      25.312078           0.0         0.462915             0.0
# 1      156.336602           0.0         3.007951             0.0
# 8       27.178325           0.0         0.375073             0.0
# 20      25.241618           0.0         0.403363             0.0
# 4       31.648943           0.0         0.401918             0.0
# 0       31.864335           0.0         0.693720             0.0
# 16      28.319552           0.0         0.430425             0.0
#
#    param_max_features param_min_samples_leaf param_n_estimators  \
# 23               sqrt                      5                200
# 7                auto                      5                200
# 27               sqrt                     10                200
# 19               sqrt                      1                200
# 11               auto                     10                200
# 15               auto                     50                200
# 3                auto                      1                200
# 10               auto                     10                100
# 26               sqrt                     10                100
# 22               sqrt                      5                100
# 6                auto                      5                100
# 31               sqrt                     50                200
# 5                auto                      5                 50
# 21               sqrt                      5                 50
# 30               sqrt                     50                100
# 14               auto                     50                100
# 9                auto                     10                 50
# 13               auto                     50                 50
# 25               sqrt                     10                 50
# 18               sqrt                      1                100
# 2                auto                      1                100
# 29               sqrt                     50                 50
# 28               sqrt                     50                 10
# 12               auto                     50                 10
# 17               sqrt                      1                 50
# 24               sqrt                     10                 10
# 1                auto                      1                 50
# 8                auto                     10                 10
# 20               sqrt                      5                 10
# 4                auto                      5                 10
# 0                auto                      1                 10
# 16               sqrt                      1                 10
#
#                                                params  split0_test_score  \
# 23  {'max_features': 'sqrt', 'min_samples_leaf': 5...           0.837524
# 7   {'max_features': 'auto', 'min_samples_leaf': 5...           0.835579
# 27  {'max_features': 'sqrt', 'min_samples_leaf': 1...           0.834294
# 19  {'max_features': 'sqrt', 'min_samples_leaf': 1...           0.833891
# 11  {'max_features': 'auto', 'min_samples_leaf': 1...           0.833660
# 15  {'max_features': 'auto', 'min_samples_leaf': 5...           0.831579
# 3   {'max_features': 'auto', 'min_samples_leaf': 1...           0.831247
# 10  {'max_features': 'auto', 'min_samples_leaf': 1...           0.831107
# 26  {'max_features': 'sqrt', 'min_samples_leaf': 1...           0.830045
# 22  {'max_features': 'sqrt', 'min_samples_leaf': 5...           0.829656
# 6   {'max_features': 'auto', 'min_samples_leaf': 5...           0.828034
# 31  {'max_features': 'sqrt', 'min_samples_leaf': 5...           0.827404
# 5   {'max_features': 'auto', 'min_samples_leaf': 5...           0.825590
# 21  {'max_features': 'sqrt', 'min_samples_leaf': 5...           0.825319
# 30  {'max_features': 'sqrt', 'min_samples_leaf': 5...           0.825118
# 14  {'max_features': 'auto', 'min_samples_leaf': 5...           0.823361
# 9   {'max_features': 'auto', 'min_samples_leaf': 1...           0.822421
# 13  {'max_features': 'auto', 'min_samples_leaf': 5...           0.820288
# 25  {'max_features': 'sqrt', 'min_samples_leaf': 1...           0.819523
# 18  {'max_features': 'sqrt', 'min_samples_leaf': 1...           0.812179
# 2   {'max_features': 'auto', 'min_samples_leaf': 1...           0.811690
# 29  {'max_features': 'sqrt', 'min_samples_leaf': 5...           0.802444
# 28  {'max_features': 'sqrt', 'min_samples_leaf': 5...           0.792797
# 12  {'max_features': 'auto', 'min_samples_leaf': 5...           0.789151
# 17  {'max_features': 'sqrt', 'min_samples_leaf': 1...           0.786140
# 24  {'max_features': 'sqrt', 'min_samples_leaf': 1...           0.780946
# 1   {'max_features': 'auto', 'min_samples_leaf': 1...           0.780426
# 8   {'max_features': 'auto', 'min_samples_leaf': 1...           0.772353
# 20  {'max_features': 'sqrt', 'min_samples_leaf': 5...           0.771535
# 4   {'max_features': 'auto', 'min_samples_leaf': 5...           0.766005
# 0   {'max_features': 'auto', 'min_samples_leaf': 1...           0.703820
# 16  {'max_features': 'sqrt', 'min_samples_leaf': 1...           0.670948
#
#     mean_test_score  std_test_score  rank_test_score
# 23         0.837524             0.0                1
# 7          0.835579             0.0                2
# 27         0.834294             0.0                3
# 19         0.833891             0.0                4
# 11         0.833660             0.0                5
# 15         0.831579             0.0                6
# 3          0.831247             0.0                7
# 10         0.831107             0.0                8
# 26         0.830045             0.0                9
# 22         0.829656             0.0               10
# 6          0.828034             0.0               11
# 31         0.827404             0.0               12
# 5          0.825590             0.0               13
# 21         0.825319             0.0               14
# 30         0.825118             0.0               15
# 14         0.823361             0.0               16
# 9          0.822421             0.0               17
# 13         0.820288             0.0               18
# 25         0.819523             0.0               19
# 18         0.812179             0.0               20
# 2          0.811690             0.0               21
# 29         0.802444             0.0               22
# 28         0.792797             0.0               23
# 12         0.789151             0.0               24
# 17         0.786140             0.0               25
# 24         0.780946             0.0               26
# 1          0.780426             0.0               27
# 8          0.772353             0.0               28
# 20         0.771535             0.0               29
# 4          0.766005             0.0               30
# 0          0.703820             0.0               31
# 16         0.670948             0.0               32

# %%
pd.DataFrame(search.cv_results_).to_csv(
    f'{BASE_DIR}/data/analysis/extra_trees/without_race_without_weather.csv', index=False
)

# %%
import pickle

rf = ExtraTreesClassifier(
    max_features='sqrt',
    min_samples_leaf=5,
    n_estimators=200,
).fit(X_train.to_numpy(), X_train_pairwise_winner_labels)

with open(f"{BASE_DIR}/data/analysis/extra_trees/without_race_without_weather.pkl",'wb') as f:
    pickle.dump(rf, f)

# %% [markdown]
# ---
