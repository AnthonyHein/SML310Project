# %% [markdown]
# # `logistic_regression_without_race_without_weather_pairwise_winners.ipynb`

# %% [markdown]
# ### Author: Anthony Hein

# %% [markdown]
# #### Last updated: 11/20/2021

# %% [markdown]
# # Overview:
#
# Use the datasets
# * `X_train_preprocess_without_race.csv`
# * `X_dev_preprocess_without_race.csv`
# * `X_test_preprocess_without_race.csv`
#
# and the targets in
# * `X_train_pairwise_winner_labels.csv`
# * `X_dev_pairwise_winner_labels.csv`
# * `X_test_pairwise_winner_labels.csv`
#
# to make a logistic regression model that tries to predict the pairwise winner between each pair of runners.

# %% [markdown]
# ---

# %% [markdown]
# ## Setup

# %%
from datetime import datetime
import git
import os
from typing import List
from tqdm import tqdm
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
BASE_DIR = git.Repo(os.getcwd(), search_parent_directories=True).working_dir
BASE_DIR
# Out:
# '/Users/anthonyhein/Desktop/SML310/project'

# %% [markdown]
# ---

# %% [markdown]
# ## Remove Features that Involve Weather

# %%
drop_cols = [
    'horse1_jockey_prev_1_position_temp',
    'horse1_jockey_prev_2_position_temp',
    'horse1_jockey_prev_3_position_temp',
    'horse1_jockey_prev_1_finishing_time_ratio_temp',
    'horse1_jockey_prev_2_finishing_time_ratio_temp',
    'horse1_jockey_prev_3_finishing_time_ratio_temp',
    'horse1_jockey_prev_1_position_msl',
    'horse1_jockey_prev_2_position_msl',
    'horse1_jockey_prev_3_position_msl',
    'horse1_jockey_prev_1_finishing_time_ratio_msl',
    'horse1_jockey_prev_2_finishing_time_ratio_msl',
    'horse1_jockey_prev_3_finishing_time_ratio_msl',
    'horse1_jockey_prev_1_position_rain',
    'horse1_jockey_prev_2_position_rain',
    'horse1_jockey_prev_3_position_rain',
    'horse1_jockey_prev_1_finishing_time_ratio_rain',
    'horse1_jockey_prev_2_finishing_time_ratio_rain',
    'horse1_jockey_prev_3_finishing_time_ratio_rain',
    'horse1_jockey_prev_1_position_rhum',
    'horse1_jockey_prev_2_position_rhum',
    'horse1_jockey_prev_3_position_rhum',
    'horse1_jockey_prev_1_finishing_time_ratio_rhum',
    'horse1_jockey_prev_2_finishing_time_ratio_rhum',
    'horse1_jockey_prev_3_finishing_time_ratio_rhum',
    'horse2_jockey_prev_1_position_temp',
    'horse2_jockey_prev_2_position_temp',
    'horse2_jockey_prev_3_position_temp',
    'horse2_jockey_prev_1_finishing_time_ratio_temp',
    'horse2_jockey_prev_2_finishing_time_ratio_temp',
    'horse2_jockey_prev_3_finishing_time_ratio_temp',
    'horse2_jockey_prev_1_position_msl',
    'horse2_jockey_prev_2_position_msl',
    'horse2_jockey_prev_3_position_msl',
    'horse2_jockey_prev_1_finishing_time_ratio_msl',
    'horse2_jockey_prev_2_finishing_time_ratio_msl',
    'horse2_jockey_prev_3_finishing_time_ratio_msl',
    'horse2_jockey_prev_1_position_rain',
    'horse2_jockey_prev_2_position_rain',
    'horse2_jockey_prev_3_position_rain',
    'horse2_jockey_prev_1_finishing_time_ratio_rain',
    'horse2_jockey_prev_2_finishing_time_ratio_rain',
    'horse2_jockey_prev_3_finishing_time_ratio_rain',
    'horse2_jockey_prev_1_position_rhum',
    'horse2_jockey_prev_2_position_rhum',
    'horse2_jockey_prev_3_position_rhum',
    'horse2_jockey_prev_1_finishing_time_ratio_rhum',
    'horse2_jockey_prev_2_finishing_time_ratio_rhum',
    'horse2_jockey_prev_3_finishing_time_ratio_rhum'
]

# %% [markdown]
# ---

# %% [markdown]
# ## Load `X_train_preprocess_without_race.csv`

# %%
X_train = pd.read_csv(f"{BASE_DIR}/data/analysis/X_train_preprocess_without_race.csv", low_memory=False)
X_train.head()
# Out:
#    horse1_age  horse1_saddle  horse1_decimalPrice  horse1_isFav  \
# 0    0.200000       0.230769             0.196970           0.0
# 1    0.400000       0.038462             0.072222           0.0
# 2    0.133333       0.423077             0.098485           0.0
# 3    0.133333       0.423077             0.098485           0.0
# 4    0.133333       0.192308             0.090278           0.0
#
#    horse1_outHandicap  horse1_RPR  horse1_weight  horse1_jockey_d_last_race  \
# 0                 0.0     0.73125       0.692308                   0.007631
# 1                 0.0     0.73125       0.743590                   0.005050
# 2                 0.0     0.65000       0.705128                   0.000740
# 3                 0.0     0.65000       0.705128                   0.000740
# 4                 0.0     0.66250       0.730769                   0.000740
#
#    horse1_jockey_d_first_race  horse1_jockey_prev_1_position  ...  \
# 0                    0.236544                          0.100  ...
# 1                    0.236544                          0.100  ...
# 2                    0.237283                          0.025  ...
# 3                    0.237283                          0.025  ...
# 4                    0.234655                          0.050  ...
#
#    horse2_jockey_prev_3_position_rain  \
# 0                               0.050
# 1                               0.100
# 2                               0.100
# 3                               0.075
# 4                               0.100
#
#    horse2_jockey_prev_1_finishing_time_ratio_rain  \
# 0                                        0.805104
# 1                                        0.801416
# 2                                        0.799909
# 3                                        0.800176
# 4                                        0.799642
#
#    horse2_jockey_prev_2_finishing_time_ratio_rain  \
# 0                                        0.780139
# 1                                        0.781238
# 2                                        0.780139
# 3                                        0.781623
# 4                                        0.783601
#
#    horse2_jockey_prev_3_finishing_time_ratio_rain  \
# 0                                        0.783438
# 1                                        0.794160
# 2                                        0.786816
# 3                                        0.781870
# 4                                        0.785468
#
#    horse2_jockey_prev_1_position_rhum  horse2_jockey_prev_2_position_rhum  \
# 0                               0.100                               0.025
# 1                               0.075                               0.050
# 2                               0.025                               0.100
# 3                               0.050                               0.075
# 4                               0.125                               0.100
#
#    horse2_jockey_prev_3_position_rhum  \
# 0                               0.025
# 1                               0.075
# 2                               0.025
# 3                               0.050
# 4                               0.025
#
#    horse2_jockey_prev_1_finishing_time_ratio_rhum  \
# 0                                        0.805104
# 1                                        0.801416
# 2                                        0.799642
# 3                                        0.801163
# 4                                        0.803191
#
#    horse2_jockey_prev_2_finishing_time_ratio_rhum  \
# 0                                        0.799642
# 1                                        0.800487
# 2                                        0.806486
# 3                                        0.801416
# 4                                        0.805104
#
#    horse2_jockey_prev_3_finishing_time_ratio_rhum
# 0                                        0.780139
# 1                                        0.785703
# 2                                        0.780139
# 3                                        0.780963
# 4                                        0.780139
#
# [5 rows x 144 columns]

# %%
X_train.shape
# Out:
# (800666, 144)

# %%
X_train = X_train.drop(columns=drop_cols)
X_train.shape
# Out:
# (800666, 96)

# %% [markdown]
# ---

# %% [markdown]
# ## Load `X_dev_preprocess_without_race.csv`

# %%
X_dev = pd.read_csv(f"{BASE_DIR}/data/analysis/X_dev_preprocess_without_race.csv", low_memory=False)
X_dev.head()
# Out:
#    horse1_age  horse1_saddle  horse1_decimalPrice  horse1_isFav  \
# 0    0.285714       0.105263             0.200000           0.0
# 1    0.285714       0.210526             0.157143           0.0
# 2    0.285714       0.210526             0.157143           0.0
# 3    0.285714       0.210526             0.157143           0.0
# 4    0.285714       0.210526             0.157143           0.0
#
#    horse1_outHandicap  horse1_RPR  horse1_weight  horse1_jockey_d_last_race  \
# 0                 0.0    0.608392       0.769231                   0.001516
# 1                 0.0    0.258741       0.769231                   0.000445
# 2                 0.0    0.258741       0.769231                   0.000445
# 3                 0.0    0.258741       0.769231                   0.000445
# 4                 0.0    0.258741       0.769231                   0.000445
#
#    horse1_jockey_d_first_race  horse1_jockey_prev_1_position  ...  \
# 0                    0.629407                          0.250  ...
# 1                    0.286087                          0.075  ...
# 2                    0.286087                          0.075  ...
# 3                    0.286087                          0.075  ...
# 4                    0.286087                          0.075  ...
#
#    horse2_jockey_prev_3_position_rain  \
# 0                               0.200
# 1                               0.075
# 2                               0.125
# 3                               0.050
# 4                               0.175
#
#    horse2_jockey_prev_1_finishing_time_ratio_rain  \
# 0                                        0.828972
# 1                                        0.826039
# 2                                        0.826413
# 3                                        0.832401
# 4                                        0.857255
#
#    horse2_jockey_prev_2_finishing_time_ratio_rain  \
# 0                                        0.837641
# 1                                        0.826039
# 2                                        0.841758
# 3                                        0.832114
# 4                                        0.835266
#
#    horse2_jockey_prev_3_finishing_time_ratio_rain  \
# 0                                        0.843255
# 1                                        0.842799
# 2                                        0.844367
# 3                                        0.828366
# 4                                        0.834946
#
#    horse2_jockey_prev_1_position_rhum  horse2_jockey_prev_2_position_rhum  \
# 0                               0.075                               0.050
# 1                               0.025                               0.025
# 2                               0.125                               0.050
# 3                               0.100                               0.075
# 4                               0.150                               0.025
#
#    horse2_jockey_prev_3_position_rhum  \
# 0                               0.275
# 1                               0.075
# 2                               0.275
# 3                               0.050
# 4                               0.200
#
#    horse2_jockey_prev_1_finishing_time_ratio_rhum  \
# 0                                        0.834583
# 1                                        0.826039
# 2                                        0.843955
# 3                                        0.832401
# 4                                        0.857255
#
#    horse2_jockey_prev_2_finishing_time_ratio_rhum  \
# 0                                        0.828972
# 1                                        0.826039
# 2                                        0.826413
# 3                                        0.837064
# 4                                        0.826039
#
#    horse2_jockey_prev_3_finishing_time_ratio_rhum
# 0                                        0.853796
# 1                                        0.842799
# 2                                        0.841758
# 3                                        0.828519
# 4                                        0.837392
#
# [5 rows x 144 columns]

# %%
X_dev.shape
# Out:
# (228766, 144)

# %%
X_dev = X_dev.drop(columns=drop_cols)
X_dev.shape
# Out:
# (228766, 96)

# %% [markdown]
# ---

# %% [markdown]
# ## Load `X_test_preprocess_without_race.csv`

# %%
X_test = pd.read_csv(f"{BASE_DIR}/data/analysis/X_test_preprocess_without_race.csv", low_memory=False)
X_test.head()
# Out:
#    horse1_age  horse1_saddle  horse1_decimalPrice  horse1_isFav  \
# 0    0.230769       0.333333              0.03268           0.0
# 1    0.230769       0.333333              0.03268           0.0
# 2    0.230769       0.333333              0.03268           0.0
# 3    0.230769       0.333333              0.03268           0.0
# 4    0.230769       0.333333              0.03268           0.0
#
#    horse1_outHandicap  horse1_RPR  horse1_weight  horse1_jockey_d_last_race  \
# 0                 0.0    0.344828        0.74359                   0.001053
# 1                 0.0    0.344828        0.74359                   0.001053
# 2                 0.0    0.344828        0.74359                   0.001053
# 3                 0.0    0.344828        0.74359                   0.001053
# 4                 0.0    0.344828        0.74359                   0.001053
#
#    horse1_jockey_d_first_race  horse1_jockey_prev_1_position  ...  \
# 0                     0.49501                          0.225  ...
# 1                     0.49501                          0.225  ...
# 2                     0.49501                          0.225  ...
# 3                     0.49501                          0.225  ...
# 4                     0.49501                          0.225  ...
#
#    horse2_jockey_prev_3_position_rain  \
# 0                               0.200
# 1                               0.150
# 2                               0.075
# 3                               0.250
# 4                               0.250
#
#    horse2_jockey_prev_1_finishing_time_ratio_rain  \
# 0                                        0.865544
# 1                                        0.864781
# 2                                        0.838534
# 3                                        0.851685
# 4                                        0.847892
#
#    horse2_jockey_prev_2_finishing_time_ratio_rain  \
# 0                                        0.847264
# 1                                        0.840533
# 2                                        0.843337
# 3                                        0.849673
# 4                                        0.842776
#
#    horse2_jockey_prev_3_finishing_time_ratio_rain  \
# 0                                        0.853154
# 1                                        0.855519
# 2                                        0.846422
# 3                                        0.854624
# 4                                        0.862423
#
#    horse2_jockey_prev_1_position_rhum  horse2_jockey_prev_2_position_rhum  \
# 0                               0.025                               0.200
# 1                               0.025                               0.025
# 2                               0.200                               0.100
# 3                               0.150                               0.250
# 4                               0.175                               0.075
#
#    horse2_jockey_prev_3_position_rhum  \
# 0                               0.300
# 1                               0.025
# 2                               0.125
# 3                               0.200
# 4                               0.275
#
#    horse2_jockey_prev_1_finishing_time_ratio_rhum  \
# 0                                        0.840533
# 1                                        0.840533
# 2                                        0.853412
# 3                                        0.849673
# 4                                        0.853634
#
#    horse2_jockey_prev_2_finishing_time_ratio_rhum  \
# 0                                        0.850856
# 1                                        0.840533
# 2                                        0.842583
# 3                                        0.854624
# 4                                        0.844529
#
#    horse2_jockey_prev_3_finishing_time_ratio_rhum
# 0                                        0.864844
# 1                                        0.840533
# 2                                        0.847859
# 3                                        0.858051
# 4                                        0.862845
#
# [5 rows x 144 columns]

# %%
X_test.shape
# Out:
# (114392, 144)

# %%
X_test = X_test.drop(columns=drop_cols)
X_test.shape
# Out:
# (114392, 96)

# %% [markdown]
# ---

# %% [markdown]
# ## Load Pairwise Winner Labels

# %%
X_train_pairwise_winner_labels = np.loadtxt(f"{BASE_DIR}/data/analysis/x_train_pairwise_winner_labels.csv",
                                            dtype=int,
                                            delimiter=',')

# %%
X_dev_pairwise_winner_labels = np.loadtxt(f"{BASE_DIR}/data/analysis/X_dev_pairwise_winner_labels.csv",
                                          dtype=int,
                                          delimiter=',')

# %%
X_test_pairwise_winner_labels = np.loadtxt(f"{BASE_DIR}/data/analysis/X_test_pairwise_winner_labels.csv",
                                           dtype=int,
                                           delimiter=',')

# %% [markdown]
# ---

# %% [markdown]
# ## Logistic Regression Model

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import PredefinedSplit, GridSearchCV

## Fixing Random Seed for Reproducibility
np.random.seed(0)

# %%
## Hyperparameter Space
space = {
    'solver': ['newton-cg', 'lbfgs', 'liblinear'],
    'penalty': ['none', 'l1', 'l2', 'elasticnet'],
    'C': [0.01, 0.1, 10, 100],
}

# %%
X_train_plus_dev = pd.concat([X_train, X_dev])
X_train_plus_dev.shape
# Out:
# (1029432, 96)

# %%
X_train_plus_dev_pairwise_winner_labels = np.concatenate(
    (X_train_pairwise_winner_labels, X_dev_pairwise_winner_labels)
)
X_train_plus_dev_pairwise_winner_labels
# Out:
# array([1, 0, 1, ..., 1, 1, 1])

# %%
len(X_train), len(X_dev)
# Out:
# (800666, 228766)

# %%
test_fold = np.concatenate(
    (np.full(len(X_train), -1),
     np.zeros(len(X_dev)))
)
test_fold
# Out:
# array([-1., -1., -1., ...,  0.,  0.,  0.])

# %%
## Predefined Split
ps = PredefinedSplit(test_fold)
ps
# Out:
# PredefinedSplit(test_fold=array([-1, -1, ...,  0,  0]))

# %%
lr = LogisticRegression(max_iter=1000)

# %%
lr = GridSearchCV(lr, space, verbose=25, refit=False, cv=ps)

# %%
search = lr.fit(X_train_plus_dev.to_numpy(), X_train_plus_dev_pairwise_winner_labels)
# Out:
# Fitting 1 folds for each of 48 candidates, totalling 48 fits
# [CV 1/1; 1/48] START C=0.01, penalty=none, solver=newton-cg.....................
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# [CV 1/1; 1/48] END C=0.01, penalty=none, solver=newton-cg;, score=0.943 total time= 1.4min
# [CV 1/1; 2/48] START C=0.01, penalty=none, solver=lbfgs.........................
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# [CV 1/1; 2/48] END C=0.01, penalty=none, solver=lbfgs;, score=0.943 total time=  58.5s
# [CV 1/1; 3/48] START C=0.01, penalty=none, solver=liblinear.....................
# [CV 1/1; 3/48] END C=0.01, penalty=none, solver=liblinear;, score=nan total time=   0.7s
# [CV 1/1; 4/48] START C=0.01, penalty=l1, solver=newton-cg.......................
# [CV 1/1; 4/48] END C=0.01, penalty=l1, solver=newton-cg;, score=nan total time=   0.5s
# [CV 1/1; 5/48] START C=0.01, penalty=l1, solver=lbfgs...........................
# [CV 1/1; 5/48] END C=0.01, penalty=l1, solver=lbfgs;, score=nan total time=   0.6s
# [CV 1/1; 6/48] START C=0.01, penalty=l1, solver=liblinear.......................
# [CV 1/1; 6/48] END C=0.01, penalty=l1, solver=liblinear;, score=0.942 total time= 7.8min
# [CV 1/1; 7/48] START C=0.01, penalty=l2, solver=newton-cg.......................
# [CV 1/1; 7/48] END C=0.01, penalty=l2, solver=newton-cg;, score=0.926 total time=  27.9s
# [CV 1/1; 8/48] START C=0.01, penalty=l2, solver=lbfgs...........................
# [CV 1/1; 8/48] END C=0.01, penalty=l2, solver=lbfgs;, score=0.926 total time=   6.3s
# [CV 1/1; 9/48] START C=0.01, penalty=l2, solver=liblinear.......................
# [CV 1/1; 9/48] END C=0.01, penalty=l2, solver=liblinear;, score=0.926 total time=  20.1s
# [CV 1/1; 10/48] START C=0.01, penalty=elasticnet, solver=newton-cg..............
# [CV 1/1; 10/48] END C=0.01, penalty=elasticnet, solver=newton-cg;, score=nan total time=   0.5s
# [CV 1/1; 11/48] START C=0.01, penalty=elasticnet, solver=lbfgs..................
# [CV 1/1; 11/48] END C=0.01, penalty=elasticnet, solver=lbfgs;, score=nan total time=   0.5s
# [CV 1/1; 12/48] START C=0.01, penalty=elasticnet, solver=liblinear..............
# [CV 1/1; 12/48] END C=0.01, penalty=elasticnet, solver=liblinear;, score=nan total time=   0.5s
# [CV 1/1; 13/48] START C=0.1, penalty=none, solver=newton-cg.....................
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# [CV 1/1; 13/48] END C=0.1, penalty=none, solver=newton-cg;, score=0.943 total time= 1.2min
# [CV 1/1; 14/48] START C=0.1, penalty=none, solver=lbfgs.........................
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# [CV 1/1; 14/48] END C=0.1, penalty=none, solver=lbfgs;, score=0.943 total time=  48.5s
# [CV 1/1; 15/48] START C=0.1, penalty=none, solver=liblinear.....................
# [CV 1/1; 15/48] END C=0.1, penalty=none, solver=liblinear;, score=nan total time=   0.5s
# [CV 1/1; 16/48] START C=0.1, penalty=l1, solver=newton-cg.......................
# [CV 1/1; 16/48] END C=0.1, penalty=l1, solver=newton-cg;, score=nan total time=   0.5s
# [CV 1/1; 17/48] START C=0.1, penalty=l1, solver=lbfgs...........................
# [CV 1/1; 17/48] END C=0.1, penalty=l1, solver=lbfgs;, score=nan total time=   0.5s
# [CV 1/1; 18/48] START C=0.1, penalty=l1, solver=liblinear.......................
# [CV 1/1; 18/48] END C=0.1, penalty=l1, solver=liblinear;, score=0.943 total time=27.9min
# [CV 1/1; 19/48] START C=0.1, penalty=l2, solver=newton-cg.......................
# [CV 1/1; 19/48] END C=0.1, penalty=l2, solver=newton-cg;, score=0.939 total time=  39.0s
# [CV 1/1; 20/48] START C=0.1, penalty=l2, solver=lbfgs...........................
# [CV 1/1; 20/48] END C=0.1, penalty=l2, solver=lbfgs;, score=0.939 total time=  14.6s
# [CV 1/1; 21/48] START C=0.1, penalty=l2, solver=liblinear.......................
# [CV 1/1; 21/48] END C=0.1, penalty=l2, solver=liblinear;, score=0.939 total time=  36.1s
# [CV 1/1; 22/48] START C=0.1, penalty=elasticnet, solver=newton-cg...............
# [CV 1/1; 22/48] END C=0.1, penalty=elasticnet, solver=newton-cg;, score=nan total time=   0.5s
# [CV 1/1; 23/48] START C=0.1, penalty=elasticnet, solver=lbfgs...................
# [CV 1/1; 23/48] END C=0.1, penalty=elasticnet, solver=lbfgs;, score=nan total time=   0.5s
# [CV 1/1; 24/48] START C=0.1, penalty=elasticnet, solver=liblinear...............
# [CV 1/1; 24/48] END C=0.1, penalty=elasticnet, solver=liblinear;, score=nan total time=   0.5s
# [CV 1/1; 25/48] START C=10, penalty=none, solver=newton-cg......................
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# [CV 1/1; 25/48] END C=10, penalty=none, solver=newton-cg;, score=0.943 total time= 1.1min
# [CV 1/1; 26/48] START C=10, penalty=none, solver=lbfgs..........................
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# [CV 1/1; 26/48] END C=10, penalty=none, solver=lbfgs;, score=0.943 total time=  53.0s
# [CV 1/1; 27/48] START C=10, penalty=none, solver=liblinear......................
# [CV 1/1; 27/48] END C=10, penalty=none, solver=liblinear;, score=nan total time=   0.5s
# [CV 1/1; 28/48] START C=10, penalty=l1, solver=newton-cg........................
# [CV 1/1; 28/48] END C=10, penalty=l1, solver=newton-cg;, score=nan total time=   0.5s
# [CV 1/1; 29/48] START C=10, penalty=l1, solver=lbfgs............................
# [CV 1/1; 29/48] END C=10, penalty=l1, solver=lbfgs;, score=nan total time=   0.5s
# [CV 1/1; 30/48] START C=10, penalty=l1, solver=liblinear........................
# [CV 1/1; 30/48] END C=10, penalty=l1, solver=liblinear;, score=0.943 total time=84.7min
# [CV 1/1; 31/48] START C=10, penalty=l2, solver=newton-cg........................
# [CV 1/1; 31/48] END C=10, penalty=l2, solver=newton-cg;, score=0.943 total time= 1.0min
# [CV 1/1; 32/48] START C=10, penalty=l2, solver=lbfgs............................
# [CV 1/1; 32/48] END C=10, penalty=l2, solver=lbfgs;, score=0.943 total time=  44.8s
# [CV 1/1; 33/48] START C=10, penalty=l2, solver=liblinear........................
# [CV 1/1; 33/48] END C=10, penalty=l2, solver=liblinear;, score=0.943 total time=  50.3s
# [CV 1/1; 34/48] START C=10, penalty=elasticnet, solver=newton-cg................
# [CV 1/1; 34/48] END C=10, penalty=elasticnet, solver=newton-cg;, score=nan total time=   0.5s
# [CV 1/1; 35/48] START C=10, penalty=elasticnet, solver=lbfgs....................
# [CV 1/1; 35/48] END C=10, penalty=elasticnet, solver=lbfgs;, score=nan total time=   0.5s
# [CV 1/1; 36/48] START C=10, penalty=elasticnet, solver=liblinear................
# [CV 1/1; 36/48] END C=10, penalty=elasticnet, solver=liblinear;, score=nan total time=   0.5s
# [CV 1/1; 37/48] START C=100, penalty=none, solver=newton-cg.....................
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# [CV 1/1; 37/48] END C=100, penalty=none, solver=newton-cg;, score=0.943 total time= 1.2min
# [CV 1/1; 38/48] START C=100, penalty=none, solver=lbfgs.........................
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# [CV 1/1; 38/48] END C=100, penalty=none, solver=lbfgs;, score=0.943 total time=  48.0s
# [CV 1/1; 39/48] START C=100, penalty=none, solver=liblinear.....................
# [CV 1/1; 39/48] END C=100, penalty=none, solver=liblinear;, score=nan total time=   0.5s
# [CV 1/1; 40/48] START C=100, penalty=l1, solver=newton-cg.......................
# [CV 1/1; 40/48] END C=100, penalty=l1, solver=newton-cg;, score=nan total time=   0.5s
# [CV 1/1; 41/48] START C=100, penalty=l1, solver=lbfgs...........................
# [CV 1/1; 41/48] END C=100, penalty=l1, solver=lbfgs;, score=nan total time=   0.5s
# [CV 1/1; 42/48] START C=100, penalty=l1, solver=liblinear.......................
# [CV 1/1; 42/48] END C=100, penalty=l1, solver=liblinear;, score=0.943 total time=88.2min
# [CV 1/1; 43/48] START C=100, penalty=l2, solver=newton-cg.......................
# [CV 1/1; 43/48] END C=100, penalty=l2, solver=newton-cg;, score=0.943 total time= 1.1min
# [CV 1/1; 44/48] START C=100, penalty=l2, solver=lbfgs...........................
# [CV 1/1; 44/48] END C=100, penalty=l2, solver=lbfgs;, score=0.943 total time=  47.6s
# [CV 1/1; 45/48] START C=100, penalty=l2, solver=liblinear.......................
# [CV 1/1; 45/48] END C=100, penalty=l2, solver=liblinear;, score=0.943 total time=  46.8s
# [CV 1/1; 46/48] START C=100, penalty=elasticnet, solver=newton-cg...............
# [CV 1/1; 46/48] END C=100, penalty=elasticnet, solver=newton-cg;, score=nan total time=   0.5s
# [CV 1/1; 47/48] START C=100, penalty=elasticnet, solver=lbfgs...................
# [CV 1/1; 47/48] END C=100, penalty=elasticnet, solver=lbfgs;, score=nan total time=   0.5s
# [CV 1/1; 48/48] START C=100, penalty=elasticnet, solver=liblinear...............
# [CV 1/1; 48/48] END C=100, penalty=elasticnet, solver=liblinear;, score=nan total time=   0.5s
# /usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:372: FitFailedWarning:
# 24 fits failed out of a total of 48.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 4 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 681, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py", line 1461, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py", line 464, in _check_solver
#     raise ValueError("penalty='none' is not supported for the liblinear solver")
# ValueError: penalty='none' is not supported for the liblinear solver
#
# --------------------------------------------------------------------------------
# 4 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 681, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py", line 1461, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py", line 447, in _check_solver
#     raise ValueError(
# ValueError: Solver newton-cg supports only 'l2' or 'none' penalties, got l1 penalty.
#
# --------------------------------------------------------------------------------
# 4 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 681, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py", line 1461, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py", line 447, in _check_solver
#     raise ValueError(
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got l1 penalty.
#
# --------------------------------------------------------------------------------
# 4 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 681, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py", line 1461, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py", line 447, in _check_solver
#     raise ValueError(
# ValueError: Solver newton-cg supports only 'l2' or 'none' penalties, got elasticnet penalty.
#
# --------------------------------------------------------------------------------
# 4 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 681, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py", line 1461, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py", line 447, in _check_solver
#     raise ValueError(
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got elasticnet penalty.
#
# --------------------------------------------------------------------------------
# 4 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 681, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py", line 1461, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "/usr/local/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py", line 457, in _check_solver
#     raise ValueError(
# ValueError: Only 'saga' solver supports elasticnet penalty, got solver=liblinear.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /usr/local/lib/python3.9/site-packages/sklearn/model_selection/_search.py:969: UserWarning: One or more of the test scores are non-finite: [0.94304661 0.94307283        nan        nan        nan 0.94223792
#  0.92644012 0.92640515 0.92638766        nan        nan        nan
#  0.94304661 0.94307283        nan        nan        nan 0.94298978
#  0.93945779 0.93948839 0.9394709         nan        nan        nan
#  0.94304661 0.94307283        nan        nan        nan 0.94302912
#  0.94301601 0.94296355 0.94298978        nan        nan        nan
#  0.94304661 0.94307283        nan        nan        nan 0.94301601
#  0.94302038 0.94301164 0.94304224        nan        nan        nan]
#   warnings.warn(

# %%
print(f"Best Score: {search.best_score_}")
print(f"Best Hyperparameters: {search.best_params_}")
# Out:
# Best Score: 0.9430728342498448
# Best Hyperparameters: {'C': 0.01, 'penalty': 'none', 'solver': 'lbfgs'}

# %%
pd.DataFrame(search.cv_results_).sort_values('rank_test_score')
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 1       58.446221           0.0         0.048647             0.0    0.01
# 25      52.934558           0.0         0.056634             0.0      10
# 37      47.968950           0.0         0.054066             0.0     100
# 13      48.460661           0.0         0.052436             0.0     0.1
# 0       86.506494           0.0         0.243583             0.0    0.01
# 24      65.907702           0.0         0.056217             0.0      10
# 36      71.469281           0.0         0.054061             0.0     100
# 12      69.134254           0.0         0.048242             0.0     0.1
# 44      46.755374           0.0         0.061386             0.0     100
# 29    5082.060630           0.0         0.510089             0.0      10
# 42      67.337535           0.0         0.042812             0.0     100
# 30      62.398143           0.0         0.052124             0.0      10
# 41    5294.587157           0.0         0.088970             0.0     100
# 43      47.536443           0.0         0.046785             0.0     100
# 32      50.240604           0.0         0.054253             0.0      10
# 17    1675.881658           0.0         0.585719             0.0     0.1
# 31      44.715513           0.0         0.053619             0.0      10
# 5      465.906200           0.0         0.215372             0.0    0.01
# 19      14.573293           0.0         0.060740             0.0     0.1
# 20      35.994846           0.0         0.062566             0.0     0.1
# 18      38.935651           0.0         0.058515             0.0     0.1
# 6       27.829515           0.0         0.050100             0.0    0.01
# 7        6.225788           0.0         0.053035             0.0    0.01
# 8       20.030364           0.0         0.053719             0.0    0.01
# 40       0.487745           0.0         0.000000             0.0     100
# 35       0.485177           0.0         0.000000             0.0      10
# 34       0.486990           0.0         0.000000             0.0      10
# 45       0.460606           0.0         0.000000             0.0     100
# 33       0.507340           0.0         0.000000             0.0      10
# 39       0.482222           0.0         0.000000             0.0     100
# 38       0.468487           0.0         0.000000             0.0     100
# 23       0.474724           0.0         0.000000             0.0     0.1
# 27       0.539136           0.0         0.000000             0.0      10
# 26       0.524364           0.0         0.000000             0.0      10
# 46       0.482427           0.0         0.000000             0.0     100
# 22       0.490452           0.0         0.000000             0.0     0.1
# 21       0.452970           0.0         0.000000             0.0     0.1
# 16       0.521505           0.0         0.000000             0.0     0.1
# 15       0.523408           0.0         0.000000             0.0     0.1
# 14       0.468916           0.0         0.000000             0.0     0.1
# 11       0.487156           0.0         0.000000             0.0    0.01
# 10       0.483560           0.0         0.000000             0.0    0.01
# 9        0.461971           0.0         0.000000             0.0    0.01
# 4        0.560436           0.0         0.000000             0.0    0.01
# 3        0.533943           0.0         0.000000             0.0    0.01
# 2        0.673913           0.0         0.000000             0.0    0.01
# 28       0.523636           0.0         0.000000             0.0      10
# 47       0.493099           0.0         0.000000             0.0     100
#
#    param_penalty param_solver  \
# 1           none        lbfgs
# 25          none        lbfgs
# 37          none        lbfgs
# 13          none        lbfgs
# 0           none    newton-cg
# 24          none    newton-cg
# 36          none    newton-cg
# 12          none    newton-cg
# 44            l2    liblinear
# 29            l1    liblinear
# 42            l2    newton-cg
# 30            l2    newton-cg
# 41            l1    liblinear
# 43            l2        lbfgs
# 32            l2    liblinear
# 17            l1    liblinear
# 31            l2        lbfgs
# 5             l1    liblinear
# 19            l2        lbfgs
# 20            l2    liblinear
# 18            l2    newton-cg
# 6             l2    newton-cg
# 7             l2        lbfgs
# 8             l2    liblinear
# 40            l1        lbfgs
# 35    elasticnet    liblinear
# 34    elasticnet        lbfgs
# 45    elasticnet    newton-cg
# 33    elasticnet    newton-cg
# 39            l1    newton-cg
# 38          none    liblinear
# 23    elasticnet    liblinear
# 27            l1    newton-cg
# 26          none    liblinear
# 46    elasticnet        lbfgs
# 22    elasticnet        lbfgs
# 21    elasticnet    newton-cg
# 16            l1        lbfgs
# 15            l1    newton-cg
# 14          none    liblinear
# 11    elasticnet    liblinear
# 10    elasticnet        lbfgs
# 9     elasticnet    newton-cg
# 4             l1        lbfgs
# 3             l1    newton-cg
# 2           none    liblinear
# 28            l1        lbfgs
# 47    elasticnet    liblinear
#
#                                                params  split0_test_score  \
# 1   {'C': 0.01, 'penalty': 'none', 'solver': 'lbfgs'}           0.943073
# 25    {'C': 10, 'penalty': 'none', 'solver': 'lbfgs'}           0.943073
# 37   {'C': 100, 'penalty': 'none', 'solver': 'lbfgs'}           0.943073
# 13   {'C': 0.1, 'penalty': 'none', 'solver': 'lbfgs'}           0.943073
# 0   {'C': 0.01, 'penalty': 'none', 'solver': 'newt...           0.943047
# 24  {'C': 10, 'penalty': 'none', 'solver': 'newton...           0.943047
# 36  {'C': 100, 'penalty': 'none', 'solver': 'newto...           0.943047
# 12  {'C': 0.1, 'penalty': 'none', 'solver': 'newto...           0.943047
# 44  {'C': 100, 'penalty': 'l2', 'solver': 'libline...           0.943042
# 29  {'C': 10, 'penalty': 'l1', 'solver': 'liblinear'}           0.943029
# 42  {'C': 100, 'penalty': 'l2', 'solver': 'newton-...           0.943020
# 30  {'C': 10, 'penalty': 'l2', 'solver': 'newton-cg'}           0.943016
# 41  {'C': 100, 'penalty': 'l1', 'solver': 'libline...           0.943016
# 43     {'C': 100, 'penalty': 'l2', 'solver': 'lbfgs'}           0.943012
# 32  {'C': 10, 'penalty': 'l2', 'solver': 'liblinear'}           0.942990
# 17  {'C': 0.1, 'penalty': 'l1', 'solver': 'libline...           0.942990
# 31      {'C': 10, 'penalty': 'l2', 'solver': 'lbfgs'}           0.942964
# 5   {'C': 0.01, 'penalty': 'l1', 'solver': 'liblin...           0.942238
# 19     {'C': 0.1, 'penalty': 'l2', 'solver': 'lbfgs'}           0.939488
# 20  {'C': 0.1, 'penalty': 'l2', 'solver': 'libline...           0.939471
# 18  {'C': 0.1, 'penalty': 'l2', 'solver': 'newton-...           0.939458
# 6   {'C': 0.01, 'penalty': 'l2', 'solver': 'newton...           0.926440
# 7     {'C': 0.01, 'penalty': 'l2', 'solver': 'lbfgs'}           0.926405
# 8   {'C': 0.01, 'penalty': 'l2', 'solver': 'liblin...           0.926388
# 40     {'C': 100, 'penalty': 'l1', 'solver': 'lbfgs'}                NaN
# 35  {'C': 10, 'penalty': 'elasticnet', 'solver': '...                NaN
# 34  {'C': 10, 'penalty': 'elasticnet', 'solver': '...                NaN
# 45  {'C': 100, 'penalty': 'elasticnet', 'solver': ...                NaN
# 33  {'C': 10, 'penalty': 'elasticnet', 'solver': '...                NaN
# 39  {'C': 100, 'penalty': 'l1', 'solver': 'newton-...                NaN
# 38  {'C': 100, 'penalty': 'none', 'solver': 'libli...                NaN
# 23  {'C': 0.1, 'penalty': 'elasticnet', 'solver': ...                NaN
# 27  {'C': 10, 'penalty': 'l1', 'solver': 'newton-cg'}                NaN
# 26  {'C': 10, 'penalty': 'none', 'solver': 'liblin...                NaN
# 46  {'C': 100, 'penalty': 'elasticnet', 'solver': ...                NaN
# 22  {'C': 0.1, 'penalty': 'elasticnet', 'solver': ...                NaN
# 21  {'C': 0.1, 'penalty': 'elasticnet', 'solver': ...                NaN
# 16     {'C': 0.1, 'penalty': 'l1', 'solver': 'lbfgs'}                NaN
# 15  {'C': 0.1, 'penalty': 'l1', 'solver': 'newton-...                NaN
# 14  {'C': 0.1, 'penalty': 'none', 'solver': 'libli...                NaN
# 11  {'C': 0.01, 'penalty': 'elasticnet', 'solver':...                NaN
# 10  {'C': 0.01, 'penalty': 'elasticnet', 'solver':...                NaN
# 9   {'C': 0.01, 'penalty': 'elasticnet', 'solver':...                NaN
# 4     {'C': 0.01, 'penalty': 'l1', 'solver': 'lbfgs'}                NaN
# 3   {'C': 0.01, 'penalty': 'l1', 'solver': 'newton...                NaN
# 2   {'C': 0.01, 'penalty': 'none', 'solver': 'libl...                NaN
# 28      {'C': 10, 'penalty': 'l1', 'solver': 'lbfgs'}                NaN
# 47  {'C': 100, 'penalty': 'elasticnet', 'solver': ...                NaN
#
#     mean_test_score  std_test_score  rank_test_score
# 1          0.943073             0.0                1
# 25         0.943073             0.0                1
# 37         0.943073             0.0                1
# 13         0.943073             0.0                1
# 0          0.943047             0.0                5
# 24         0.943047             0.0                5
# 36         0.943047             0.0                5
# 12         0.943047             0.0                5
# 44         0.943042             0.0                9
# 29         0.943029             0.0               10
# 42         0.943020             0.0               11
# 30         0.943016             0.0               12
# 41         0.943016             0.0               12
# 43         0.943012             0.0               14
# 32         0.942990             0.0               15
# 17         0.942990             0.0               15
# 31         0.942964             0.0               17
# 5          0.942238             0.0               18
# 19         0.939488             0.0               19
# 20         0.939471             0.0               20
# 18         0.939458             0.0               21
# 6          0.926440             0.0               22
# 7          0.926405             0.0               23
# 8          0.926388             0.0               24
# 40              NaN             NaN               25
# 35              NaN             NaN               26
# 34              NaN             NaN               27
# 45              NaN             NaN               28
# 33              NaN             NaN               29
# 39              NaN             NaN               30
# 38              NaN             NaN               31
# 23              NaN             NaN               32
# 27              NaN             NaN               33
# 26              NaN             NaN               34
# 46              NaN             NaN               35
# 22              NaN             NaN               36
# 21              NaN             NaN               37
# 16              NaN             NaN               38
# 15              NaN             NaN               39
# 14              NaN             NaN               40
# 11              NaN             NaN               41
# 10              NaN             NaN               42
# 9               NaN             NaN               43
# 4               NaN             NaN               44
# 3               NaN             NaN               45
# 2               NaN             NaN               46
# 28              NaN             NaN               47
# 47              NaN             NaN               48

# %%
pd.DataFrame(search.cv_results_).to_csv(
    f"{BASE_DIR}/data/analysis/logistic_regression/without_race_without_weather.csv", index=False
)

# %%
import pickle

lr = LogisticRegression(
    max_iter=1000,
    C=100,
    penalty='none',
    solver='lbfgs',
).fit(X_train.to_numpy(), X_train_pairwise_winner_labels)

with open(f"{BASE_DIR}/data/analysis/logistic_regression/without_race_without_weather.pkl",'wb') as f:
    pickle.dump(lr, f)
# Out:
# /usr/local/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(

# %% [markdown]
# ---
