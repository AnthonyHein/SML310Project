# %% [markdown]
# # `decision_tree_without_race_pairwise_winners.ipynb`

# %% [markdown]
# ### Author: Anthony Hein

# %% [markdown]
# #### Last updated: 11/20/2021

# %% [markdown]
# # Overview:
#
# Use the datasets
# * `X_train_preprocess_without_race.csv`
# * `X_dev_preprocess_without_race.csv`
# * `X_test_preprocess_without_race.csv`
#
# and the targets in
# * `X_train_pairwise_winner_labels.csv`
# * `X_dev_pairwise_winner_labels.csv`
# * `X_test_pairwise_winner_labels.csv`
#
# to make a decision tree that tries to predict the pairwise winner between each pair of runners.

# %% [markdown]
# ---

# %% [markdown]
# ## Setup

# %%
from datetime import datetime
import git
import os
from typing import List
from tqdm import tqdm
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
BASE_DIR = git.Repo(os.getcwd(), search_parent_directories=True).working_dir
BASE_DIR
# Out:
# '/Users/anthonyhein/Desktop/SML310/project'

# %% [markdown]
# ---

# %% [markdown]
# ## Load `X_train_preprocess_without_race.csv`

# %%
X_train = pd.read_csv(f"{BASE_DIR}/data/analysis/X_train_preprocess_without_race.csv", low_memory=False)
X_train.head()
# Out:
#    horse1_age  horse1_saddle  horse1_decimalPrice  horse1_isFav  \
# 0    0.200000       0.230769             0.196970           0.0
# 1    0.400000       0.038462             0.072222           0.0
# 2    0.133333       0.423077             0.098485           0.0
# 3    0.133333       0.423077             0.098485           0.0
# 4    0.133333       0.192308             0.090278           0.0
#
#    horse1_outHandicap  horse1_RPR  horse1_weight  horse1_jockey_d_last_race  \
# 0                 0.0     0.73125       0.692308                   0.007631
# 1                 0.0     0.73125       0.743590                   0.005050
# 2                 0.0     0.65000       0.705128                   0.000740
# 3                 0.0     0.65000       0.705128                   0.000740
# 4                 0.0     0.66250       0.730769                   0.000740
#
#    horse1_jockey_d_first_race  horse1_jockey_prev_1_position  ...  \
# 0                    0.236544                          0.100  ...
# 1                    0.236544                          0.100  ...
# 2                    0.237283                          0.025  ...
# 3                    0.237283                          0.025  ...
# 4                    0.234655                          0.050  ...
#
#    horse2_jockey_prev_3_position_rain  \
# 0                               0.050
# 1                               0.100
# 2                               0.100
# 3                               0.075
# 4                               0.100
#
#    horse2_jockey_prev_1_finishing_time_ratio_rain  \
# 0                                        0.805104
# 1                                        0.801416
# 2                                        0.799909
# 3                                        0.800176
# 4                                        0.799642
#
#    horse2_jockey_prev_2_finishing_time_ratio_rain  \
# 0                                        0.780139
# 1                                        0.781238
# 2                                        0.780139
# 3                                        0.781623
# 4                                        0.783601
#
#    horse2_jockey_prev_3_finishing_time_ratio_rain  \
# 0                                        0.783438
# 1                                        0.794160
# 2                                        0.786816
# 3                                        0.781870
# 4                                        0.785468
#
#    horse2_jockey_prev_1_position_rhum  horse2_jockey_prev_2_position_rhum  \
# 0                               0.100                               0.025
# 1                               0.075                               0.050
# 2                               0.025                               0.100
# 3                               0.050                               0.075
# 4                               0.125                               0.100
#
#    horse2_jockey_prev_3_position_rhum  \
# 0                               0.025
# 1                               0.075
# 2                               0.025
# 3                               0.050
# 4                               0.025
#
#    horse2_jockey_prev_1_finishing_time_ratio_rhum  \
# 0                                        0.805104
# 1                                        0.801416
# 2                                        0.799642
# 3                                        0.801163
# 4                                        0.803191
#
#    horse2_jockey_prev_2_finishing_time_ratio_rhum  \
# 0                                        0.799642
# 1                                        0.800487
# 2                                        0.806486
# 3                                        0.801416
# 4                                        0.805104
#
#    horse2_jockey_prev_3_finishing_time_ratio_rhum
# 0                                        0.780139
# 1                                        0.785703
# 2                                        0.780139
# 3                                        0.780963
# 4                                        0.780139
#
# [5 rows x 144 columns]

# %%
X_train.shape
# Out:
# (800666, 144)

# %% [markdown]
# ---

# %% [markdown]
# ## Load `X_dev_preprocess_without_race.csv`

# %%
X_dev = pd.read_csv(f"{BASE_DIR}/data/analysis/X_dev_preprocess_without_race.csv", low_memory=False)
X_dev.head()
# Out:
#    horse1_age  horse1_saddle  horse1_decimalPrice  horse1_isFav  \
# 0    0.285714       0.105263             0.200000           0.0
# 1    0.285714       0.210526             0.157143           0.0
# 2    0.285714       0.210526             0.157143           0.0
# 3    0.285714       0.210526             0.157143           0.0
# 4    0.285714       0.210526             0.157143           0.0
#
#    horse1_outHandicap  horse1_RPR  horse1_weight  horse1_jockey_d_last_race  \
# 0                 0.0    0.608392       0.769231                   0.001516
# 1                 0.0    0.258741       0.769231                   0.000445
# 2                 0.0    0.258741       0.769231                   0.000445
# 3                 0.0    0.258741       0.769231                   0.000445
# 4                 0.0    0.258741       0.769231                   0.000445
#
#    horse1_jockey_d_first_race  horse1_jockey_prev_1_position  ...  \
# 0                    0.629407                          0.250  ...
# 1                    0.286087                          0.075  ...
# 2                    0.286087                          0.075  ...
# 3                    0.286087                          0.075  ...
# 4                    0.286087                          0.075  ...
#
#    horse2_jockey_prev_3_position_rain  \
# 0                               0.200
# 1                               0.075
# 2                               0.125
# 3                               0.050
# 4                               0.175
#
#    horse2_jockey_prev_1_finishing_time_ratio_rain  \
# 0                                        0.828972
# 1                                        0.826039
# 2                                        0.826413
# 3                                        0.832401
# 4                                        0.857255
#
#    horse2_jockey_prev_2_finishing_time_ratio_rain  \
# 0                                        0.837641
# 1                                        0.826039
# 2                                        0.841758
# 3                                        0.832114
# 4                                        0.835266
#
#    horse2_jockey_prev_3_finishing_time_ratio_rain  \
# 0                                        0.843255
# 1                                        0.842799
# 2                                        0.844367
# 3                                        0.828366
# 4                                        0.834946
#
#    horse2_jockey_prev_1_position_rhum  horse2_jockey_prev_2_position_rhum  \
# 0                               0.075                               0.050
# 1                               0.025                               0.025
# 2                               0.125                               0.050
# 3                               0.100                               0.075
# 4                               0.150                               0.025
#
#    horse2_jockey_prev_3_position_rhum  \
# 0                               0.275
# 1                               0.075
# 2                               0.275
# 3                               0.050
# 4                               0.200
#
#    horse2_jockey_prev_1_finishing_time_ratio_rhum  \
# 0                                        0.834583
# 1                                        0.826039
# 2                                        0.843955
# 3                                        0.832401
# 4                                        0.857255
#
#    horse2_jockey_prev_2_finishing_time_ratio_rhum  \
# 0                                        0.828972
# 1                                        0.826039
# 2                                        0.826413
# 3                                        0.837064
# 4                                        0.826039
#
#    horse2_jockey_prev_3_finishing_time_ratio_rhum
# 0                                        0.853796
# 1                                        0.842799
# 2                                        0.841758
# 3                                        0.828519
# 4                                        0.837392
#
# [5 rows x 144 columns]

# %%
X_dev.shape
# Out:
# (228766, 144)

# %% [markdown]
# ---

# %% [markdown]
# ## Load `X_test_preprocess_without_race.csv`

# %%
X_test = pd.read_csv(f"{BASE_DIR}/data/analysis/X_test_preprocess_without_race.csv", low_memory=False)
X_test.head()
# Out:
#    horse1_age  horse1_saddle  horse1_decimalPrice  horse1_isFav  \
# 0    0.230769       0.333333              0.03268           0.0
# 1    0.230769       0.333333              0.03268           0.0
# 2    0.230769       0.333333              0.03268           0.0
# 3    0.230769       0.333333              0.03268           0.0
# 4    0.230769       0.333333              0.03268           0.0
#
#    horse1_outHandicap  horse1_RPR  horse1_weight  horse1_jockey_d_last_race  \
# 0                 0.0    0.344828        0.74359                   0.001053
# 1                 0.0    0.344828        0.74359                   0.001053
# 2                 0.0    0.344828        0.74359                   0.001053
# 3                 0.0    0.344828        0.74359                   0.001053
# 4                 0.0    0.344828        0.74359                   0.001053
#
#    horse1_jockey_d_first_race  horse1_jockey_prev_1_position  ...  \
# 0                     0.49501                          0.225  ...
# 1                     0.49501                          0.225  ...
# 2                     0.49501                          0.225  ...
# 3                     0.49501                          0.225  ...
# 4                     0.49501                          0.225  ...
#
#    horse2_jockey_prev_3_position_rain  \
# 0                               0.200
# 1                               0.150
# 2                               0.075
# 3                               0.250
# 4                               0.250
#
#    horse2_jockey_prev_1_finishing_time_ratio_rain  \
# 0                                        0.865544
# 1                                        0.864781
# 2                                        0.838534
# 3                                        0.851685
# 4                                        0.847892
#
#    horse2_jockey_prev_2_finishing_time_ratio_rain  \
# 0                                        0.847264
# 1                                        0.840533
# 2                                        0.843337
# 3                                        0.849673
# 4                                        0.842776
#
#    horse2_jockey_prev_3_finishing_time_ratio_rain  \
# 0                                        0.853154
# 1                                        0.855519
# 2                                        0.846422
# 3                                        0.854624
# 4                                        0.862423
#
#    horse2_jockey_prev_1_position_rhum  horse2_jockey_prev_2_position_rhum  \
# 0                               0.025                               0.200
# 1                               0.025                               0.025
# 2                               0.200                               0.100
# 3                               0.150                               0.250
# 4                               0.175                               0.075
#
#    horse2_jockey_prev_3_position_rhum  \
# 0                               0.300
# 1                               0.025
# 2                               0.125
# 3                               0.200
# 4                               0.275
#
#    horse2_jockey_prev_1_finishing_time_ratio_rhum  \
# 0                                        0.840533
# 1                                        0.840533
# 2                                        0.853412
# 3                                        0.849673
# 4                                        0.853634
#
#    horse2_jockey_prev_2_finishing_time_ratio_rhum  \
# 0                                        0.850856
# 1                                        0.840533
# 2                                        0.842583
# 3                                        0.854624
# 4                                        0.844529
#
#    horse2_jockey_prev_3_finishing_time_ratio_rhum
# 0                                        0.864844
# 1                                        0.840533
# 2                                        0.847859
# 3                                        0.858051
# 4                                        0.862845
#
# [5 rows x 144 columns]

# %%
X_test.shape
# Out:
# (114392, 144)

# %% [markdown]
# ---

# %% [markdown]
# ## Load Pairwise Winner Labels

# %%
X_train_pairwise_winner_labels = np.loadtxt(f"{BASE_DIR}/data/analysis/x_train_pairwise_winner_labels.csv",
                                            dtype=int,
                                            delimiter=',')

# %%
X_dev_pairwise_winner_labels = np.loadtxt(f"{BASE_DIR}/data/analysis/X_dev_pairwise_winner_labels.csv",
                                          dtype=int,
                                          delimiter=',')

# %%
X_test_pairwise_winner_labels = np.loadtxt(f"{BASE_DIR}/data/analysis/X_test_pairwise_winner_labels.csv",
                                           dtype=int,
                                           delimiter=',')

# %% [markdown]
# ---

# %% [markdown]
# ## Decision Tree Classifier Model

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import PredefinedSplit, GridSearchCV

## Fixing Random Seed for Reproducibility
np.random.seed(0)

# %%
## Hyperparameter Space

space = {
    'criterion': ['gini', 'entropy'],
    'splitter': ['best', 'random'],
    'max_depth': [5, 10, 20],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 4, 8],
}

# %%
X_train_plus_dev = pd.concat([X_train, X_dev])
X_train_plus_dev.shape
# Out:
# (1029432, 144)

# %%
X_train_plus_dev_pairwise_winner_labels = np.concatenate(
    (X_train_pairwise_winner_labels, X_dev_pairwise_winner_labels)
)
X_train_plus_dev_pairwise_winner_labels
# Out:
# array([1, 0, 1, ..., 1, 1, 1])

# %%
len(X_train), len(X_dev)
# Out:
# (800666, 228766)

# %%
test_fold = np.concatenate(
    (np.full(len(X_train), -1),
     np.zeros(len(X_dev)))
)
test_fold
# Out:
# array([-1., -1., -1., ...,  0.,  0.,  0.])

# %%
## Predefined Split
ps = PredefinedSplit(test_fold)
ps
# Out:
# PredefinedSplit(test_fold=array([-1, -1, ...,  0,  0]))

# %%
dt = DecisionTreeClassifier()

# %%
dt = GridSearchCV(dt, space, verbose=25, refit=False, cv=ps)

# %%
search = dt.fit(X_train_plus_dev.to_numpy(), X_train_plus_dev_pairwise_winner_labels)
# Out:
# Fitting 1 folds for each of 108 candidates, totalling 108 fits
# [CV 1/1; 1/108] START criterion=gini, max_depth=5, min_samples_leaf=1, min_samples_split=2, splitter=best
# [CV 1/1; 1/108] END criterion=gini, max_depth=5, min_samples_leaf=1, min_samples_split=2, splitter=best;, score=0.841 total time= 1.2min
# [CV 1/1; 2/108] START criterion=gini, max_depth=5, min_samples_leaf=1, min_samples_split=2, splitter=random
# [CV 1/1; 2/108] END criterion=gini, max_depth=5, min_samples_leaf=1, min_samples_split=2, splitter=random;, score=0.786 total time=  13.2s
# [CV 1/1; 3/108] START criterion=gini, max_depth=5, min_samples_leaf=1, min_samples_split=5, splitter=best
# [CV 1/1; 3/108] END criterion=gini, max_depth=5, min_samples_leaf=1, min_samples_split=5, splitter=best;, score=0.841 total time=  44.2s
# [CV 1/1; 4/108] START criterion=gini, max_depth=5, min_samples_leaf=1, min_samples_split=5, splitter=random
# [CV 1/1; 4/108] END criterion=gini, max_depth=5, min_samples_leaf=1, min_samples_split=5, splitter=random;, score=0.781 total time=  13.4s
# [CV 1/1; 5/108] START criterion=gini, max_depth=5, min_samples_leaf=1, min_samples_split=10, splitter=best
# [CV 1/1; 5/108] END criterion=gini, max_depth=5, min_samples_leaf=1, min_samples_split=10, splitter=best;, score=0.841 total time=  42.2s
# [CV 1/1; 6/108] START criterion=gini, max_depth=5, min_samples_leaf=1, min_samples_split=10, splitter=random
# [CV 1/1; 6/108] END criterion=gini, max_depth=5, min_samples_leaf=1, min_samples_split=10, splitter=random;, score=0.768 total time=  13.7s
# [CV 1/1; 7/108] START criterion=gini, max_depth=5, min_samples_leaf=4, min_samples_split=2, splitter=best
# [CV 1/1; 7/108] END criterion=gini, max_depth=5, min_samples_leaf=4, min_samples_split=2, splitter=best;, score=0.841 total time=  41.5s
# [CV 1/1; 8/108] START criterion=gini, max_depth=5, min_samples_leaf=4, min_samples_split=2, splitter=random
# [CV 1/1; 8/108] END criterion=gini, max_depth=5, min_samples_leaf=4, min_samples_split=2, splitter=random;, score=0.752 total time=  12.8s
# [CV 1/1; 9/108] START criterion=gini, max_depth=5, min_samples_leaf=4, min_samples_split=5, splitter=best
# [CV 1/1; 9/108] END criterion=gini, max_depth=5, min_samples_leaf=4, min_samples_split=5, splitter=best;, score=0.841 total time=  39.6s
# [CV 1/1; 10/108] START criterion=gini, max_depth=5, min_samples_leaf=4, min_samples_split=5, splitter=random
# [CV 1/1; 10/108] END criterion=gini, max_depth=5, min_samples_leaf=4, min_samples_split=5, splitter=random;, score=0.766 total time=  12.2s
# [CV 1/1; 11/108] START criterion=gini, max_depth=5, min_samples_leaf=4, min_samples_split=10, splitter=best
# [CV 1/1; 11/108] END criterion=gini, max_depth=5, min_samples_leaf=4, min_samples_split=10, splitter=best;, score=0.841 total time=  36.8s
# [CV 1/1; 12/108] START criterion=gini, max_depth=5, min_samples_leaf=4, min_samples_split=10, splitter=random
# [CV 1/1; 12/108] END criterion=gini, max_depth=5, min_samples_leaf=4, min_samples_split=10, splitter=random;, score=0.740 total time=  12.1s
# [CV 1/1; 13/108] START criterion=gini, max_depth=5, min_samples_leaf=8, min_samples_split=2, splitter=best
# [CV 1/1; 13/108] END criterion=gini, max_depth=5, min_samples_leaf=8, min_samples_split=2, splitter=best;, score=0.841 total time=  36.4s
# [CV 1/1; 14/108] START criterion=gini, max_depth=5, min_samples_leaf=8, min_samples_split=2, splitter=random
# [CV 1/1; 14/108] END criterion=gini, max_depth=5, min_samples_leaf=8, min_samples_split=2, splitter=random;, score=0.772 total time=  11.9s
# [CV 1/1; 15/108] START criterion=gini, max_depth=5, min_samples_leaf=8, min_samples_split=5, splitter=best
# [CV 1/1; 15/108] END criterion=gini, max_depth=5, min_samples_leaf=8, min_samples_split=5, splitter=best;, score=0.841 total time=  36.6s
# [CV 1/1; 16/108] START criterion=gini, max_depth=5, min_samples_leaf=8, min_samples_split=5, splitter=random
# [CV 1/1; 16/108] END criterion=gini, max_depth=5, min_samples_leaf=8, min_samples_split=5, splitter=random;, score=0.737 total time=  11.8s
# [CV 1/1; 17/108] START criterion=gini, max_depth=5, min_samples_leaf=8, min_samples_split=10, splitter=best
# [CV 1/1; 17/108] END criterion=gini, max_depth=5, min_samples_leaf=8, min_samples_split=10, splitter=best;, score=0.841 total time=  36.6s
# [CV 1/1; 18/108] START criterion=gini, max_depth=5, min_samples_leaf=8, min_samples_split=10, splitter=random
# [CV 1/1; 18/108] END criterion=gini, max_depth=5, min_samples_leaf=8, min_samples_split=10, splitter=random;, score=0.736 total time=  11.9s
# [CV 1/1; 19/108] START criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=2, splitter=best
# [CV 1/1; 19/108] END criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=2, splitter=best;, score=0.904 total time= 8.1min
# [CV 1/1; 20/108] START criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=2, splitter=random
# [CV 1/1; 20/108] END criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=2, splitter=random;, score=0.868 total time=  36.2s
# [CV 1/1; 21/108] START criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=5, splitter=best
# [CV 1/1; 21/108] END criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=5, splitter=best;, score=0.904 total time= 1.6min
# [CV 1/1; 22/108] START criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=5, splitter=random
# [CV 1/1; 22/108] END criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=5, splitter=random;, score=0.807 total time=  57.1s
# [CV 1/1; 23/108] START criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=10, splitter=best
# [CV 1/1; 23/108] END criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=10, splitter=best;, score=0.904 total time= 1.8min
# [CV 1/1; 24/108] START criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=10, splitter=random
# [CV 1/1; 24/108] END criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=10, splitter=random;, score=0.849 total time=  20.2s
# [CV 1/1; 25/108] START criterion=gini, max_depth=10, min_samples_leaf=4, min_samples_split=2, splitter=best
# [CV 1/1; 25/108] END criterion=gini, max_depth=10, min_samples_leaf=4, min_samples_split=2, splitter=best;, score=0.905 total time= 1.1min
# [CV 1/1; 26/108] START criterion=gini, max_depth=10, min_samples_leaf=4, min_samples_split=2, splitter=random
# [CV 1/1; 26/108] END criterion=gini, max_depth=10, min_samples_leaf=4, min_samples_split=2, splitter=random;, score=0.881 total time=  18.9s
# [CV 1/1; 27/108] START criterion=gini, max_depth=10, min_samples_leaf=4, min_samples_split=5, splitter=best
# [CV 1/1; 27/108] END criterion=gini, max_depth=10, min_samples_leaf=4, min_samples_split=5, splitter=best;, score=0.904 total time= 1.1min
# [CV 1/1; 28/108] START criterion=gini, max_depth=10, min_samples_leaf=4, min_samples_split=5, splitter=random
# [CV 1/1; 28/108] END criterion=gini, max_depth=10, min_samples_leaf=4, min_samples_split=5, splitter=random;, score=0.835 total time=  20.5s
# [CV 1/1; 29/108] START criterion=gini, max_depth=10, min_samples_leaf=4, min_samples_split=10, splitter=best
# [CV 1/1; 29/108] END criterion=gini, max_depth=10, min_samples_leaf=4, min_samples_split=10, splitter=best;, score=0.905 total time= 1.1min
# [CV 1/1; 30/108] START criterion=gini, max_depth=10, min_samples_leaf=4, min_samples_split=10, splitter=random
# [CV 1/1; 30/108] END criterion=gini, max_depth=10, min_samples_leaf=4, min_samples_split=10, splitter=random;, score=0.852 total time=  20.0s
# [CV 1/1; 31/108] START criterion=gini, max_depth=10, min_samples_leaf=8, min_samples_split=2, splitter=best
# [CV 1/1; 31/108] END criterion=gini, max_depth=10, min_samples_leaf=8, min_samples_split=2, splitter=best;, score=0.904 total time= 1.1min
# [CV 1/1; 32/108] START criterion=gini, max_depth=10, min_samples_leaf=8, min_samples_split=2, splitter=random
# [CV 1/1; 32/108] END criterion=gini, max_depth=10, min_samples_leaf=8, min_samples_split=2, splitter=random;, score=0.874 total time=  20.7s
# [CV 1/1; 33/108] START criterion=gini, max_depth=10, min_samples_leaf=8, min_samples_split=5, splitter=best
# [CV 1/1; 33/108] END criterion=gini, max_depth=10, min_samples_leaf=8, min_samples_split=5, splitter=best;, score=0.904 total time= 1.1min
# [CV 1/1; 34/108] START criterion=gini, max_depth=10, min_samples_leaf=8, min_samples_split=5, splitter=random
# [CV 1/1; 34/108] END criterion=gini, max_depth=10, min_samples_leaf=8, min_samples_split=5, splitter=random;, score=0.820 total time=  20.8s
# [CV 1/1; 35/108] START criterion=gini, max_depth=10, min_samples_leaf=8, min_samples_split=10, splitter=best
# [CV 1/1; 35/108] END criterion=gini, max_depth=10, min_samples_leaf=8, min_samples_split=10, splitter=best;, score=0.904 total time= 1.1min
# [CV 1/1; 36/108] START criterion=gini, max_depth=10, min_samples_leaf=8, min_samples_split=10, splitter=random
# [CV 1/1; 36/108] END criterion=gini, max_depth=10, min_samples_leaf=8, min_samples_split=10, splitter=random;, score=0.780 total time=  20.5s
# [CV 1/1; 37/108] START criterion=gini, max_depth=20, min_samples_leaf=1, min_samples_split=2, splitter=best
# [CV 1/1; 37/108] END criterion=gini, max_depth=20, min_samples_leaf=1, min_samples_split=2, splitter=best;, score=0.814 total time= 1.9min
# [CV 1/1; 38/108] START criterion=gini, max_depth=20, min_samples_leaf=1, min_samples_split=2, splitter=random
# [CV 1/1; 38/108] END criterion=gini, max_depth=20, min_samples_leaf=1, min_samples_split=2, splitter=random;, score=0.803 total time=  28.8s
# [CV 1/1; 39/108] START criterion=gini, max_depth=20, min_samples_leaf=1, min_samples_split=5, splitter=best
# [CV 1/1; 39/108] END criterion=gini, max_depth=20, min_samples_leaf=1, min_samples_split=5, splitter=best;, score=0.811 total time= 1.9min
# [CV 1/1; 40/108] START criterion=gini, max_depth=20, min_samples_leaf=1, min_samples_split=5, splitter=random
# [CV 1/1; 40/108] END criterion=gini, max_depth=20, min_samples_leaf=1, min_samples_split=5, splitter=random;, score=0.792 total time=  27.5s
# [CV 1/1; 41/108] START criterion=gini, max_depth=20, min_samples_leaf=1, min_samples_split=10, splitter=best
# [CV 1/1; 41/108] END criterion=gini, max_depth=20, min_samples_leaf=1, min_samples_split=10, splitter=best;, score=0.812 total time= 1.9min
# [CV 1/1; 42/108] START criterion=gini, max_depth=20, min_samples_leaf=1, min_samples_split=10, splitter=random
# [CV 1/1; 42/108] END criterion=gini, max_depth=20, min_samples_leaf=1, min_samples_split=10, splitter=random;, score=0.845 total time=  29.5s
# [CV 1/1; 43/108] START criterion=gini, max_depth=20, min_samples_leaf=4, min_samples_split=2, splitter=best
# [CV 1/1; 43/108] END criterion=gini, max_depth=20, min_samples_leaf=4, min_samples_split=2, splitter=best;, score=0.841 total time= 1.8min
# [CV 1/1; 44/108] START criterion=gini, max_depth=20, min_samples_leaf=4, min_samples_split=2, splitter=random
# [CV 1/1; 44/108] END criterion=gini, max_depth=20, min_samples_leaf=4, min_samples_split=2, splitter=random;, score=0.866 total time=  26.8s
# [CV 1/1; 45/108] START criterion=gini, max_depth=20, min_samples_leaf=4, min_samples_split=5, splitter=best
# [CV 1/1; 45/108] END criterion=gini, max_depth=20, min_samples_leaf=4, min_samples_split=5, splitter=best;, score=0.836 total time= 1.8min
# [CV 1/1; 46/108] START criterion=gini, max_depth=20, min_samples_leaf=4, min_samples_split=5, splitter=random
# [CV 1/1; 46/108] END criterion=gini, max_depth=20, min_samples_leaf=4, min_samples_split=5, splitter=random;, score=0.870 total time=  28.7s
# [CV 1/1; 47/108] START criterion=gini, max_depth=20, min_samples_leaf=4, min_samples_split=10, splitter=best
# [CV 1/1; 47/108] END criterion=gini, max_depth=20, min_samples_leaf=4, min_samples_split=10, splitter=best;, score=0.848 total time= 1.8min
# [CV 1/1; 48/108] START criterion=gini, max_depth=20, min_samples_leaf=4, min_samples_split=10, splitter=random
# [CV 1/1; 48/108] END criterion=gini, max_depth=20, min_samples_leaf=4, min_samples_split=10, splitter=random;, score=0.866 total time=  27.2s
# [CV 1/1; 49/108] START criterion=gini, max_depth=20, min_samples_leaf=8, min_samples_split=2, splitter=best
# [CV 1/1; 49/108] END criterion=gini, max_depth=20, min_samples_leaf=8, min_samples_split=2, splitter=best;, score=0.893 total time= 1.8min
# [CV 1/1; 50/108] START criterion=gini, max_depth=20, min_samples_leaf=8, min_samples_split=2, splitter=random
# [CV 1/1; 50/108] END criterion=gini, max_depth=20, min_samples_leaf=8, min_samples_split=2, splitter=random;, score=0.899 total time=  26.7s
# [CV 1/1; 51/108] START criterion=gini, max_depth=20, min_samples_leaf=8, min_samples_split=5, splitter=best
# [CV 1/1; 51/108] END criterion=gini, max_depth=20, min_samples_leaf=8, min_samples_split=5, splitter=best;, score=0.892 total time= 1.8min
# [CV 1/1; 52/108] START criterion=gini, max_depth=20, min_samples_leaf=8, min_samples_split=5, splitter=random
# [CV 1/1; 52/108] END criterion=gini, max_depth=20, min_samples_leaf=8, min_samples_split=5, splitter=random;, score=0.890 total time=  28.0s
# [CV 1/1; 53/108] START criterion=gini, max_depth=20, min_samples_leaf=8, min_samples_split=10, splitter=best
# [CV 1/1; 53/108] END criterion=gini, max_depth=20, min_samples_leaf=8, min_samples_split=10, splitter=best;, score=0.892 total time= 1.8min
# [CV 1/1; 54/108] START criterion=gini, max_depth=20, min_samples_leaf=8, min_samples_split=10, splitter=random
# [CV 1/1; 54/108] END criterion=gini, max_depth=20, min_samples_leaf=8, min_samples_split=10, splitter=random;, score=0.889 total time=  29.4s
# [CV 1/1; 55/108] START criterion=entropy, max_depth=5, min_samples_leaf=1, min_samples_split=2, splitter=best
# [CV 1/1; 55/108] END criterion=entropy, max_depth=5, min_samples_leaf=1, min_samples_split=2, splitter=best;, score=0.827 total time=  37.2s
# [CV 1/1; 56/108] START criterion=entropy, max_depth=5, min_samples_leaf=1, min_samples_split=2, splitter=random
# [CV 1/1; 56/108] END criterion=entropy, max_depth=5, min_samples_leaf=1, min_samples_split=2, splitter=random;, score=0.708 total time=  12.0s
# [CV 1/1; 57/108] START criterion=entropy, max_depth=5, min_samples_leaf=1, min_samples_split=5, splitter=best
# [CV 1/1; 57/108] END criterion=entropy, max_depth=5, min_samples_leaf=1, min_samples_split=5, splitter=best;, score=0.827 total time=  37.0s
# [CV 1/1; 58/108] START criterion=entropy, max_depth=5, min_samples_leaf=1, min_samples_split=5, splitter=random
# [CV 1/1; 58/108] END criterion=entropy, max_depth=5, min_samples_leaf=1, min_samples_split=5, splitter=random;, score=0.757 total time=  11.9s
# [CV 1/1; 59/108] START criterion=entropy, max_depth=5, min_samples_leaf=1, min_samples_split=10, splitter=best
# [CV 1/1; 59/108] END criterion=entropy, max_depth=5, min_samples_leaf=1, min_samples_split=10, splitter=best;, score=0.827 total time=  37.0s
# [CV 1/1; 60/108] START criterion=entropy, max_depth=5, min_samples_leaf=1, min_samples_split=10, splitter=random
# [CV 1/1; 60/108] END criterion=entropy, max_depth=5, min_samples_leaf=1, min_samples_split=10, splitter=random;, score=0.790 total time=  12.0s
# [CV 1/1; 61/108] START criterion=entropy, max_depth=5, min_samples_leaf=4, min_samples_split=2, splitter=best
# [CV 1/1; 61/108] END criterion=entropy, max_depth=5, min_samples_leaf=4, min_samples_split=2, splitter=best;, score=0.827 total time=  36.9s
# [CV 1/1; 62/108] START criterion=entropy, max_depth=5, min_samples_leaf=4, min_samples_split=2, splitter=random
# [CV 1/1; 62/108] END criterion=entropy, max_depth=5, min_samples_leaf=4, min_samples_split=2, splitter=random;, score=0.686 total time=  12.0s
# [CV 1/1; 63/108] START criterion=entropy, max_depth=5, min_samples_leaf=4, min_samples_split=5, splitter=best
# [CV 1/1; 63/108] END criterion=entropy, max_depth=5, min_samples_leaf=4, min_samples_split=5, splitter=best;, score=0.827 total time=  37.0s
# [CV 1/1; 64/108] START criterion=entropy, max_depth=5, min_samples_leaf=4, min_samples_split=5, splitter=random
# [CV 1/1; 64/108] END criterion=entropy, max_depth=5, min_samples_leaf=4, min_samples_split=5, splitter=random;, score=0.757 total time=  11.7s
# [CV 1/1; 65/108] START criterion=entropy, max_depth=5, min_samples_leaf=4, min_samples_split=10, splitter=best
# [CV 1/1; 65/108] END criterion=entropy, max_depth=5, min_samples_leaf=4, min_samples_split=10, splitter=best;, score=0.827 total time=  37.2s
# [CV 1/1; 66/108] START criterion=entropy, max_depth=5, min_samples_leaf=4, min_samples_split=10, splitter=random
# [CV 1/1; 66/108] END criterion=entropy, max_depth=5, min_samples_leaf=4, min_samples_split=10, splitter=random;, score=0.762 total time=  11.8s
# [CV 1/1; 67/108] START criterion=entropy, max_depth=5, min_samples_leaf=8, min_samples_split=2, splitter=best
# [CV 1/1; 67/108] END criterion=entropy, max_depth=5, min_samples_leaf=8, min_samples_split=2, splitter=best;, score=0.827 total time=  37.2s
# [CV 1/1; 68/108] START criterion=entropy, max_depth=5, min_samples_leaf=8, min_samples_split=2, splitter=random
# [CV 1/1; 68/108] END criterion=entropy, max_depth=5, min_samples_leaf=8, min_samples_split=2, splitter=random;, score=0.724 total time=  11.8s
# [CV 1/1; 69/108] START criterion=entropy, max_depth=5, min_samples_leaf=8, min_samples_split=5, splitter=best
# [CV 1/1; 69/108] END criterion=entropy, max_depth=5, min_samples_leaf=8, min_samples_split=5, splitter=best;, score=0.827 total time=  36.9s
# [CV 1/1; 70/108] START criterion=entropy, max_depth=5, min_samples_leaf=8, min_samples_split=5, splitter=random
# [CV 1/1; 70/108] END criterion=entropy, max_depth=5, min_samples_leaf=8, min_samples_split=5, splitter=random;, score=0.825 total time=  18.7s
# [CV 1/1; 71/108] START criterion=entropy, max_depth=5, min_samples_leaf=8, min_samples_split=10, splitter=best
# [CV 1/1; 71/108] END criterion=entropy, max_depth=5, min_samples_leaf=8, min_samples_split=10, splitter=best;, score=0.827 total time= 1.2min
# [CV 1/1; 72/108] START criterion=entropy, max_depth=5, min_samples_leaf=8, min_samples_split=10, splitter=random
# [CV 1/1; 72/108] END criterion=entropy, max_depth=5, min_samples_leaf=8, min_samples_split=10, splitter=random;, score=0.757 total time=  11.3s
# [CV 1/1; 73/108] START criterion=entropy, max_depth=10, min_samples_leaf=1, min_samples_split=2, splitter=best
# [CV 1/1; 73/108] END criterion=entropy, max_depth=10, min_samples_leaf=1, min_samples_split=2, splitter=best;, score=0.900 total time= 1.6min
# [CV 1/1; 74/108] START criterion=entropy, max_depth=10, min_samples_leaf=1, min_samples_split=2, splitter=random
# [CV 1/1; 74/108] END criterion=entropy, max_depth=10, min_samples_leaf=1, min_samples_split=2, splitter=random;, score=0.870 total time=  53.5s
# [CV 1/1; 75/108] START criterion=entropy, max_depth=10, min_samples_leaf=1, min_samples_split=5, splitter=best
# [CV 1/1; 75/108] END criterion=entropy, max_depth=10, min_samples_leaf=1, min_samples_split=5, splitter=best;, score=0.900 total time= 1.8min
# [CV 1/1; 76/108] START criterion=entropy, max_depth=10, min_samples_leaf=1, min_samples_split=5, splitter=random
# [CV 1/1; 76/108] END criterion=entropy, max_depth=10, min_samples_leaf=1, min_samples_split=5, splitter=random;, score=0.827 total time=  20.2s
# [CV 1/1; 77/108] START criterion=entropy, max_depth=10, min_samples_leaf=1, min_samples_split=10, splitter=best
# [CV 1/1; 77/108] END criterion=entropy, max_depth=10, min_samples_leaf=1, min_samples_split=10, splitter=best;, score=0.900 total time= 1.2min
# [CV 1/1; 78/108] START criterion=entropy, max_depth=10, min_samples_leaf=1, min_samples_split=10, splitter=random
# [CV 1/1; 78/108] END criterion=entropy, max_depth=10, min_samples_leaf=1, min_samples_split=10, splitter=random;, score=0.869 total time=  19.9s
# [CV 1/1; 79/108] START criterion=entropy, max_depth=10, min_samples_leaf=4, min_samples_split=2, splitter=best
# [CV 1/1; 79/108] END criterion=entropy, max_depth=10, min_samples_leaf=4, min_samples_split=2, splitter=best;, score=0.901 total time= 1.2min
# [CV 1/1; 80/108] START criterion=entropy, max_depth=10, min_samples_leaf=4, min_samples_split=2, splitter=random
# [CV 1/1; 80/108] END criterion=entropy, max_depth=10, min_samples_leaf=4, min_samples_split=2, splitter=random;, score=0.783 total time=  21.2s
# [CV 1/1; 81/108] START criterion=entropy, max_depth=10, min_samples_leaf=4, min_samples_split=5, splitter=best
# [CV 1/1; 81/108] END criterion=entropy, max_depth=10, min_samples_leaf=4, min_samples_split=5, splitter=best;, score=0.902 total time= 1.2min
# [CV 1/1; 82/108] START criterion=entropy, max_depth=10, min_samples_leaf=4, min_samples_split=5, splitter=random
# [CV 1/1; 82/108] END criterion=entropy, max_depth=10, min_samples_leaf=4, min_samples_split=5, splitter=random;, score=0.852 total time=  19.8s
# [CV 1/1; 83/108] START criterion=entropy, max_depth=10, min_samples_leaf=4, min_samples_split=10, splitter=best
# [CV 1/1; 83/108] END criterion=entropy, max_depth=10, min_samples_leaf=4, min_samples_split=10, splitter=best;, score=0.901 total time= 1.2min
# [CV 1/1; 84/108] START criterion=entropy, max_depth=10, min_samples_leaf=4, min_samples_split=10, splitter=random
# [CV 1/1; 84/108] END criterion=entropy, max_depth=10, min_samples_leaf=4, min_samples_split=10, splitter=random;, score=0.824 total time=  20.3s
# [CV 1/1; 85/108] START criterion=entropy, max_depth=10, min_samples_leaf=8, min_samples_split=2, splitter=best
# [CV 1/1; 85/108] END criterion=entropy, max_depth=10, min_samples_leaf=8, min_samples_split=2, splitter=best;, score=0.901 total time= 1.2min
# [CV 1/1; 86/108] START criterion=entropy, max_depth=10, min_samples_leaf=8, min_samples_split=2, splitter=random
# [CV 1/1; 86/108] END criterion=entropy, max_depth=10, min_samples_leaf=8, min_samples_split=2, splitter=random;, score=0.859 total time=  20.3s
# [CV 1/1; 87/108] START criterion=entropy, max_depth=10, min_samples_leaf=8, min_samples_split=5, splitter=best
# [CV 1/1; 87/108] END criterion=entropy, max_depth=10, min_samples_leaf=8, min_samples_split=5, splitter=best;, score=0.901 total time= 1.2min
# [CV 1/1; 88/108] START criterion=entropy, max_depth=10, min_samples_leaf=8, min_samples_split=5, splitter=random
# [CV 1/1; 88/108] END criterion=entropy, max_depth=10, min_samples_leaf=8, min_samples_split=5, splitter=random;, score=0.862 total time=  20.4s
# [CV 1/1; 89/108] START criterion=entropy, max_depth=10, min_samples_leaf=8, min_samples_split=10, splitter=best
# [CV 1/1; 89/108] END criterion=entropy, max_depth=10, min_samples_leaf=8, min_samples_split=10, splitter=best;, score=0.901 total time= 1.2min
# [CV 1/1; 90/108] START criterion=entropy, max_depth=10, min_samples_leaf=8, min_samples_split=10, splitter=random
# [CV 1/1; 90/108] END criterion=entropy, max_depth=10, min_samples_leaf=8, min_samples_split=10, splitter=random;, score=0.829 total time=  19.8s
# [CV 1/1; 91/108] START criterion=entropy, max_depth=20, min_samples_leaf=1, min_samples_split=2, splitter=best
# [CV 1/1; 91/108] END criterion=entropy, max_depth=20, min_samples_leaf=1, min_samples_split=2, splitter=best;, score=0.865 total time= 1.5min
# [CV 1/1; 92/108] START criterion=entropy, max_depth=20, min_samples_leaf=1, min_samples_split=2, splitter=random
# [CV 1/1; 92/108] END criterion=entropy, max_depth=20, min_samples_leaf=1, min_samples_split=2, splitter=random;, score=0.849 total time=  27.3s
# [CV 1/1; 93/108] START criterion=entropy, max_depth=20, min_samples_leaf=1, min_samples_split=5, splitter=best
# [CV 1/1; 93/108] END criterion=entropy, max_depth=20, min_samples_leaf=1, min_samples_split=5, splitter=best;, score=0.861 total time= 1.5min
# [CV 1/1; 94/108] START criterion=entropy, max_depth=20, min_samples_leaf=1, min_samples_split=5, splitter=random
# [CV 1/1; 94/108] END criterion=entropy, max_depth=20, min_samples_leaf=1, min_samples_split=5, splitter=random;, score=0.850 total time=  25.7s
# [CV 1/1; 95/108] START criterion=entropy, max_depth=20, min_samples_leaf=1, min_samples_split=10, splitter=best
# [CV 1/1; 95/108] END criterion=entropy, max_depth=20, min_samples_leaf=1, min_samples_split=10, splitter=best;, score=0.864 total time= 1.5min
# [CV 1/1; 96/108] START criterion=entropy, max_depth=20, min_samples_leaf=1, min_samples_split=10, splitter=random
# [CV 1/1; 96/108] END criterion=entropy, max_depth=20, min_samples_leaf=1, min_samples_split=10, splitter=random;, score=0.848 total time=  26.4s
# [CV 1/1; 97/108] START criterion=entropy, max_depth=20, min_samples_leaf=4, min_samples_split=2, splitter=best
# [CV 1/1; 97/108] END criterion=entropy, max_depth=20, min_samples_leaf=4, min_samples_split=2, splitter=best;, score=0.884 total time= 1.5min
# [CV 1/1; 98/108] START criterion=entropy, max_depth=20, min_samples_leaf=4, min_samples_split=2, splitter=random
# [CV 1/1; 98/108] END criterion=entropy, max_depth=20, min_samples_leaf=4, min_samples_split=2, splitter=random;, score=0.875 total time=  27.3s
# [CV 1/1; 99/108] START criterion=entropy, max_depth=20, min_samples_leaf=4, min_samples_split=5, splitter=best
# [CV 1/1; 99/108] END criterion=entropy, max_depth=20, min_samples_leaf=4, min_samples_split=5, splitter=best;, score=0.882 total time= 1.5min
# [CV 1/1; 100/108] START criterion=entropy, max_depth=20, min_samples_leaf=4, min_samples_split=5, splitter=random
# [CV 1/1; 100/108] END criterion=entropy, max_depth=20, min_samples_leaf=4, min_samples_split=5, splitter=random;, score=0.875 total time=  27.7s
# [CV 1/1; 101/108] START criterion=entropy, max_depth=20, min_samples_leaf=4, min_samples_split=10, splitter=best
# [CV 1/1; 101/108] END criterion=entropy, max_depth=20, min_samples_leaf=4, min_samples_split=10, splitter=best;, score=0.883 total time= 1.4min
# [CV 1/1; 102/108] START criterion=entropy, max_depth=20, min_samples_leaf=4, min_samples_split=10, splitter=random
# [CV 1/1; 102/108] END criterion=entropy, max_depth=20, min_samples_leaf=4, min_samples_split=10, splitter=random;, score=0.888 total time=  26.0s
# [CV 1/1; 103/108] START criterion=entropy, max_depth=20, min_samples_leaf=8, min_samples_split=2, splitter=best
# [CV 1/1; 103/108] END criterion=entropy, max_depth=20, min_samples_leaf=8, min_samples_split=2, splitter=best;, score=0.899 total time= 1.4min
# [CV 1/1; 104/108] START criterion=entropy, max_depth=20, min_samples_leaf=8, min_samples_split=2, splitter=random
# [CV 1/1; 104/108] END criterion=entropy, max_depth=20, min_samples_leaf=8, min_samples_split=2, splitter=random;, score=0.892 total time=  27.3s
# [CV 1/1; 105/108] START criterion=entropy, max_depth=20, min_samples_leaf=8, min_samples_split=5, splitter=best
# [CV 1/1; 105/108] END criterion=entropy, max_depth=20, min_samples_leaf=8, min_samples_split=5, splitter=best;, score=0.899 total time= 1.4min
# [CV 1/1; 106/108] START criterion=entropy, max_depth=20, min_samples_leaf=8, min_samples_split=5, splitter=random
# [CV 1/1; 106/108] END criterion=entropy, max_depth=20, min_samples_leaf=8, min_samples_split=5, splitter=random;, score=0.893 total time=  27.7s
# [CV 1/1; 107/108] START criterion=entropy, max_depth=20, min_samples_leaf=8, min_samples_split=10, splitter=best
# [CV 1/1; 107/108] END criterion=entropy, max_depth=20, min_samples_leaf=8, min_samples_split=10, splitter=best;, score=0.900 total time= 1.4min
# [CV 1/1; 108/108] START criterion=entropy, max_depth=20, min_samples_leaf=8, min_samples_split=10, splitter=random
# [CV 1/1; 108/108] END criterion=entropy, max_depth=20, min_samples_leaf=8, min_samples_split=10, splitter=random;, score=0.898 total time=  27.9s

# %%
print(f"Best Score: {search.best_score_}")
print(f"Best Hyperparameters: {search.best_params_}")
# Out:
# Best Score: 0.9049334254216098
# Best Hyperparameters: {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 10, 'splitter': 'best'}

# %%
pd.DataFrame(search.cv_results_)
# Out:
#      mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        74.290251           0.0         0.166583             0.0
# 1        12.844604           0.0         0.403162             0.0
# 2        43.962635           0.0         0.214883             0.0
# 3        13.208908           0.0         0.198514             0.0
# 4        41.974117           0.0         0.184403             0.0
# ..             ...           ...              ...             ...
# 103      27.075179           0.0         0.189619             0.0
# 104      85.813122           0.0         0.179066             0.0
# 105      27.511585           0.0         0.185908             0.0
# 106      85.534676           0.0         0.177749             0.0
# 107      27.748615           0.0         0.191860             0.0
#
#     param_criterion param_max_depth param_min_samples_leaf  \
# 0              gini               5                      1
# 1              gini               5                      1
# 2              gini               5                      1
# 3              gini               5                      1
# 4              gini               5                      1
# ..              ...             ...                    ...
# 103         entropy              20                      8
# 104         entropy              20                      8
# 105         entropy              20                      8
# 106         entropy              20                      8
# 107         entropy              20                      8
#
#     param_min_samples_split param_splitter  \
# 0                         2           best
# 1                         2         random
# 2                         5           best
# 3                         5         random
# 4                        10           best
# ..                      ...            ...
# 103                       2         random
# 104                       5           best
# 105                       5         random
# 106                      10           best
# 107                      10         random
#
#                                                 params  split0_test_score  \
# 0    {'criterion': 'gini', 'max_depth': 5, 'min_sam...           0.841292
# 1    {'criterion': 'gini', 'max_depth': 5, 'min_sam...           0.785877
# 2    {'criterion': 'gini', 'max_depth': 5, 'min_sam...           0.841292
# 3    {'criterion': 'gini', 'max_depth': 5, 'min_sam...           0.780964
# 4    {'criterion': 'gini', 'max_depth': 5, 'min_sam...           0.841292
# ..                                                 ...                ...
# 103  {'criterion': 'entropy', 'max_depth': 20, 'min...           0.892327
# 104  {'criterion': 'entropy', 'max_depth': 20, 'min...           0.899032
# 105  {'criterion': 'entropy', 'max_depth': 20, 'min...           0.892550
# 106  {'criterion': 'entropy', 'max_depth': 20, 'min...           0.900300
# 107  {'criterion': 'entropy', 'max_depth': 20, 'min...           0.897590
#
#      mean_test_score  std_test_score  rank_test_score
# 0           0.841292             0.0               58
# 1           0.785877             0.0               91
# 2           0.841292             0.0               58
# 3           0.780964             0.0               93
# 4           0.841292             0.0               58
# ..               ...             ...              ...
# 103         0.892327             0.0               26
# 104         0.899032             0.0               20
# 105         0.892550             0.0               25
# 106         0.900300             0.0               16
# 107         0.897590             0.0               23
#
# [108 rows x 14 columns]

# %%
pd.DataFrame(search.cv_results_).to_csv(
    f"{BASE_DIR}/data/analysis/decision_tree/without_race_with_weather.csv", index=False
)

# %%
import pickle

dt = DecisionTreeClassifier(
    criterion='gini',
    max_depth=10,
    min_samples_leaf=4,
    min_samples_split=10,
    splitter='best',
).fit(X_train.to_numpy(), X_train_pairwise_winner_labels)

with open(f"{BASE_DIR}/data/analysis/decision_tree/without_race_with_weather.pkl",'wb') as f:
    pickle.dump(dt, f)

# %% [markdown]
# ---
