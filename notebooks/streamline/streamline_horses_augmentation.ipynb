# %% [markdown]
# # `streamline_horses_augmentation.ipynb`

# %% [markdown]
# ### Author: Anthony Hein

# %% [markdown]
# #### Last updated: 11/3/2021

# %% [markdown]
# # Overview:
#
# Augment the horses dataset so that each row includes an additional columns which is the _estimated_ finishing time of this horse. This is calculated based on the distance (in lengths) to the first place finisher, the distance of the race, and the winning time of the first place finisher.
#
# Some of this borders on featurization. For us, the difference between augmenting the dataset and featurizing the dataset will be that featuriziation considers rows in our dataset with respect to other rows in the dataset whereas augmentation can exist for a row in isolation.

# %% [markdown]
# ---

# %% [markdown]
# ## Setup

# %%
from datetime import datetime
import git
import os
import re
from typing import List
from tqdm import tqdm
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
BASE_DIR = git.Repo(os.getcwd(), search_parent_directories=True).working_dir
BASE_DIR
# Out:
# '/Users/anthonyhein/Desktop/SML310/project'

# %% [markdown]
# ---

# %% [markdown]
# ## Load `horses_selected_trimmed_clean.csv`

# %%
horses_selected_trimmed_clean = pd.read_csv(f"{BASE_DIR}/data/streamline/horses_selected_trimmed_clean.csv",
                                            low_memory=False) 
horses_selected_trimmed_clean.head()
# Out:
#       rid         horseName  age  saddle  decimalPrice  isFav   trainerName  \
# 0  302858      Kings Return  6.0     4.0      0.600000      1   W P Mullins
# 1  302858    Majestic Red I  6.0     5.0      0.047619      0  John Hackett
# 2  302858  Clearly Canadian  6.0     2.0      0.166667      0    D T Hughes
# 3  302858  Bernestic Wonder  8.0     1.0      0.058824      0    E McNamara
# 4  302858    Beauty's Pride  5.0     6.0      0.038462      0    J J Lennon
#
#       jockeyName  position positionL  ...    RPR  TR  OR       father  \
# 0      D J Casey         1         0  ...  102.0 NaN NaN  King's Ride
# 1  Conor O'Dwyer         2         8  ...   94.0 NaN NaN    Long Pond
# 2       G Cotter         3       1.5  ...   92.0 NaN NaN      Nordico
# 3    J Old Jones         4      dist  ...    NaN NaN NaN     Roselier
# 4       T Martin         5      dist  ...    NaN NaN NaN       Noalto
#
#             mother       gfather weight res_win  res_place  res_show
# 0  Browne's Return      Deep Run     73       1          1         0
# 1  Courtlough Lady   Giolla Mear     73       0          1         0
# 2    Over The Seas  North Summit     71       0          0         0
# 3    Miss Reindeer      Reindeer     73       0          0         0
# 4   Elena's Beauty      Tarqogan     66       0          0         0
#
# [5 rows x 22 columns]

# %%
horses_selected_trimmed_clean.shape
# Out:
# (202304, 22)

# %%
horses_selected_trimmed_clean_augmented = horses_selected_trimmed_clean.copy()
horses_selected_trimmed_clean_augmented.head()
# Out:
#       rid         horseName  age  saddle  decimalPrice  isFav   trainerName  \
# 0  302858      Kings Return  6.0     4.0      0.600000      1   W P Mullins
# 1  302858    Majestic Red I  6.0     5.0      0.047619      0  John Hackett
# 2  302858  Clearly Canadian  6.0     2.0      0.166667      0    D T Hughes
# 3  302858  Bernestic Wonder  8.0     1.0      0.058824      0    E McNamara
# 4  302858    Beauty's Pride  5.0     6.0      0.038462      0    J J Lennon
#
#       jockeyName  position positionL  ...    RPR  TR  OR       father  \
# 0      D J Casey         1         0  ...  102.0 NaN NaN  King's Ride
# 1  Conor O'Dwyer         2         8  ...   94.0 NaN NaN    Long Pond
# 2       G Cotter         3       1.5  ...   92.0 NaN NaN      Nordico
# 3    J Old Jones         4      dist  ...    NaN NaN NaN     Roselier
# 4       T Martin         5      dist  ...    NaN NaN NaN       Noalto
#
#             mother       gfather weight res_win  res_place  res_show
# 0  Browne's Return      Deep Run     73       1          1         0
# 1  Courtlough Lady   Giolla Mear     73       0          1         0
# 2    Over The Seas  North Summit     71       0          0         0
# 3    Miss Reindeer      Reindeer     73       0          0         0
# 4   Elena's Beauty      Tarqogan     66       0          0         0
#
# [5 rows x 22 columns]

# %% [markdown]
# ---

# %% [markdown]
# ## Load `races_selected_trimmed_clean.csv`

# %%
races_selected_trimmed_clean = pd.read_csv(f"{BASE_DIR}/data/streamline/races_selected_trimmed_clean.csv",
                                           low_memory=False) 
races_selected_trimmed_clean.head()
# Out:
#       rid       course                                              title  \
# 0  302858      Thurles                       Liffey Maiden Hurdle (Div 1)
# 1  291347  Punchestown  Ericsson G.S.M. Grand National Trial Handicap ...
# 2   75447     Listowel               Ballybunion E.B.F. Beginners S'chase
# 3  358038  Punchestown  Quinns Of Baltinglass Chase (La Touche) (Cross...
# 4   89211    Tipperary                       Topaz Sprint Stakes (Listed)
#
#    winningTime  metric  ncond  class  runners    margin  \
# 0        277.2  3821.0      1      0        6  1.219263
# 1        447.2  5229.0      5      0        9  1.218049
# 2        318.4  3620.0      5      0        8  1.277320
# 3        533.9  6637.0      1      0       10  1.286595
# 4         59.9  1005.0      4      0        5  1.217043
#
#    1st_place_rank_in_odds  ...     station name  station lat  station lng  \
# 0                       1  ...             BIRR      53.0525      -7.5325
# 1                       4  ...         CASEMENT      53.1820      -6.2620
# 2                       3  ...  SHANNON AIRPORT      52.4125      -8.5505
# 3                       1  ...         CASEMENT      53.1820      -6.2620
# 4                       4  ...  SHANNON AIRPORT      52.4125      -8.5505
#
#    dist to station  station reading date  temp     msl  rain  rhum  \
# 0        45.288813          1/9/97 12:00   1.6  1012.4   0.0    87
# 1        24.477602         2/16/97 15:00   8.0   992.5   0.4    87
# 2        63.534139          3/1/97 14:00  12.0  1003.5   0.0    73
# 3        24.477602         4/24/97 14:00  12.6  1011.9   0.0    72
# 4        25.222137          5/8/97 17:00  11.1   994.2   0.0    59
#
#    station reading timedelta
# 0                       15.0
# 1                       20.0
# 2                        0.0
# 3                       20.0
# 4                       30.0
#
# [5 rows x 34 columns]

# %%
races_selected_trimmed_clean.shape
# Out:
# (20201, 34)

# %% [markdown]
# ---

# %% [markdown]
# ## Helper Dictionaries

# %%
rid_to_distance = {}
rid_to_winning_time = {}

for _, row in races_selected_trimmed_clean.iterrows():
    rid_to_distance[row['rid']] = row['metric']
    rid_to_winning_time[row['rid']] = row['winningTime']

# %% [markdown]
# ---

# %% [markdown]
# ## Augment w/ Finishing Time

# %% [markdown]
# The following is a function for the amount of time a "length" in a given horse race is, inspired by [https://edge.twinspires.com/racing/the-real-value-of-a-length/](https://edge.twinspires.com/racing/the-real-value-of-a-length/).
#
# $$\text{time of length in seconds} = 1\ /\ [\ \text{distance}\ /\ \text{winning time}\ /\ \text{average horse length}\ ]$$
#
# Note that the distance and the average horse length must have the same units to cancel out.

# %%
AVERAGE_HORSE_LENGTH = 2.55 # meters

# %%
def get_time_of_length(distance: float, winning_time: float) -> float:
    return 1 / (distance / winning_time / AVERAGE_HORSE_LENGTH)

# %%
def get_horse_finish_time(row) -> float:
    length_time = get_time_of_length(rid_to_distance[row['rid']], rid_to_winning_time[row['rid']])
    return rid_to_winning_time[row['rid']] + row['dist'] * length_time

# %%
horses_selected_trimmed_clean_augmented['finishing time'] = horses_selected_trimmed_clean_augmented.apply(
    get_horse_finish_time,
    axis=1
)
horses_selected_trimmed_clean_augmented
# Out:
#            rid         horseName  age  saddle  decimalPrice  isFav  \
# 0       302858      Kings Return  6.0     4.0      0.600000      1
# 1       302858    Majestic Red I  6.0     5.0      0.047619      0
# 2       302858  Clearly Canadian  6.0     2.0      0.166667      0
# 3       302858  Bernestic Wonder  8.0     1.0      0.058824      0
# 4       302858    Beauty's Pride  5.0     6.0      0.038462      0
# ...        ...               ...  ...     ...           ...    ...
# 202299  227139           Old Tim  6.0     5.0      0.142857      0
# 202300  227139          Our Ling  6.0    12.0      0.111111      0
# 202301  227139       Ballinarrid  6.0     2.0      0.111111      0
# 202302  227139      Fountain Pen  9.0     3.0      0.047619      0
# 202303  227139            Marmat  7.0     9.0      0.153846      0
#
#                   trainerName      jockeyName  position positionL  ...  TR  \
# 0                 W P Mullins       D J Casey         1         0  ... NaN
# 1                John Hackett   Conor O'Dwyer         2         8  ... NaN
# 2                  D T Hughes        G Cotter         3       1.5  ... NaN
# 3                  E McNamara     J Old Jones         4      dist  ... NaN
# 4                  J J Lennon        T Martin         5      dist  ... NaN
# ...                       ...             ...       ...       ...  ...  ..
# 202299          Donal Hassett    Mr B Hassett         8        15  ... NaN
# 202300           C P Donoghue  Philip Dempsey         9        13  ... NaN
# 202301        Seamus P Murphy     Mr P Fenton        10      0.75  ... NaN
# 202302  William J Fitzpatrick      Mr P Fahey        11      dist  ... NaN
# 202303             F J Bowles   Mr A J Martin        40        30  ... NaN
#
#         OR          father           mother        gfather weight res_win  \
# 0      NaN     King's Ride  Browne's Return       Deep Run     73       1
# 1      NaN       Long Pond  Courtlough Lady    Giolla Mear     73       0
# 2      NaN         Nordico    Over The Seas   North Summit     71       0
# 3      NaN        Roselier    Miss Reindeer       Reindeer     73       0
# 4      NaN          Noalto   Elena's Beauty       Tarqogan     66       0
# ...     ..             ...              ...            ...    ...     ...
# 202299 NaN  Poet's Dream I          Settled  Blue Cashmere     73       0
# 202300 NaN           Vaour         May-Ling    Mississippi     73       0
# 202301 NaN     John French         Cuckaloo    Master Buck     76       0
# 202302 NaN  Royal Fountain     Monday's Pet        Menelek     74       0
# 202303 NaN         Cataldi         Hot Chic      Hot Grove     73       0
#
#        res_place  res_show  finishing time
# 0              1         0      277.200000
# 1              1         0      278.679948
# 2              0         0      278.957438
# 3              0         0      284.507242
# 4              0         0      290.057045
# ...          ...       ...             ...
# 202299         0         0      263.612842
# 202300         0         0      266.195410
# 202301         0         0      266.344405
# 202302         0         0      272.304178
# 202303         0         0      278.263951
#
# [202304 rows x 23 columns]

# %% [markdown]
# ---

# %% [markdown]
# ## Augment w/ `(finishing time ratio) = (finishing time) / (winning time)`

# %% [markdown]
# This is a good summary statistic since it is agnostic to the nominal time and captures information about the distance to a finisher in one cell.

# %%
def get_horse_finishing_time_ratio(row) -> float:
    return row['finishing time'] / rid_to_winning_time[row['rid']]

# %%
horses_selected_trimmed_clean_augmented['finishing time ratio'] = horses_selected_trimmed_clean_augmented.apply(
    get_horse_finishing_time_ratio,
    axis=1
)

# %% [markdown]
# ---

# %% [markdown]
# ## Save Dataframe

# %%
horses_selected_trimmed_clean_augmented.to_csv(
    f"{BASE_DIR}/data/streamline/horses_selected_trimmed_clean_augmented.csv",
    index=False
)

# %% [markdown]
# ---
