# %% [markdown]
# # `make_station_set.ipynb`

# %% [markdown]
# ### Author: Anthony Hein

# %% [markdown]
# #### Last updated: 10/18/2021

# %% [markdown]
# # Overview:
#
# Make a set of the unique weather stations in Great Britain that we will need to extract data from.

# %% [markdown]
# ---

# %% [markdown]
# ## Setup

# %%
from datetime import datetime
import git
import os
from typing import List, Union
from tqdm import tqdm
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
BASE_DIR = git.Repo(os.getcwd(), search_parent_directories=True).working_dir
BASE_DIR
# Out:
# '/Users/anthonyhein/Desktop/SML310/project'

# %%
import sys

sys.path.append(f'{BASE_DIR}/utils/')

from rid_to_station import RID_TO_STATION

# %% [markdown]
# ---

# %% [markdown]
# ## Make Station Set

# %%
a = set([v for _, v in RID_TO_STATION.items() if v[2] >= 2010])

# %%
len(a)
# Out:
# 571

# %%
a
# Out:
# {('WIGGONHOLT', 'WEST SUSSEX', 2001),
#  ('LEEK: THORNCLIFFE', 'STAFFORDSHIRE', 2020),
#  ('PRESTWICK NO 2', 'AYRSHIRE', 2011),
#  ('CARLISLE', 'CUMBRIA', 2017),
#  ('CHARTERHALL', 'BERWICKSHIRE', 2009),
#  ('NOTTINGHAM: WATNALL', 'NOTTINGHAMSHIRE', 2009),
#  ('BRAMHAM', 'WEST YORKSHIRE', 1999),
#  ('SUTTON BONINGTON', 'NOTTINGHAMSHIRE', 2020),
#  ('GRINGLEY-ON-THE-HILL', 'NOTTINGHAMSHIRE', 2001),
#  ('DUNKESWELL AERODROME', 'DEVON', 2005),
#  ('TOPCLIFFE', 'NORTH YORKSHIRE', 2001),
#  ('EXETER AIRPORT', 'DEVON', 2002),
#  ('HOUGHTON HALL', 'NORFOLK', 2019),
#  ('WINCHCOMBE: SUDELEY CASTLE', 'GLOUCESTERSHIRE', 2006),
#  ('LEEMING', 'NORTH YORKSHIRE', 2007),
#  ('LECONFIELD', 'HUMBERSIDE', 2002),
#  ('EAST KILBRIDE NO 2', 'LANARKSHIRE', 2016),
#  ('GATWICK', 'WEST SUSSEX', 2015),
#  ('BRAMHAM', 'WEST YORKSHIRE', 2012),
#  ('MORPETH: COCKLE PARK', 'NORTHUMBERLAND', 2006),
#  ('CROSBY', 'MERSEYSIDE', 2014),
#  ('SCAMPTON', 'LINCOLNSHIRE', 1999),
# ...

# %% [markdown]
# ---

# %% [markdown]
# ## Write to File in `utils`

# %%
s = f"STATION = {a}"
s[:100]
# Out:
# "STATION = {'HEREFORD: CREDENHILL', 'BOLTSHOPE PARK', 'AUGHTON', 'MORPETH: COCKLE PARK', 'LOFTUS', 'G"

# %%
with open(f"{BASE_DIR}/utils/station.py", 'w', encoding='utf-8') as f:
    f.write(s)

# %% [markdown]
# ---
