# %% [markdown]
# # `change_dist_horse.ipynb`

# %% [markdown]
# ### Author: Anthony Hein

# %% [markdown]
# #### Last updated: 10/19/2021

# %% [markdown]
# # Overview:
#
# The current `dist` column within our horses dataset calculates the distance to a placing horse, not the winning horse. That is, it is the distance to the horse in second place. Since our goal is to convert distance information into raw race times, this is not helpful and we instead want to know the distance to the horse in first (the only one for which we know the racing time). To do so, we will recalculate the distance to first place and change the current `dist` variable to reflect this.

# %% [markdown]
# ---

# %% [markdown]
# ## Setup

# %%
from datetime import datetime
import git
import os
import math
import re
from typing import List
from tqdm import tqdm
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
BASE_DIR = git.Repo(os.getcwd(), search_parent_directories=True).working_dir
BASE_DIR
# Out:
# '/Users/anthonyhein/Desktop/SML310/project'

# %%
import sys
sys.path.append(f'{BASE_DIR}/utils/')

from length_abbrv_to_dist import LENGTH_ABBRV_TO_DIST

# %% [markdown]
# ---

# %% [markdown]
# ## Load `horses_augment.csv`

# %%
horses_augment = pd.read_csv(f"{BASE_DIR}/data/csv/horses_augment.csv", low_memory=False) 
horses_augment.head()
# Out:
#       rid         horseName  age  saddle  decimalPrice   trainerName  \
# 0  302858      Kings Return  6.0     4.0      0.600000   W P Mullins
# 1  302858    Majestic Red I  6.0     5.0      0.047619  John Hackett
# 2  302858  Clearly Canadian  6.0     2.0      0.166667    D T Hughes
# 3  302858  Bernestic Wonder  8.0     1.0      0.058824    E McNamara
# 4  302858    Beauty's Pride  5.0     6.0      0.038462    J J Lennon
#
#       jockeyName  position positionL  dist  outHandicap        RPR         TR  \
# 0      D J Casey         1       NaN   0.0          0.0  102.00000  51.591987
# 1  Conor O'Dwyer         2         8   0.0          0.0   94.00000  51.591987
# 2       G Cotter         3       1.5   9.5          0.0   92.00000  51.591987
# 3    J Old Jones         4      dist  39.5          0.0   71.87665  51.591987
# 4       T Martin         5      dist  69.5          0.0   71.87665  51.591987
#
#           OR       father           mother       gfather  weight
# 0  79.654604  King's Ride  Browne's Return      Deep Run      73
# 1  79.654604    Long Pond  Courtlough Lady   Giolla Mear      73
# 2  79.654604      Nordico    Over The Seas  North Summit      71
# 3  79.654604     Roselier    Miss Reindeer      Reindeer      73
# 4  79.654604       Noalto   Elena's Beauty      Tarqogan      66

# %%
horses_augment.shape
# Out:
# (194898, 18)

# %%
horses_augment_dist = horses_augment.copy()
horses_augment_dist.head()
# Out:
#       rid         horseName  age  saddle  decimalPrice   trainerName  \
# 0  302858      Kings Return  6.0     4.0      0.600000   W P Mullins
# 1  302858    Majestic Red I  6.0     5.0      0.047619  John Hackett
# 2  302858  Clearly Canadian  6.0     2.0      0.166667    D T Hughes
# 3  302858  Bernestic Wonder  8.0     1.0      0.058824    E McNamara
# 4  302858    Beauty's Pride  5.0     6.0      0.038462    J J Lennon
#
#       jockeyName  position positionL  dist  outHandicap        RPR         TR  \
# 0      D J Casey         1       NaN   0.0          0.0  102.00000  51.591987
# 1  Conor O'Dwyer         2         8   0.0          0.0   94.00000  51.591987
# 2       G Cotter         3       1.5   9.5          0.0   92.00000  51.591987
# 3    J Old Jones         4      dist  39.5          0.0   71.87665  51.591987
# 4       T Martin         5      dist  69.5          0.0   71.87665  51.591987
#
#           OR       father           mother       gfather  weight
# 0  79.654604  King's Ride  Browne's Return      Deep Run      73
# 1  79.654604    Long Pond  Courtlough Lady   Giolla Mear      73
# 2  79.654604      Nordico    Over The Seas  North Summit      71
# 3  79.654604     Roselier    Miss Reindeer      Reindeer      73
# 4  79.654604       Noalto   Elena's Beauty      Tarqogan      66

# %% [markdown]
# ---

# %% [markdown]
# ## Helper Function

# %%
def get_dist_of_horse(df: pd.core.frame.DataFrame, idx: int) -> float:
    """
    Given a dataframe `df` that represents a race, calculate the `dist`
    of the horse with identifier `idx`.
    """
    
    df = df.sort_values(by=['position'])
    
    # cumulative distance to the runner in 1st place
    dist = 0
    
    # there may be ties for a position
    curr_position = 1
    
    # for all entries in this race
    for _, row in df.iterrows():
        
        # convert `positionL` to a numerical value,
        # it is safe to assume that the length is 0 where `positionL = NaN`, see prior discussion
        if row['positionL'] and (isinstance(row['positionL'], str) or not math.isnan(row['positionL'])):
            lengths = row['positionL']
        else:
            lengths = 0
        
        # some `positionL` values are strings encoding length information
        try:
            lengths = float(lengths)
        except:
            lengths = LENGTH_ABBRV_TO_DIST[lengths]
            
        # be careful about changing the current position bc of ties
        curr_position = row['position']
       
        # accumulate distance so long as we are not looking at nonfinishing horses
        if curr_position != 40:
            dist += lengths
        
        # found the desired horse
        if int(row.name) == idx:
            return dist + (LENGTH_ABBRV_TO_DIST['dist'] if curr_position == 40 else 0)

# %%
df = horses_augment_dist[horses_augment_dist['rid'] == 302858]
df
# Out:
#       rid         horseName  age  saddle  decimalPrice        trainerName  \
# 0  302858      Kings Return  6.0     4.0      0.600000        W P Mullins
# 1  302858    Majestic Red I  6.0     5.0      0.047619       John Hackett
# 2  302858  Clearly Canadian  6.0     2.0      0.166667         D T Hughes
# 3  302858  Bernestic Wonder  8.0     1.0      0.058824         E McNamara
# 4  302858    Beauty's Pride  5.0     6.0      0.038462         J J Lennon
# 5  302858     Graignamanagh  6.0     3.0      0.307692  Harry De Bromhead
#
#       jockeyName  position positionL  dist  outHandicap        RPR         TR  \
# 0      D J Casey         1       NaN   0.0          0.0  102.00000  51.591987
# 1  Conor O'Dwyer         2         8   8.0          0.0   94.00000  51.591987
# 2       G Cotter         3       1.5   9.5          0.0   92.00000  51.591987
# 3    J Old Jones         4      dist  39.5          0.0   71.87665  51.591987
# 4       T Martin         5      dist  69.5          0.0   71.87665  51.591987
# 5      J R Barry        40       NaN  99.5          0.0   71.87665  51.591987
#
#           OR       father           mother       gfather  weight
# 0  79.654604  King's Ride  Browne's Return      Deep Run      73
# 1  79.654604    Long Pond  Courtlough Lady   Giolla Mear      73
# 2  79.654604      Nordico    Over The Seas  North Summit      71
# 3  79.654604     Roselier    Miss Reindeer      Reindeer      73
# 4  79.654604       Noalto   Elena's Beauty      Tarqogan      66
# 5  79.654604    Tremblant      Feathermore  Crash Course      73

# %%
for idx, entry in tqdm(df.iterrows()):
    print(get_dist_of_horse(df, idx))
# Out:
# 6it [00:00, 1326.54it/s]
# 0.0
# 8.0
# 9.5
# 39.5
# 69.5
# 99.5

# %%
df = horses_augment_dist[horses_augment_dist['rid'] == 89607]
df
# Out:
#           rid         horseName   age  saddle  decimalPrice  \
# 182407  89607         Valentana   4.0     3.0      0.250000
# 182408  89607          Gentil J   3.0    12.0      0.058824
# 182409  89607      Ducky Mallon   5.0     1.0      0.166667
# 182410  89607   Snoozing Indian   4.0     4.0      0.047619
# 182411  89607       No Approval   3.0    13.0      0.090909
# 182412  89607   Deeds Not Words   5.0     6.0      0.111111
# 182413  89607  Elusive Approach   4.0     2.0      0.133333
# 182414  89607         Cairdiuil  10.0     5.0      0.076923
# 182415  89607       Sister Slew   6.0    11.0      0.066667
# 182416  89607             Mzuri   4.0     9.0      0.100000
# 182417  89607       Gold Chaser   3.0    16.0      0.038462
# 182418  89607    True Companion   3.0    18.0      0.066667
# 182419  89607       Spanish Boy   3.0    14.0      0.066667
# 182420  89607    Touch Of Frost   3.0    15.0      0.038462
#
#                   trainerName        jockeyName  position positionL   dist  \
# 182407             W McCreery           W J Lee         1       NaN   0.00
# 182408               H Rogers       Shane Foley         2         2   2.00
# 182409         Donal Kinsella      Ronan Whelan         3         3   5.00
# 182410             T J O'Mara      Wayne Lordan         4        .5   5.50
# 182411      Kevin Prendergast       Chris Hayes         5        .5   6.00
# 182412             J F Levins   Donagh O'Connor         6        .5   6.50
# 182413             J S Bolger     Kevin Manning         7       .75   7.25
# 182414               I Madden  Seamie Heffernan         8      1.25   8.50
# 182415            Shane Nolan     Robbie Downey         9      1.75  10.25
# 182416       Ms Sheila Lavery       Pat Smullen        10        nk  10.50
# 182417              M Halford       Conor Hoban        11      4.75  15.25
# 182418   Adrian Brendan Joyce   Declan McDonogh        12       .75  16.00
# 182419  Damian Joseph English       Rory Cleary        13      1.75  17.75
# 182420             J F Levins       Leigh Roche        14        18  35.75
#
#         outHandicap       RPR         TR    OR           father  \
# 182407          0.0  86.00000  76.000000  73.0           Haatef
# 182408          0.0  75.00000  63.000000  69.0           Jeremy
# 182409          0.0  75.00000  61.000000  73.0           Jeremy
# 182410          0.0  70.00000  58.000000  72.0  Sleeping Indian
# 182411          0.0  64.00000  50.000000  69.0          Approve
# 182412          0.0  65.00000  55.000000  70.0   Royal Applause
# 182413          0.0  66.00000  53.000000  73.0     New Approach
# 182414          0.0  61.00000  47.000000  71.0    Bachelor Duke
# 182415          0.0  52.00000  38.000000  67.0          Kheleyf
# 182416          0.0  54.00000  39.000000  69.0           Tagula
# 182417          0.0  36.00000  19.000000  66.0   Canford Cliffs
# 182418          0.0  30.00000  13.000000  62.0     Fast Company
# 182419          0.0  29.00000  12.000000  66.0     Lope De Vega
# 182420          0.0  71.87665  51.591987  66.0     Silver Frost
#
#                     mother          gfather  weight
# 182407         Miss Latina           Mozart      62
# 182408       Lady Pitrizza      Night Shift      58
# 182409         Indus Ridge     Indian Ridge      62
# 182410             Balnaha           Lomond      62
# 182411           Night Cam      Night Shift      58
# 182412                Wars     Green Desert      58
# 182413  Soilse Na Cathrach     Elusive City      62
# 182414           Lilabelle        Lil's Boy      61
# 182415         Capote West           Capote      58
# 182416              Meadow     Green Desert      60
# 182417            Snippets      Be My Guest      57
# 182418         Panglossian         Barathea      55
# 182419             Iuturna          Intidab      57
# 182420   Fantastic Opinion  Fantastic Light      57

# %%
for idx, entry in tqdm(df.iterrows()):
    print(get_dist_of_horse(df, idx))
# Out:
# 14it [00:00, 889.85it/s]
# 0.0
# 2.0
# 5.0
# 5.5
# 6.0
# 6.5
# 7.25
# 8.5
# 10.25
# 10.5
# 15.25
# 16.0
# 17.75
# 35.75

# %%
for idx, entry in tqdm(horses_augment_dist.iterrows()):
    df = horses_augment_dist[horses_augment_dist['rid'] == entry['rid']]
    dist = get_dist_of_horse(df, idx)
    horses_augment_dist.at[idx, 'dist'] = dist
# Out:
# 194898it [03:30, 927.54it/s]

# %% [markdown]
# ---

# %% [markdown]
# ## Save Dataframes

# %%
horses_augment_dist.to_csv(f"{BASE_DIR}/data/csv/horses_augment_dist.csv", index=False)

# %% [markdown]
# ---
