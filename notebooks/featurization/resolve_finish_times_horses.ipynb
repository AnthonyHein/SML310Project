# %% [markdown]
# # `resolve_finish_times_horses.ipynb`

# %% [markdown]
# ### Author: Anthony Hein

# %% [markdown]
# #### Last updated: 10/19/2021

# %% [markdown]
# # Overview:
#
# Prior to featurizing the horse dataset, we must add finishing times for all horses for all races. This will obviously not be a feature to the model but instead will be used to engineer other features such as average race time, best race time under similar conditions, and others.

# %% [markdown]
# ---

# %% [markdown]
# ## Setup

# %%
from datetime import datetime
import git
import os
import re
from typing import List
from tqdm import tqdm
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
BASE_DIR = git.Repo(os.getcwd(), search_parent_directories=True).working_dir
BASE_DIR
# Out:
# '/Users/anthonyhein/Desktop/SML310/project'

# %%
import sys
sys.path.append(f'{BASE_DIR}/utils/')

from rid_to_winning_time import RID_TO_WINNING_TIME
from rid_to_distance import RID_TO_DISTANCE

# %% [markdown]
# ---

# %% [markdown]
# ## Load `horses_augment.csv`

# %%
horses_augment_dist = pd.read_csv(f"{BASE_DIR}/data/csv/horses_augment_dist.csv", low_memory=False) 
horses_augment_dist.head()
# Out:
#       rid         horseName  age  saddle  decimalPrice   trainerName  \
# 0  302858      Kings Return  6.0     4.0      0.600000   W P Mullins
# 1  302858    Majestic Red I  6.0     5.0      0.047619  John Hackett
# 2  302858  Clearly Canadian  6.0     2.0      0.166667    D T Hughes
# 3  302858  Bernestic Wonder  8.0     1.0      0.058824    E McNamara
# 4  302858    Beauty's Pride  5.0     6.0      0.038462    J J Lennon
#
#       jockeyName  position positionL  dist  outHandicap        RPR         TR  \
# 0      D J Casey         1       NaN   0.0          0.0  102.00000  51.591987
# 1  Conor O'Dwyer         2         8   8.0          0.0   94.00000  51.591987
# 2       G Cotter         3       1.5   9.5          0.0   92.00000  51.591987
# 3    J Old Jones         4      dist  39.5          0.0   71.87665  51.591987
# 4       T Martin         5      dist  69.5          0.0   71.87665  51.591987
#
#           OR       father           mother       gfather  weight
# 0  79.654604  King's Ride  Browne's Return      Deep Run      73
# 1  79.654604    Long Pond  Courtlough Lady   Giolla Mear      73
# 2  79.654604      Nordico    Over The Seas  North Summit      71
# 3  79.654604     Roselier    Miss Reindeer      Reindeer      73
# 4  79.654604       Noalto   Elena's Beauty      Tarqogan      66

# %%
horses_augment_dist.shape
# Out:
# (194573, 18)

# %%
horses_augment_times = horses_augment_dist.copy()
horses_augment_times.head()
# Out:
#       rid         horseName  age  saddle  decimalPrice   trainerName  \
# 0  302858      Kings Return  6.0     4.0      0.600000   W P Mullins
# 1  302858    Majestic Red I  6.0     5.0      0.047619  John Hackett
# 2  302858  Clearly Canadian  6.0     2.0      0.166667    D T Hughes
# 3  302858  Bernestic Wonder  8.0     1.0      0.058824    E McNamara
# 4  302858    Beauty's Pride  5.0     6.0      0.038462    J J Lennon
#
#       jockeyName  position positionL  dist  outHandicap        RPR         TR  \
# 0      D J Casey         1       NaN   0.0          0.0  102.00000  51.591987
# 1  Conor O'Dwyer         2         8   8.0          0.0   94.00000  51.591987
# 2       G Cotter         3       1.5   9.5          0.0   92.00000  51.591987
# 3    J Old Jones         4      dist  39.5          0.0   71.87665  51.591987
# 4       T Martin         5      dist  69.5          0.0   71.87665  51.591987
#
#           OR       father           mother       gfather  weight
# 0  79.654604  King's Ride  Browne's Return      Deep Run      73
# 1  79.654604    Long Pond  Courtlough Lady   Giolla Mear      73
# 2  79.654604      Nordico    Over The Seas  North Summit      71
# 3  79.654604     Roselier    Miss Reindeer      Reindeer      73
# 4  79.654604       Noalto   Elena's Beauty      Tarqogan      66

# %% [markdown]
# ---

# %% [markdown]
# ## Helper Functions

# %% [markdown]
# The following is a function for the amount of time a "length" in a given horse race is, inspired by [https://edge.twinspires.com/racing/the-real-value-of-a-length/](https://edge.twinspires.com/racing/the-real-value-of-a-length/).
#
# $$\text{time of length in seconds} = 1\ /\ [\ \text{distance}\ /\ \text{winning time}\ /\ \text{average horse length}\ ]$$
#
# Note that the distance and the average horse length must have the same units to cancel out.

# %%
AVERAGE_HORSE_LENGTH = 2.55 # meters

# %%
def get_time_of_length(distance: float, winning_time: float) -> float:
    return 1 / (distance / winning_time / AVERAGE_HORSE_LENGTH)

# %%
get_time_of_length(1609.34, 95) # 1 mile w/ fast horses
# Out:
# 0.15052754545341568

# %%
get_time_of_length(2*1609.34, 270) # 2 mile w/ moderately fast horses
# Out:
# 0.21390756459169596

# %%
def get_horse_finish_time(row) -> float:
    length_time = get_time_of_length(RID_TO_DISTANCE[row['rid']], RID_TO_WINNING_TIME[row['rid']])
    return RID_TO_WINNING_TIME[row['rid']] + row['dist'] * length_time

# %%
horses_augment_times.iloc[0]
# Out:
# rid                      302858
# horseName          Kings Return
# age                         6.0
# saddle                      4.0
# decimalPrice                0.6
# trainerName         W P Mullins
# jockeyName            D J Casey
# position                      1
# positionL                   NaN
# dist                        0.0
# outHandicap                 0.0
# RPR                       102.0
# TR                    51.591987
# OR                    79.654604
# father              King's Ride
# mother          Browne's Return
# gfather                Deep Run
# weight                       73
# Name: 0, dtype: object

# %%
horses_augment_times.iloc[1]
# Out:
# rid                      302858
# horseName        Majestic Red I
# age                         6.0
# saddle                      5.0
# decimalPrice           0.047619
# trainerName        John Hackett
# jockeyName        Conor O'Dwyer
# position                      2
# positionL                     8
# dist                        8.0
# outHandicap                 0.0
# RPR                        94.0
# TR                    51.591987
# OR                    79.654604
# father                Long Pond
# mother          Courtlough Lady
# gfather             Giolla Mear
# weight                       73
# Name: 1, dtype: object

# %%
get_horse_finish_time(horses_augment_times.iloc[0]), get_horse_finish_time(horses_augment_times.iloc[1])
# Out:
# (277.2, 278.6799476576812)

# %% [markdown]
# ---

# %% [markdown]
# ## Calculate Finish Times for Horses

# %%
horses_augment_times['time'] = horses_augment_times.apply(get_horse_finish_time, axis=1)
horses_augment_times
# Out:
#            rid         horseName  age  saddle  decimalPrice  \
# 0       302858      Kings Return  6.0     4.0      0.600000
# 1       302858    Majestic Red I  6.0     5.0      0.047619
# 2       302858  Clearly Canadian  6.0     2.0      0.166667
# 3       302858  Bernestic Wonder  8.0     1.0      0.058824
# 4       302858    Beauty's Pride  5.0     6.0      0.038462
# ...        ...               ...  ...     ...           ...
# 194568  227139           Old Tim  6.0     5.0      0.142857
# 194569  227139          Our Ling  6.0    12.0      0.111111
# 194570  227139       Ballinarrid  6.0     2.0      0.111111
# 194571  227139      Fountain Pen  9.0     3.0      0.047619
# 194572  227139            Marmat  7.0     9.0      0.153846
#
#                   trainerName      jockeyName  position positionL    dist  \
# 0                 W P Mullins       D J Casey         1       NaN    0.00
# 1                John Hackett   Conor O'Dwyer         2         8    8.00
# 2                  D T Hughes        G Cotter         3       1.5    9.50
# 3                  E McNamara     J Old Jones         4      dist   39.50
# 4                  J J Lennon        T Martin         5      dist   69.50
# ...                       ...             ...       ...       ...     ...
# 194568          Donal Hassett    Mr B Hassett         8        15   65.00
# 194569           C P Donoghue  Philip Dempsey         9        13   78.00
# 194570        Seamus P Murphy     Mr P Fenton        10      0.75   78.75
# 194571  William J Fitzpatrick      Mr P Fahey        11      dist  108.75
# 194572             F J Bowles   Mr A J Martin        40       NaN  138.75
#
#         outHandicap        RPR         TR         OR          father  \
# 0               0.0  102.00000  51.591987  79.654604     King's Ride
# 1               0.0   94.00000  51.591987  79.654604       Long Pond
# 2               0.0   92.00000  51.591987  79.654604         Nordico
# 3               0.0   71.87665  51.591987  79.654604        Roselier
# 4               0.0   71.87665  51.591987  79.654604          Noalto
# ...             ...        ...        ...        ...             ...
# 194568          0.0   42.00000  51.591987  79.654604  Poet's Dream I
# 194569          0.0   24.00000  51.591987  79.654604           Vaour
# 194570          0.0   28.00000  51.591987  79.654604     John French
# 194571          0.0   71.87665  51.591987  79.654604  Royal Fountain
# 194572          0.0   71.87665  51.591987  79.654604         Cataldi
#
#                  mother        gfather  weight        time
# 0       Browne's Return       Deep Run      73  277.200000
# 1       Courtlough Lady    Giolla Mear      73  278.679948
# 2         Over The Seas   North Summit      71  278.957438
# 3         Miss Reindeer       Reindeer      73  284.507242
# 4        Elena's Beauty       Tarqogan      66  290.057045
# ...                 ...            ...     ...         ...
# 194568          Settled  Blue Cashmere      73  263.612842
# 194569         May-Ling    Mississippi      73  266.195410
# 194570         Cuckaloo    Master Buck      76  266.344405
# 194571     Monday's Pet        Menelek      74  272.304178
# 194572         Hot Chic      Hot Grove      73  278.263951
#
# [194573 rows x 19 columns]

# %% [markdown]
# ---

# %% [markdown]
# ## Drop Unecessary Columns

# %% [markdown]
# Finally, we can drop `positionL` and `dist` in favor of this new column `time`.

# %%
horses_augment_times = horses_augment_times.drop(columns=['positionL', 'dist'])
horses_augment_times
# Out:
#            rid         horseName  age  saddle  decimalPrice  \
# 0       302858      Kings Return  6.0     4.0      0.600000
# 1       302858    Majestic Red I  6.0     5.0      0.047619
# 2       302858  Clearly Canadian  6.0     2.0      0.166667
# 3       302858  Bernestic Wonder  8.0     1.0      0.058824
# 4       302858    Beauty's Pride  5.0     6.0      0.038462
# ...        ...               ...  ...     ...           ...
# 194568  227139           Old Tim  6.0     5.0      0.142857
# 194569  227139          Our Ling  6.0    12.0      0.111111
# 194570  227139       Ballinarrid  6.0     2.0      0.111111
# 194571  227139      Fountain Pen  9.0     3.0      0.047619
# 194572  227139            Marmat  7.0     9.0      0.153846
#
#                   trainerName      jockeyName  position  outHandicap  \
# 0                 W P Mullins       D J Casey         1          0.0
# 1                John Hackett   Conor O'Dwyer         2          0.0
# 2                  D T Hughes        G Cotter         3          0.0
# 3                  E McNamara     J Old Jones         4          0.0
# 4                  J J Lennon        T Martin         5          0.0
# ...                       ...             ...       ...          ...
# 194568          Donal Hassett    Mr B Hassett         8          0.0
# 194569           C P Donoghue  Philip Dempsey         9          0.0
# 194570        Seamus P Murphy     Mr P Fenton        10          0.0
# 194571  William J Fitzpatrick      Mr P Fahey        11          0.0
# 194572             F J Bowles   Mr A J Martin        40          0.0
#
#               RPR         TR         OR          father           mother  \
# 0       102.00000  51.591987  79.654604     King's Ride  Browne's Return
# 1        94.00000  51.591987  79.654604       Long Pond  Courtlough Lady
# 2        92.00000  51.591987  79.654604         Nordico    Over The Seas
# 3        71.87665  51.591987  79.654604        Roselier    Miss Reindeer
# 4        71.87665  51.591987  79.654604          Noalto   Elena's Beauty
# ...           ...        ...        ...             ...              ...
# 194568   42.00000  51.591987  79.654604  Poet's Dream I          Settled
# 194569   24.00000  51.591987  79.654604           Vaour         May-Ling
# 194570   28.00000  51.591987  79.654604     John French         Cuckaloo
# 194571   71.87665  51.591987  79.654604  Royal Fountain     Monday's Pet
# 194572   71.87665  51.591987  79.654604         Cataldi         Hot Chic
#
#               gfather  weight        time
# 0            Deep Run      73  277.200000
# 1         Giolla Mear      73  278.679948
# 2        North Summit      71  278.957438
# 3            Reindeer      73  284.507242
# 4            Tarqogan      66  290.057045
# ...               ...     ...         ...
# 194568  Blue Cashmere      73  263.612842
# 194569    Mississippi      73  266.195410
# 194570    Master Buck      76  266.344405
# 194571        Menelek      74  272.304178
# 194572      Hot Grove      73  278.263951
#
# [194573 rows x 17 columns]

# %% [markdown]
# ## Save Dataframes

# %%
horses_augment_times.to_csv(f"{BASE_DIR}/data/csv/horses_augment_times.csv", index=False)

# %% [markdown]
# ---
