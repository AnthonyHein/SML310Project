# %% [markdown]
# # `featurize_horses_v3.ipynb`

# %% [markdown]
# ### Author: Anthony Hein

# %% [markdown]
# #### Last updated: 10/19/2021

# %% [markdown]
# # Overview:
#
# Continue featurization, cannot do in one notebook because requires too much memory.

# %% [markdown]
# ---

# %% [markdown]
# ## Setup

# %%
from datetime import datetime
import git
import os
import re
from typing import List
from tqdm import tqdm
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
BASE_DIR = git.Repo(os.getcwd(), search_parent_directories=True).working_dir
BASE_DIR
# Out:
# '/Users/anthonyhein/Desktop/SML310/project'

# %% [markdown]
# ---

# %% [markdown]
# ## Load `horses_featurized.csv`

# %%
horses_featurized_v2 = pd.read_csv(f"{BASE_DIR}/data/csv/horses_featurized_v2.csv", low_memory=False) 
horses_featurized_v2.head()
# Out:
#       rid         horseName  age  saddle  decimalPrice   trainerName  \
# 0  302858      Kings Return  6.0     4.0      0.600000   W P Mullins
# 1  302858    Majestic Red I  6.0     5.0      0.047619  John Hackett
# 2  302858  Clearly Canadian  6.0     2.0      0.166667    D T Hughes
# 3  302858  Bernestic Wonder  8.0     1.0      0.058824    E McNamara
# 4  302858    Beauty's Pride  5.0     6.0      0.038462    J J Lennon
#
#       jockeyName  position  outHandicap        RPR  ...  father_avg_speed  \
# 0      D J Casey         1          0.0  102.00000  ...               NaN
# 1  Conor O'Dwyer         2          0.0   94.00000  ...               NaN
# 2       G Cotter         3          0.0   92.00000  ...               NaN
# 3    J Old Jones         4          0.0   71.87665  ...               NaN
# 4       T Martin         5          0.0   71.87665  ...               NaN
#
#    mother_avg_speed trainer_avg_speed trainer_avg_position  avg_position  \
# 0               NaN               NaN                  NaN           NaN
# 1               NaN               NaN                  NaN           NaN
# 2               NaN               NaN                  NaN           NaN
# 3               NaN               NaN                  NaN           NaN
# 4               NaN               NaN                  NaN           NaN
#
#    prev_position  jockey_avg_speed  jockey_avg_position  jockey_prev_speed  \
# 0            NaN               NaN                  NaN                NaN
# 1            NaN               NaN                  NaN                NaN
# 2            NaN               NaN                  NaN                NaN
# 3            NaN               NaN                  NaN                NaN
# 4            NaN               NaN                  NaN                NaN
#
#    jockey_prev_position
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
#
# [5 rows x 28 columns]

# %%
horses_featurized_v2.shape
# Out:
# (194573, 28)

# %%
horses_featurized_v3 = horses_featurized_v2.copy()
horses_featurized_v3.head()
# Out:
#       rid         horseName  age  saddle  decimalPrice   trainerName  \
# 0  302858      Kings Return  6.0     4.0      0.600000   W P Mullins
# 1  302858    Majestic Red I  6.0     5.0      0.047619  John Hackett
# 2  302858  Clearly Canadian  6.0     2.0      0.166667    D T Hughes
# 3  302858  Bernestic Wonder  8.0     1.0      0.058824    E McNamara
# 4  302858    Beauty's Pride  5.0     6.0      0.038462    J J Lennon
#
#       jockeyName  position  outHandicap        RPR  ...  father_avg_speed  \
# 0      D J Casey         1          0.0  102.00000  ...               NaN
# 1  Conor O'Dwyer         2          0.0   94.00000  ...               NaN
# 2       G Cotter         3          0.0   92.00000  ...               NaN
# 3    J Old Jones         4          0.0   71.87665  ...               NaN
# 4       T Martin         5          0.0   71.87665  ...               NaN
#
#    mother_avg_speed trainer_avg_speed trainer_avg_position  avg_position  \
# 0               NaN               NaN                  NaN           NaN
# 1               NaN               NaN                  NaN           NaN
# 2               NaN               NaN                  NaN           NaN
# 3               NaN               NaN                  NaN           NaN
# 4               NaN               NaN                  NaN           NaN
#
#    prev_position  jockey_avg_speed  jockey_avg_position  jockey_prev_speed  \
# 0            NaN               NaN                  NaN                NaN
# 1            NaN               NaN                  NaN                NaN
# 2            NaN               NaN                  NaN                NaN
# 3            NaN               NaN                  NaN                NaN
# 4            NaN               NaN                  NaN                NaN
#
#    jockey_prev_position
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
#
# [5 rows x 28 columns]

# %% [markdown]
# ---

# %% [markdown]
# ## Load `races_clean_augment_clean.csv`

# %%
races_clean_augment_clean = pd.read_csv(f"{BASE_DIR}/data/csv/races_clean_augment_clean.csv", low_memory=False) 
races_clean_augment_clean.head()
# Out:
#       rid              course  winningTime  metric  ncond    margin  runners  \
# 0  302858       Thurles (IRE)        277.2  3821.0      1  1.219263        6
# 1  291347   Punchestown (IRE)        447.2  5229.0      5  1.218049        9
# 2  377929  Leopardstown (IRE)        106.4  1609.0      4  1.204927        5
# 3  275117       Curragh (IRE)        125.9  2011.0      4  1.083838        5
# 4   66511  Leopardstown (IRE)        116.3  1810.0      1  1.077871        5
#
#    temp     msl  rain  rhum  Station number             datetime
# 0   2.2  1012.7   0.0    82            4919  1997-01-09 13:15:00
# 1   8.1   992.8   0.0    79            3723  1997-02-16 15:40:00
# 2  10.1   996.7   0.0    76             532  1997-05-11 15:00:00
# 3  15.8  1030.1   0.0    53            3723  1997-05-25 15:35:00
# 4  16.3  1022.9   0.0    53             532  1997-06-02 16:30:00

# %%
races_clean_augment_clean.shape
# Out:
# (19228, 13)

# %% [markdown]
# ---

# %%
def get_average_speed(df) -> float:
    if len(df) == 0:
        return float('nan')
    else:
        return np.mean(df['metric'] / df['time'])

# %%
def get_average_position(df) -> float:
    if len(df) == 0:
        return float('nan')
    else:
        return np.mean(df['position'])

# %%
def get_prev_trainer_races(trainer_name: str, rid: int) -> pd.core.frame.DataFrame:
    df = trainer_to_races[trainer_name]
    if len(df) <= 1:
        return pd.DataFrame()
    else:
        df = df.merge(races_clean_augment_clean, how='inner', on='rid')
        return df[df['datetime'] < df[df['rid'] == rid].iloc[0]['datetime']]

# %%
def get_prev_position_binary(df, rid) -> float:
    if len(df) == 0:
        return float('nan')
    else:
        
        rid_datetime = df[df['rid'] == rid].iloc[0]['datetime']
         
        lo = 0
        hi = len(df) - 1

        while lo <= hi:

            mid = lo + (hi - lo) // 2
            
            curr_datetime = df.iloc[mid]['datetime']

            if curr_datetime < rid_datetime:
                lo = mid + 1

            elif curr_datetime > rid_datetime:
                hi = mid - 1
            
            else:
                break

        return df.iloc[mid - 1]['position'] if mid > 0 else float('nan')

# %%
def get_prev_speed_binary(df, rid) -> float:
    if len(df) == 0:
        return float('nan')
    else:
        
        rid_datetime = df[df['rid'] == rid].iloc[0]['datetime']
         
        lo = 0
        hi = len(df) - 1

        while lo <= hi:

            mid = lo + (hi - lo) // 2
            
            curr_datetime = df.iloc[mid]['datetime']

            if curr_datetime < rid_datetime:
                lo = mid + 1

            elif curr_datetime > rid_datetime:
                hi = mid - 1
            
            else:
                break

        return df.iloc[mid - 1]['metric'] / df.iloc[mid - 1]['time'] if mid > 0 else float('nan')

# %% [markdown]
# ---

# %% [markdown]
# ## Map Horse to Trainer Most Previous Speed

# %%
horses_featurized_v2['trainerName'].value_counts()[:500]
# Out:
# A P O'Brien         7696
# D K Weld            7194
# J S Bolger          6963
# M Halford           5284
# G M Lyons           4616
#                     ...
# Patrick Lacey         40
# Ms Sandra Hughes      40
# L Byrne               40
# C Wilkinson           40
# J P O'Keeffe          40
# Name: trainerName, Length: 500, dtype: int64

# %%
def get_all_races_trainer(trainer_name: str) -> pd.core.frame.DataFrame:
    df = horses_featurized_v2[horses_featurized_v2['trainerName'] == trainer_name]
    if len(df) == 0:
        return pd.DataFrame()
    else:
        df = df.merge(races_clean_augment_clean, how='inner', on='rid')
        df['datetime'] = pd.to_datetime(df['datetime'])
        return df.sort_values(by='datetime')

# %%
sorted_trainer_races = {}

for trainer_name in tqdm(horses_featurized_v2['trainerName'].unique()):
    sorted_trainer_races[trainer_name] = get_all_races_trainer(trainer_name)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1650/1650 [00:26<00:00, 61.78it/s]

# %%
get_all_races_trainer('Patrick Lacey').head()
# Out:
#        rid     horseName  age  saddle  decimalPrice    trainerName  \
# 32  347295   Dip's Guest  4.0     2.0      0.058824  Patrick Lacey
# 33  306437   Dip's Guest  4.0     7.0      0.285714  Patrick Lacey
# 34  231817   Dip's Guest  4.0    12.0      0.066667  Patrick Lacey
# 35  288691  Mister Cheer  3.0     7.0      0.029412  Patrick Lacey
# 36   82221  Mister Cheer  3.0     4.0      0.019608  Patrick Lacey
#
#        jockeyName  position  outHandicap       RPR  ...  metric  ncond  \
# 32     Fran Berry         5          0.0  38.00000  ...  2815.0      1
# 33   Charlie Swan         1          0.0  91.00000  ...  3419.0      1
# 34  Mr J O'Hanlon         6          0.0  33.00000  ...  3218.0      9
# 35     Fran Berry        14          0.0   1.00000  ...  1206.0      2
# 36      J E Casey         9          0.0  71.87665  ...  1407.0      2
#
#       margin runners  temp     msl  rain  rhum  Station number  \
# 32  1.187376       8  15.4  1020.7   0.0    68             518
# 33  1.167938       9  20.2  1019.8   0.0    56             518
# 34  1.410961      11   8.8  1009.0   0.0    74            4935
# 35  1.420869      14  14.0  1015.5   0.0    72            3904
# 36  1.212307       9  15.2  1024.1   0.0    63            4935
#
#               datetime
# 32 1998-08-24 20:05:00
# 33 1998-08-29 14:35:00
# 34 1998-10-26 14:55:00
# 35 1999-06-29 18:00:00
# 36 1999-07-27 20:00:00
#
# [5 rows x 35 columns]

# %%
get_prev_speed_binary(sorted_trainer_races['Patrick Lacey'], 347295)
# Out:
# nan

# %%
get_prev_speed_binary(sorted_trainer_races['Patrick Lacey'], 306437)
# Out:
# 13.826689841709138

# %%
get_prev_speed_binary(sorted_trainer_races['Patrick Lacey'], 231817)
# Out:
# 14.041067761806982

# %%
horse_to_trainer_prev_speed = {}

for idx, row in tqdm(horses_featurized_v2.iterrows()):
    prev_trainer_races = sorted_trainer_races[row['trainerName']]
    horse_to_trainer_prev_speed[idx] = get_prev_speed_binary(prev_trainer_races, row['rid'])
# Out:
# 194573it [05:41, 570.24it/s]

# %% [markdown]
# ---

# %% [markdown]
# ## Map Horse to Trainer Most Previous Position

# %%
get_prev_position_binary(sorted_trainer_races['Patrick Lacey'], 347295)
# Out:
# nan

# %%
get_prev_position_binary(sorted_trainer_races['Patrick Lacey'], 306437)
# Out:
# 5

# %%
get_prev_position_binary(sorted_trainer_races['Patrick Lacey'], 231817)
# Out:
# 1

# %%
horse_to_trainer_prev_position = {}

for idx, row in tqdm(horses_featurized_v2.iterrows()):
    prev_trainer_races = sorted_trainer_races[row['trainerName']]
    horse_to_trainer_prev_position[idx] = get_prev_position_binary(prev_trainer_races, row['rid'])
# Out:
# 194573it [05:06, 634.05it/s]

# %% [markdown]
# ---

# %% [markdown]
# ## Checkpoint `horses_featurized`

# %%
rename_cols = {
    0: 'trainer_prev_speed',
}

df_trainer_prev_speed = pd.DataFrame.from_dict(horse_to_trainer_prev_speed, orient='index').rename(columns=rename_cols)
df_trainer_prev_speed.sample(5)
# Out:
#         trainer_prev_speed
# 192255           16.604747
# 36899            16.397398
# 31636            15.445918
# 118470           13.998131
# 103680           15.528950

# %%
rename_cols = {
    0: 'trainer_prev_position',
}

df_trainer_prev_position = pd.DataFrame.from_dict(horse_to_trainer_prev_position, orient='index').rename(columns=rename_cols)
df_trainer_prev_position.sample(5)
# Out:
#         trainer_prev_position
# 148736                    4.0
# 173744                    1.0
# 37918                    12.0
# 37446                     5.0
# 20661                     4.0

# %%
horses_featurized_v3 = horses_featurized_v3.join(df_trainer_prev_speed) \
                                           .join(df_trainer_prev_position)

# %%
horses_featurized_v3.sample(10)
# Out:
#            rid         horseName  age  saddle  decimalPrice  \
# 126962  185905      Reckless Lad  4.0     6.0      0.142857
# 94361   206453     Final Opinion  5.0     3.0      0.047619
# 80003    35344  Mississippi John  3.0     8.0      0.058824
# 148767  315414  Touchwoodexpress  5.0    12.0      0.222222
# 104222  390087            Macnas  4.0    13.0      0.058824
# 77877   325470    Pelican Waters  3.0     3.0      0.142857
# 58783   186399    Lift The Gloom  6.0     4.0      0.230769
# 99217   282857            Krivan  3.0     6.0      0.047619
# 104847  199505        Heavy Duty  5.0    10.0      0.024390
# 128348   90775        Michaelmas  3.0     8.0      0.142857
#
#                 trainerName       jockeyName  position  outHandicap   RPR  \
# 126962       Patrick Martin      Conor Hoban         3          0.0  75.0
# 94361      Declan Gillespie      Davy Condon         4          0.0  79.0
# 80003             G M Lyons     Gary Carroll        10          0.0  24.0
# 148767           Paul Nolan  Mr A Fitzgerald         4          0.0  89.0
# 104222   John Joseph Murphy    Marc Monaghan         4          0.0  65.0
# 77877   Mrs John Harrington       Fran Berry         6          0.0  86.0
# 58783           Noel Lawlor      Rory Cleary         2          0.0  64.0
# 99217             M Halford      Shane Foley         3          0.0  74.0
# 104847              S Buggy       Ms K Walsh         9          0.0  97.0
# 128348          A P O'Brien   Joseph O'Brien         7          0.0  95.0
#
#         ...  trainer_avg_speed  trainer_avg_position avg_position  \
# 126962  ...          15.244656              6.789181     3.000000
# 94361   ...          15.005777              5.918719     4.200000
# 80003   ...          15.693452              5.303017     7.800000
# 148767  ...          13.511881              7.056338          NaN
# 104222  ...          14.737579              7.323133     4.833333
# 77877   ...          14.473813              6.830835     5.714286
# 58783   ...          15.471457              7.988095     6.222222
# 99217   ...          15.336099              5.878150          NaN
# 104847  ...                NaN                   NaN          NaN
# 128348  ...          15.467009              4.038976     1.666667
#
#        prev_position  jockey_avg_speed  jockey_avg_position  \
# 126962           1.0         15.546661             6.514429
# 94361            8.0         15.032847             6.703797
# 80003            4.0         15.535219             6.262282
# 148767           NaN         12.808601             5.775281
# 104222           7.0         15.652317             7.690476
# 77877            3.0         15.156899             5.706398
# 58783            2.0         15.230877             7.128869
# 99217            NaN         15.396640             6.317889
# 104847           NaN         13.422050             5.045455
# 128348           2.0         15.454437             4.742435
#
#         jockey_prev_speed  jockey_prev_position  trainer_prev_speed  \
# 126962          15.507608                   5.0           15.340554
# 94361           16.420609                   7.0           16.594657
# 80003           16.297014                  11.0           16.313352
# 148767          13.458804                   1.0           14.715963
# 104222          15.412892                  13.0           15.738064
# 77877           16.270912                   1.0           14.046268
# 58783           14.142396                  10.0           15.869178
# 99217           15.868159                   5.0           15.868159
# 104847          12.561556                   9.0                 NaN
# 128348          16.312287                   1.0           15.724399
#
#         trainer_prev_position
# 126962                    6.0
# 94361                     3.0
# 80003                     4.0
# 148767                   10.0
# 104222                    5.0
# 77877                     1.0
# 58783                    11.0
# 99217                     5.0
# 104847                    NaN
# 128348                   11.0
#
# [10 rows x 30 columns]

# %%
horses_featurized_v3.shape
# Out:
# (194573, 30)

# %% [markdown]
# ---

# %% [markdown]
# ## Save Dataframes

# %%
horses_featurized_v3.to_csv(f"{BASE_DIR}/data/csv/horses_featurized_v3.csv", index=False)

# %% [markdown]
# ---
