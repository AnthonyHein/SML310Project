# %% [markdown]
# # `trim_augment_races.ipynb`

# %% [markdown]
# ### Author: Anthony Hein

# %% [markdown]
# #### Last updated: 10/19/2021

# %% [markdown]
# # Overview:
#
# We can once again trim the dataset since we have since made several simiplications from the last time it was trimmed.

# %% [markdown]
# ---

# %% [markdown]
# ## Setup

# %%
from datetime import datetime
import git
import os
from typing import List
from tqdm import tqdm
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
BASE_DIR = git.Repo(os.getcwd(), search_parent_directories=True).working_dir
BASE_DIR
# Out:
# '/Users/anthonyhein/Desktop/SML310/project'

# %% [markdown]
# ---

# %% [markdown]
# ## Load `races_aticnmidg.csv`

# %%
races_clean_augment = pd.read_csv(f"{BASE_DIR}/data/csv/races_clean_augment.csv", low_memory=False) 
races_clean_augment.head()
# Out:
#       rid              course   time      date  hurdles prizes  winningTime  \
# 0  302858       Thurles (IRE)  01:15  97/01/09      NaN     []        277.2
# 1  291347   Punchestown (IRE)  03:40  97/02/16      NaN     []        447.2
# 2  377929  Leopardstown (IRE)  03:00  97/05/11      NaN     []        106.4
# 3  275117       Curragh (IRE)  03:35  97/05/25      NaN     []        125.9
# 4   66511  Leopardstown (IRE)  04:30  97/06/02      NaN     []        116.3
#
#    metric countryCode  ncond  class    margin  runners  temp     msl  rain  \
# 0  3821.0          IE      1      0  1.219263        6   2.2  1012.7   0.0
# 1  5229.0          IE      5      0  1.218049        9   8.1   992.8   0.0
# 2  1609.0          IE      4      0  1.204927        5  10.1   996.7   0.0
# 3  2011.0          IE      4      0  1.083838        5  15.8  1030.1   0.0
# 4  1810.0          IE      1      0  1.077871        5  16.3  1022.9   0.0
#
#    rhum  Station number
# 0    82            4919
# 1    79            3723
# 2    76             532
# 3    53            3723
# 4    53             532

# %%
races_clean_augment.shape
# Out:
# (19271, 18)

# %% [markdown]
# ---

# %% [markdown]
# ## Drop Unecessary Columns

# %% [markdown]
# In particular, we no longer need `hurdles` (since they are all `NaN`), we have realized that `prizes` is unecessary (this is only needed for a potential Monte Carlo simulation), we no longer need `countryCode` because it is all Ireland, and we can drop `class` since there are only 11 instances of a class not equal to 0.

# %%
races_clean_augment = races_clean_augment[races_clean_augment['class'] == 0]
races_clean_augment
# Out:
#           rid              course   time      date  hurdles prizes  \
# 0      302858       Thurles (IRE)  01:15  97/01/09      NaN     []
# 1      291347   Punchestown (IRE)  03:40  97/02/16      NaN     []
# 2      377929  Leopardstown (IRE)  03:00  97/05/11      NaN     []
# 3      275117       Curragh (IRE)  03:35  97/05/25      NaN     []
# 4       66511  Leopardstown (IRE)  04:30  97/06/02      NaN     []
# ...       ...                 ...    ...       ...      ...    ...
# 19266  227342          Cork (IRE)  03:30  99/12/12      NaN     []
# 19267  243638    Down Royal (IRE)  03:30  99/12/27      NaN     []
# 19268   44932       Clonmel (IRE)  03:35  99/12/27      NaN     []
# 19269  360255  Leopardstown (IRE)  03:45  99/12/29      NaN     []
# 19270  227139  Leopardstown (IRE)  03:15  99/12/29      NaN     []
#
#        winningTime  metric countryCode  ncond  class    margin  runners  temp  \
# 0            277.2  3821.0          IE      1      0  1.219263        6   2.2
# 1            447.2  5229.0          IE      5      0  1.218049        9   8.1
# 2            106.4  1609.0          IE      4      0  1.204927        5  10.1
# 3            125.9  2011.0          IE      4      0  1.083838        5  15.8
# 4            116.3  1810.0          IE      1      0  1.077871        5  16.3
# ...            ...     ...         ...    ...    ...       ...      ...   ...
# 19266        248.2  3218.0          IE      9      0  1.540875       14   4.0
# 19267        252.0  3218.0          IE      9      0  1.576670       14   2.5
# 19268        296.2  3620.0          IE     12      0  1.595269       12   3.5
# 19269        253.0  3218.0          IE     11      0  1.296711       10   2.7
# 19270        250.7  3218.0          IE     11      0  1.403233       12   4.1
#
#           msl  rain  rhum  Station number
# 0      1012.7   0.0    82            4919
# 1       992.8   0.0    79            3723
# 2       996.7   0.0    76             532
# 3      1030.1   0.0    53            3723
# 4      1022.9   0.0    53             532
# ...       ...   ...   ...             ...
# 19266  1003.5   0.4    83            3904
# 19267   988.8   0.0    93            2437
# 19268   990.3   0.0    85            3613
# 19269  1021.3   0.0    88             532
# 19270  1021.0   0.0    85             532
#
# [19260 rows x 18 columns]

# %%
races_clean_augment = races_clean_augment.drop(columns=['hurdles', 'prizes', 'countryCode', 'class'])
races_clean_augment
# Out:
#           rid              course   time      date  winningTime  metric  \
# 0      302858       Thurles (IRE)  01:15  97/01/09        277.2  3821.0
# 1      291347   Punchestown (IRE)  03:40  97/02/16        447.2  5229.0
# 2      377929  Leopardstown (IRE)  03:00  97/05/11        106.4  1609.0
# 3      275117       Curragh (IRE)  03:35  97/05/25        125.9  2011.0
# 4       66511  Leopardstown (IRE)  04:30  97/06/02        116.3  1810.0
# ...       ...                 ...    ...       ...          ...     ...
# 19266  227342          Cork (IRE)  03:30  99/12/12        248.2  3218.0
# 19267  243638    Down Royal (IRE)  03:30  99/12/27        252.0  3218.0
# 19268   44932       Clonmel (IRE)  03:35  99/12/27        296.2  3620.0
# 19269  360255  Leopardstown (IRE)  03:45  99/12/29        253.0  3218.0
# 19270  227139  Leopardstown (IRE)  03:15  99/12/29        250.7  3218.0
#
#        ncond    margin  runners  temp     msl  rain  rhum  Station number
# 0          1  1.219263        6   2.2  1012.7   0.0    82            4919
# 1          5  1.218049        9   8.1   992.8   0.0    79            3723
# 2          4  1.204927        5  10.1   996.7   0.0    76             532
# 3          4  1.083838        5  15.8  1030.1   0.0    53            3723
# 4          1  1.077871        5  16.3  1022.9   0.0    53             532
# ...      ...       ...      ...   ...     ...   ...   ...             ...
# 19266      9  1.540875       14   4.0  1003.5   0.4    83            3904
# 19267      9  1.576670       14   2.5   988.8   0.0    93            2437
# 19268     12  1.595269       12   3.5   990.3   0.0    85            3613
# 19269     11  1.296711       10   2.7  1021.3   0.0    88             532
# 19270     11  1.403233       12   4.1  1021.0   0.0    85             532
#
# [19260 rows x 14 columns]

# %% [markdown]
# ---

# %% [markdown]
# ## Merge `date` and `time`

# %% [markdown]
# Let's also make `date` and `time` one column which is just `datetime`, and we will save this in a more standard format to prevent going back-and-forth.

# %%
races_clean_augment['datetime'] = [
    datetime.strptime(row['date'] + ' ' + row['time'] + ' PM', '%y/%m/%d %I:%M %p')
    for idx, row
    in races_clean_augment.iterrows()
]
races_clean_augment.head()
# Out:
#       rid              course   time      date  winningTime  metric  ncond  \
# 0  302858       Thurles (IRE)  01:15  97/01/09        277.2  3821.0      1
# 1  291347   Punchestown (IRE)  03:40  97/02/16        447.2  5229.0      5
# 2  377929  Leopardstown (IRE)  03:00  97/05/11        106.4  1609.0      4
# 3  275117       Curragh (IRE)  03:35  97/05/25        125.9  2011.0      4
# 4   66511  Leopardstown (IRE)  04:30  97/06/02        116.3  1810.0      1
#
#      margin  runners  temp     msl  rain  rhum  Station number  \
# 0  1.219263        6   2.2  1012.7   0.0    82            4919
# 1  1.218049        9   8.1   992.8   0.0    79            3723
# 2  1.204927        5  10.1   996.7   0.0    76             532
# 3  1.083838        5  15.8  1030.1   0.0    53            3723
# 4  1.077871        5  16.3  1022.9   0.0    53             532
#
#              datetime
# 0 1997-01-09 13:15:00
# 1 1997-02-16 15:40:00
# 2 1997-05-11 15:00:00
# 3 1997-05-25 15:35:00
# 4 1997-06-02 16:30:00

# %% [markdown]
# Now, we can drop `date` and `time`.

# %%
races_clean_augment = races_clean_augment.drop(columns=['date', 'time'])
races_clean_augment
# Out:
#           rid              course  winningTime  metric  ncond    margin  \
# 0      302858       Thurles (IRE)        277.2  3821.0      1  1.219263
# 1      291347   Punchestown (IRE)        447.2  5229.0      5  1.218049
# 2      377929  Leopardstown (IRE)        106.4  1609.0      4  1.204927
# 3      275117       Curragh (IRE)        125.9  2011.0      4  1.083838
# 4       66511  Leopardstown (IRE)        116.3  1810.0      1  1.077871
# ...       ...                 ...          ...     ...    ...       ...
# 19266  227342          Cork (IRE)        248.2  3218.0      9  1.540875
# 19267  243638    Down Royal (IRE)        252.0  3218.0      9  1.576670
# 19268   44932       Clonmel (IRE)        296.2  3620.0     12  1.595269
# 19269  360255  Leopardstown (IRE)        253.0  3218.0     11  1.296711
# 19270  227139  Leopardstown (IRE)        250.7  3218.0     11  1.403233
#
#        runners  temp     msl  rain  rhum  Station number            datetime
# 0            6   2.2  1012.7   0.0    82            4919 1997-01-09 13:15:00
# 1            9   8.1   992.8   0.0    79            3723 1997-02-16 15:40:00
# 2            5  10.1   996.7   0.0    76             532 1997-05-11 15:00:00
# 3            5  15.8  1030.1   0.0    53            3723 1997-05-25 15:35:00
# 4            5  16.3  1022.9   0.0    53             532 1997-06-02 16:30:00
# ...        ...   ...     ...   ...   ...             ...                 ...
# 19266       14   4.0  1003.5   0.4    83            3904 1999-12-12 15:30:00
# 19267       14   2.5   988.8   0.0    93            2437 1999-12-27 15:30:00
# 19268       12   3.5   990.3   0.0    85            3613 1999-12-27 15:35:00
# 19269       10   2.7  1021.3   0.0    88             532 1999-12-29 15:45:00
# 19270       12   4.1  1021.0   0.0    85             532 1999-12-29 15:15:00
#
# [19260 rows x 13 columns]

# %% [markdown]
# ---

# %% [markdown]
# ## Save Dataframes

# %%
races_clean_augment.to_csv(f"{BASE_DIR}/data/csv/races_clean_augment_clean.csv", index=False)

# %% [markdown]
# ---
