# %% [markdown]
# # `create_races_all.ipynb`

# %% [markdown]
# ### Author: Anthony Hein

# %% [markdown]
# #### Last updated: 9/19/2021

# %% [markdown]
# # Overview:
#
# Concatenates `races_x.csv` files found at [https://www.kaggle.com/hwaitt/horse-racing](https://www.kaggle.com/hwaitt/horse-racing) into one file `races_all.csv`.

# %% [markdown]
# ---

# %% [markdown]
# ## Setup

# %%
import git
import os
import glob
import pandas as pd
import numpy as np

# %%
BASE_DIR = git.Repo(os.getcwd(), search_parent_directories=True).working_dir
BASE_DIR
# Out:
# '/Users/anthonyhein/Desktop/SML310/project'

# %% [markdown]
# ---

# %% [markdown]
# ## Find Files

# %%
races_x_csvs = glob.glob(f"{BASE_DIR}/raw/csv/racing/races_*.csv")
races_x_csvs
# Out:
# ['/Users/anthonyhein/Desktop/SML310/project/raw/csv/racing/races_1997.csv',
#  '/Users/anthonyhein/Desktop/SML310/project/raw/csv/racing/races_1996.csv',
#  '/Users/anthonyhein/Desktop/SML310/project/raw/csv/racing/races_1994.csv',
#  '/Users/anthonyhein/Desktop/SML310/project/raw/csv/racing/races_1995.csv',
#  '/Users/anthonyhein/Desktop/SML310/project/raw/csv/racing/races_1991.csv',
#  '/Users/anthonyhein/Desktop/SML310/project/raw/csv/racing/races_1990.csv',
#  '/Users/anthonyhein/Desktop/SML310/project/raw/csv/racing/races_1992.csv',
#  '/Users/anthonyhein/Desktop/SML310/project/raw/csv/racing/races_1993.csv',
#  '/Users/anthonyhein/Desktop/SML310/project/raw/csv/racing/races_2018.csv',
#  '/Users/anthonyhein/Desktop/SML310/project/raw/csv/racing/races_2019.csv',
#  '/Users/anthonyhein/Desktop/SML310/project/raw/csv/racing/races_2009.csv',
#  '/Users/anthonyhein/Desktop/SML310/project/raw/csv/racing/races_2020.csv',
#  '/Users/anthonyhein/Desktop/SML310/project/raw/csv/racing/races_2008.csv',
#  '/Users/anthonyhein/Desktop/SML310/project/raw/csv/racing/races_2012.csv',
#  '/Users/anthonyhein/Desktop/SML310/project/raw/csv/racing/races_2006.csv',
#  '/Users/anthonyhein/Desktop/SML310/project/raw/csv/racing/races_2007.csv',
#  '/Users/anthonyhein/Desktop/SML310/project/raw/csv/racing/races_2013.csv',
#  '/Users/anthonyhein/Desktop/SML310/project/raw/csv/racing/races_2005.csv',
#  '/Users/anthonyhein/Desktop/SML310/project/raw/csv/racing/races_2011.csv',
#  '/Users/anthonyhein/Desktop/SML310/project/raw/csv/racing/races_2010.csv',
#  '/Users/anthonyhein/Desktop/SML310/project/raw/csv/racing/races_2004.csv',
#  '/Users/anthonyhein/Desktop/SML310/project/raw/csv/racing/races_2000.csv',
#  '/Users/anthonyhein/Desktop/SML310/project/raw/csv/racing/races_2014.csv',
#  '/Users/anthonyhein/Desktop/SML310/project/raw/csv/racing/races_2015.csv',
#  '/Users/anthonyhein/Desktop/SML310/project/raw/csv/racing/races_2001.csv',
#  '/Users/anthonyhein/Desktop/SML310/project/raw/csv/racing/races_2017.csv',
#  '/Users/anthonyhein/Desktop/SML310/project/raw/csv/racing/races_2003.csv',
#  '/Users/anthonyhein/Desktop/SML310/project/raw/csv/racing/races_2002.csv',
#  '/Users/anthonyhein/Desktop/SML310/project/raw/csv/racing/races_2016.csv',
#  '/Users/anthonyhein/Desktop/SML310/project/raw/csv/racing/races_1998.csv',
#  '/Users/anthonyhein/Desktop/SML310/project/raw/csv/racing/races_1999.csv']

# %%
len(races_x_csvs)
# Out:
# 31

# %% [markdown]
# ---

# %% [markdown]
# ## Extract Dataframes

# %%
dfs = [pd.read_csv(e, low_memory=False) for e in races_x_csvs]
dfs[0].head()
# Out:
#       rid          course   time      date  \
# 0  267255  Southwell (AW)  03:40  97/01/01
# 1  297570  Southwell (AW)  12:35  97/01/01
# 2  334421  Southwell (AW)  01:05  97/01/01
# 3  366304  Southwell (AW)  03:10  97/01/01
# 4   13063  Southwell (AW)  02:40  97/01/01
#
#                                                title   rclass  band   ages  \
# 0                          New Year Handicap Class E  Class 5  0-70    3yo
# 1         Resolution Claiming Stakes Class F (Div I)  Class 6   NaN   4yo+
# 2  One Too Many Median Auction Maiden Apprentices...  Class 6   NaN  4-6yo
# 3  Morning Call Selling Stakes Class G Southwell ...  Class 6   NaN    3yo
# 4           Thinking &amp; Drinking Handicap Class E  Class 5  0-70   4yo+
#
#   distance condition hurdles                           prizes  winningTime  \
# 0       1m  Standard     NaN  [2752.25, 833.0, 406.5, 193.25]        106.9
# 1       7f  Standard     NaN           [1944.0, 544.0, 264.0]         91.0
# 2     1m3f  Standard     NaN           [2502.0, 702.0, 342.0]        150.7
# 3       1m  Standard     NaN           [2189.0, 614.0, 299.0]        108.6
# 4     2m½f  Standard     NaN  [2726.25, 825.0, 402.5, 191.25]        231.4
#
#     prize  metric countryCode  ncond  class
# 0  4184.0  1609.0          GB      0      5
# 1  2752.0  1407.0          GB      0      6
# 2  3546.0  2212.0          GB      0      6
# 3  3102.0  1609.0          GB      0      6
# 4  4144.0  3318.5          GB      0      5

# %% [markdown]
# ---

# %% [markdown]
# ## Clean Dataframes

# %%
columns = dfs[0].columns
for i, df in enumerate(dfs):
    if len(df.columns) != len(columns) or not np.all(df.columns == columns):
        print(f"Failed at index {i}")
        print(set(df.columns).symmetric_difference(set(columns)))
# Out:
# Failed at index 11
# {'currency'}

# %%
dfs[11].head()
# Out:
#      rid            course   time      date  \
# 0  10312          Fakenham  02:55  20/01/01
# 1  10896        Cheltenham  03:50  20/01/01
# 2  23038     Tramore (IRE)  02:55  20/01/01
# 3  23986  Fairyhouse (IRE)  02:40  20/01/01
# 4  25123  Fairyhouse (IRE)  02:05  20/01/01
#
#                                                title   rclass    band  ages  \
# 0               Happy New Year Maiden Hurdle (Div I)  Class 4     NaN  4yo+
# 1  EBF Stallions &amp; Cheltenham Pony Club (A St...  Class 1     NaN   4yo
# 2        Jerry O'Donovan Memorial Rated Novice Chase      NaN     NaN  5yo+
# 3  Follow Fairyhouse On Social Media Beginners Chase      NaN     NaN  5yo+
# 4  Fairyhouse Launches New Brand In 2020 Handicap...      NaN  80-109  4yo+
#
#   distance     condition     hurdles  \
# 0       2m  Good To Soft   9 hurdles
# 1     1m6f          Soft         NaN
# 2       2m          Soft   12 fences
# 3     2m5f      Yielding   13 fences
# 4       3m      Yielding  13 hurdles
#
#                                             prizes  winningTime  prize  \
# 0                   [5198.4, 1526.4, 763.2, 381.6]       253.88   7869
# 1  [14237.5, 5342.5, 2675.0, 1332.5, 670.0, 335.0]       206.55  24592
# 2    [7387.5, 2387.5, 1137.5, 512.5, 262.5, 137.5]       266.40  11826
# 3    [8274.0, 2674.0, 1274.0, 574.0, 294.0, 154.0]       340.90  13244
# 4    [7092.0, 2292.0, 1092.0, 492.0, 252.0, 132.0]       389.00  11352
#
#    metric countryCode  ncond  class currency
# 0  3218.0          GB     10      4      NaN
# 1  2815.0          GB      5      1      NaN
# 2  3218.0          IE      5      0      NaN
# 3  4223.0          IE      6      0      NaN
# 4  4827.0          IE      6      0      NaN

# %% [markdown]
# Seems like this dataset has extraneous columns. Let's remove those.

# %%
try:
    dfs[11] = dfs[11].drop(columns='currency')
except KeyError:
    print("Already dropped this column.")
        
dfs[11].head()
# Out:
#      rid            course   time      date  \
# 0  10312          Fakenham  02:55  20/01/01
# 1  10896        Cheltenham  03:50  20/01/01
# 2  23038     Tramore (IRE)  02:55  20/01/01
# 3  23986  Fairyhouse (IRE)  02:40  20/01/01
# 4  25123  Fairyhouse (IRE)  02:05  20/01/01
#
#                                                title   rclass    band  ages  \
# 0               Happy New Year Maiden Hurdle (Div I)  Class 4     NaN  4yo+
# 1  EBF Stallions &amp; Cheltenham Pony Club (A St...  Class 1     NaN   4yo
# 2        Jerry O'Donovan Memorial Rated Novice Chase      NaN     NaN  5yo+
# 3  Follow Fairyhouse On Social Media Beginners Chase      NaN     NaN  5yo+
# 4  Fairyhouse Launches New Brand In 2020 Handicap...      NaN  80-109  4yo+
#
#   distance     condition     hurdles  \
# 0       2m  Good To Soft   9 hurdles
# 1     1m6f          Soft         NaN
# 2       2m          Soft   12 fences
# 3     2m5f      Yielding   13 fences
# 4       3m      Yielding  13 hurdles
#
#                                             prizes  winningTime  prize  \
# 0                   [5198.4, 1526.4, 763.2, 381.6]       253.88   7869
# 1  [14237.5, 5342.5, 2675.0, 1332.5, 670.0, 335.0]       206.55  24592
# 2    [7387.5, 2387.5, 1137.5, 512.5, 262.5, 137.5]       266.40  11826
# 3    [8274.0, 2674.0, 1274.0, 574.0, 294.0, 154.0]       340.90  13244
# 4    [7092.0, 2292.0, 1092.0, 492.0, 252.0, 132.0]       389.00  11352
#
#    metric countryCode  ncond  class
# 0  3218.0          GB     10      4
# 1  2815.0          GB      5      1
# 2  3218.0          IE      5      0
# 3  4223.0          IE      6      0
# 4  4827.0          IE      6      0

# %%
columns = dfs[0].columns
for i, df in enumerate(dfs):
    if len(df.columns) != len(columns) or not np.all(df.columns == columns):
        print(f"Failed at index {i}")
        print(set(df.columns).symmetric_difference(set(columns)))

# %% [markdown]
# ---

# %% [markdown]
# ## Concatenate Dataframes

# %%
races_all = pd.concat(dfs)
races_all.head()
# Out:
#       rid          course   time      date  \
# 0  267255  Southwell (AW)  03:40  97/01/01
# 1  297570  Southwell (AW)  12:35  97/01/01
# 2  334421  Southwell (AW)  01:05  97/01/01
# 3  366304  Southwell (AW)  03:10  97/01/01
# 4   13063  Southwell (AW)  02:40  97/01/01
#
#                                                title   rclass  band   ages  \
# 0                          New Year Handicap Class E  Class 5  0-70    3yo
# 1         Resolution Claiming Stakes Class F (Div I)  Class 6   NaN   4yo+
# 2  One Too Many Median Auction Maiden Apprentices...  Class 6   NaN  4-6yo
# 3  Morning Call Selling Stakes Class G Southwell ...  Class 6   NaN    3yo
# 4           Thinking &amp; Drinking Handicap Class E  Class 5  0-70   4yo+
#
#   distance condition hurdles                           prizes  winningTime  \
# 0       1m  Standard     NaN  [2752.25, 833.0, 406.5, 193.25]        106.9
# 1       7f  Standard     NaN           [1944.0, 544.0, 264.0]         91.0
# 2     1m3f  Standard     NaN           [2502.0, 702.0, 342.0]        150.7
# 3       1m  Standard     NaN           [2189.0, 614.0, 299.0]        108.6
# 4     2m½f  Standard     NaN  [2726.25, 825.0, 402.5, 191.25]        231.4
#
#     prize  metric countryCode ncond  class
# 0  4184.0  1609.0          GB     0      5
# 1  2752.0  1407.0          GB     0      6
# 2  3546.0  2212.0          GB     0      6
# 3  3102.0  1609.0          GB     0      6
# 4  4144.0  3318.5          GB     0      5

# %%
races_all.shape
# Out:
# (396572, 18)

# %%
assert len(races_all) == sum([len(df) for df in dfs])

# %% [markdown]
# ---

# %% [markdown]
# ## Save Dataframe

# %%
races_all.to_csv(f"{BASE_DIR}/data/csv/races_all.csv", index=False)
